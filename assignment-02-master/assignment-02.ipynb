# %% [markdown]
# # Lesson 2: Importing & Exploring Data

# %% [markdown]
# In this lesson, we'll learn to pull data into our Python environment and run some of the first diagnostics we'll need to understand our data.
#
# Why don't you kick us off by importing our two most important data analytic tools into our Jupyter notebook: Pandas and Numpy?
#
# ## Exercise 1
# Import Pandas and NumPy into your Jupyter Notebook and assign the standard aliases to them.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Exercise 2
#
# Now let's go straight into importing data into our Python environment! Check out DC's Open Data Portal at opendata.dc.gov.
#
# From here, we'll import data into our Python environment in two different ways. First, let's try downloading the data from the website and then pulling it into this notebook.
#
# Find the City Service Requests for 2016 in DC's Open Data Portal and download the spreadsheet (.csv file) to your computer.
#
# This is a data set containing requests for service through DC's 311 system. People can enter these requests by calling 311, texting DC-311 (32-311), using the 311 app, or visiting the city's online 311 portal.
#
# Now let's try pulling the data into our Python environment using Pandas.
#
#
# Pull the .csv file into your Python environment using Pandas and assign it to an object called 'df'.

# %%
pd.read_csv('City_Service_Requests_in_2016.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d8bfd2132142> in <module>()
# ----> 1 pd.read_csv('City_Service_Requests_in_2016.csv')
#
# C:\Users\CDL\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     644                     skip_blank_lines=skip_blank_lines)
#     645
# --> 646         return _read(filepath_or_buffer, kwds)
#     647
#     648     parser_f.__name__ = name
#
# C:\Users\CDL\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     387
#     388     # Create the parser.
# --> 389     parser = TextFileReader(filepath_or_buffer, **kwds)
#     390
#     391     if (nrows is not None) and (chunksize is not None):
#
# C:\Users\CDL\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     728             self.options['has_index_names'] = kwds['has_index_names']
#     729
# --> 730         self._make_engine(self.engine)
#     731
#     732     def close(self):
#
# C:\Users\CDL\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#     921     def _make_engine(self, engine='c'):
#     922         if engine == 'c':
# --> 923             self._engine = CParserWrapper(self.f, **self.options)
#     924         else:
#     925             if engine == 'python':
#
# C:\Users\CDL\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1388         kwds['allow_leading_cols'] = self.index_col is not False
#    1389
# -> 1390         self._reader = _parser.TextReader(src, **kwds)
#    1391
#    1392         # XXX
#
# pandas\parser.pyx in pandas.parser.TextReader.__cinit__ (pandas\parser.c:4184)()
#
# pandas\parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas\parser.c:8449)()
#
# FileNotFoundError: File b'City_Service_Requests_in_2016.csv' does not exist

# %% [markdown]
# What happened? You may have received an error like this: "OSError: File b'City_Service_Requests_in_2016.csv' does not exist"
#
# This means that the .csv file is not in the directory your notebook is calling from (which is, in fact, the directory the notebook is in). To find out which directory your notebook is calling from, import the os package and get the current working directory.
#
# ## Exercise 3
#
# Import the os package and get the current working directory.

# %%
# %ls 
#line magic is more I-Pythonic
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is BA59-3588
#
#  Directory of C:\Users\CDL\Documents\My python learning\assignment-02-master
#
# 09/09/2017  05:41 PM    <DIR>          .
# 09/09/2017  05:41 PM    <DIR>          ..
# 09/09/2017  11:50 AM    <DIR>          .ipynb_checkpoints
# 09/09/2017  05:38 PM           121,942 assignment-02.ipynb
# 09/09/2017  05:18 PM    <DIR>          data
# 09/09/2017  11:45 AM               842 README.md
#                2 File(s)        122,784 bytes
#                4 Dir(s)  317,672,869,888 bytes free

# %% [markdown]
# Ok, now that we know what the current working directory is, we must either change the working directory or move the file into the current working directory. I'll let you decide which you want to do, but this is how you change the working directory.

# %%
os.chdir('C:\\Users\\peter.casey\\Downloads') 
## There's this weird thing in Python where you have to use double slashes when specifying working directories.
## If you have trouble getting a file from a directory you know it's in, this is a common error.

#

# %% [markdown]
# Now you should be able to pull the data into your Jupyter Notebook. Try it again.

# %%
df = pd.read_csv("https://opendata.arcgis.com/datasets/0e4b7d3a83b94a178b3d1f015db901ee_7.csv")

# %%
mkdir data

# %%
df.to_csv('data/serv_16.csv') #more ipythonic to mkdir and save to data folder

# %% [markdown]
# We can also pull the .csv file directly from the Open Data Portal by using the link.

# %%
## I'm commenting this out because it takes a while to pull the data into the environment because it's a large file
#df = pd.read_csv('https://opendata.arcgis.com/datasets/0e4b7d3a83b94a178b3d1f015db901ee_7.csv')

# %% [markdown]
# Great! You have the data!
#
# One of the first things we'd like to know when we're dealing with a data set is its shape; that is the number of rows and columns it has.

# %%
df.shape
# Out:
# (302985, 30)

# %% [markdown]
# This data has 302,925 rows and 30 columns. Generally speaking, rows are our "observations" or "samples", while columns are our "variables" or "features".
#
# Now try getting JUST the number of rows.

# %%
df.shape[0]
# Out:
# 302985

# %% [markdown]
# When you have an item like this with multiple elements, you can often call the elements by their number. In Python, we always start counting elements with the number '0', so that the first element is always element '0'.
#
# ## Exercise 4
# Now try getting the number of columns yourself.

# %%
df.shape[1]
# Out:
# 30

# %% [markdown]
# The next thing we may want to do is actually LOOK at the data. But you probably don't want to print out all 300,000 rows of data in your notebook! (In reality, Pandas won't do that. Instead, it will show you a subset of the rows.)
#
# But to have greater control we can use the head command.

# %%
df.head()
# Out:
#            X          Y  OBJECTID SERVICECODE  \
# 0 -77.068472  38.959221    928367       EMNPV
# 1 -77.028858  38.903745    947826       S0276
# 2 -77.019418  38.941567    947827       S0361
# 3 -77.014655  38.906236    947828     PRUNING
# 4 -77.004008  38.835935    947829       S0031
#
#               SERVICECODEDESCRIPTION  \
# 0  Emergency No-Parking Verification
# 1               Parking Meter Repair
# 2                    Sidewalk Repair
# 3                       Tree Pruning
# 4                    Bulk Collection
#
#                           SERVICETYPECODEDESCRIPTION ORGANIZATIONACRONYM  \
# 0  PEMA- Parking Enforcement Management Administr...                 DPW
# 1           Transportation Operations Administration                DDOT
# 2                    Toa-Street & Bridge Maintenance                DDOT
# 3                                    Urban Forrestry                DDOT
# 4          SWMA- Solid Waste Management Admistration                 DPW
#
#    SERVICECALLCOUNT                   ADDDATE            RESOLUTIONDATE  \
# 0                 1  2016-01-04T16:45:21.000Z  2016-01-04T21:13:04.000Z
# 1                 1  2016-05-02T11:43:31.000Z  2016-05-03T01:38:10.000Z
# 2                 1  2016-05-02T11:47:49.000Z                       NaN
# 3                 1  2016-05-02T10:44:23.000Z  2017-01-19T11:03:08.000Z
# 4                 1  2016-05-02T11:49:49.000Z  2016-05-12T14:27:19.000Z
#
#                          ...                             XCOORD  \
# 0                        ...                          394065.60
# 1                        ...                          397497.09
# 2                        ...                          398316.79
# 3                        ...                          398729.12
# 4                        ...                          399652.25
#
#           YCOORD   LATITUDE  LONGITUDE        CITY STATE  ZIPCODE  \
# 0  143480.700000  38.959214 -77.068470  WASHINGTON    DC  20015.0
# 1  137320.600003  38.903738 -77.028856  WASHINGTON    DC  20005.0
# 2  141518.950000  38.941560 -77.019416  WASHINGTON    DC  20011.0
# 3  137596.790000  38.906229 -77.014652  WASHINGTON    DC  20001.0
# 4  129792.780000  38.835928 -77.004005  WASHINGTON    DC  20032.0
#
#   MARADDRESSREPOSITORYID WARD  \
# 0               262895.0  3.0
# 1               812754.0  2.0
# 2               247564.0  4.0
# 3               238344.0  6.0
# 4                66302.0  8.0
#
#                                              DETAILS
# 0                                                NaN
# 1                              Need More Information
# 2                                                NaN
# 3  By BANUA, SIMOUN: 5/2/2016 12:48:15 PM\nthis t...
# 4  w riggans collected bulk on 5/12/16*closed by ...
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Exercise 11
#
# The default head command shows us 5 rows. Try increasing the number of rows it shows us.

# %%
df.head(10)
# Out:
#            X          Y  OBJECTID SERVICECODE  \
# 0 -77.068472  38.959221    928367       EMNPV
# 1 -77.028858  38.903745    947826       S0276
# 2 -77.019418  38.941567    947827       S0361
# 3 -77.014655  38.906236    947828     PRUNING
# 4 -77.004008  38.835935    947829       S0031
# 5 -77.004008  38.835935    947830       S0031
# 6 -77.020134  38.914935    986620       S0261
# 7 -77.018788  38.915155    986621       S0441
# 8 -77.018788  38.915155    986622       S0441
# 9 -77.011544  38.915718    986623       S0441
#
#               SERVICECODEDESCRIPTION  \
# 0  Emergency No-Parking Verification
# 1               Parking Meter Repair
# 2                    Sidewalk Repair
# 3                       Tree Pruning
# 4                    Bulk Collection
# 5                    Bulk Collection
# 6                Parking Enforcement
# 7          Trash Collection - Missed
# 8          Trash Collection - Missed
# 9          Trash Collection - Missed
#
#                           SERVICETYPECODEDESCRIPTION ORGANIZATIONACRONYM  \
# 0  PEMA- Parking Enforcement Management Administr...                 DPW
# 1           Transportation Operations Administration                DDOT
# 2                    Toa-Street & Bridge Maintenance                DDOT
# 3                                    Urban Forrestry                DDOT
# 4          SWMA- Solid Waste Management Admistration                 DPW
# 5          SWMA- Solid Waste Management Admistration                 DPW
# 6  PEMA- Parking Enforcement Management Administr...                 DPW
# 7          SWMA- Solid Waste Management Admistration                 DPW
# 8          SWMA- Solid Waste Management Admistration                 DPW
# 9          SWMA- Solid Waste Management Admistration                 DPW
#
#    SERVICECALLCOUNT                   ADDDATE            RESOLUTIONDATE  \
# 0                 1  2016-01-04T16:45:21.000Z  2016-01-04T21:13:04.000Z
# 1                 1  2016-05-02T11:43:31.000Z  2016-05-03T01:38:10.000Z
# 2                 1  2016-05-02T11:47:49.000Z                       NaN
# 3                 1  2016-05-02T10:44:23.000Z  2017-01-19T11:03:08.000Z
# 4                 1  2016-05-02T11:49:49.000Z  2016-05-12T14:27:19.000Z
# 5                 1  2016-05-02T11:49:50.000Z  2016-05-12T14:26:24.000Z
# 6                 1  2016-03-16T08:10:25.000Z  2016-03-16T11:01:29.000Z
# 7                 1  2016-03-16T08:12:34.000Z  2016-03-18T11:20:03.000Z
# 8                 1  2016-03-16T08:12:35.000Z  2016-03-18T11:22:49.000Z
# 9                 1  2016-03-16T08:10:29.000Z  2016-03-25T08:13:57.000Z
#
#                          ...                             XCOORD  \
# 0                        ...                          394065.60
# 1                        ...                          397497.09
# 2                        ...                          398316.79
# 3                        ...                          398729.12
# 4                        ...                          399652.25
# 5                        ...                          399652.25
# 6                        ...                          398254.07
# 7                        ...                          398370.81
# 8                        ...                          398370.81
# 9                        ...                          398999.01
#
#           YCOORD   LATITUDE  LONGITUDE        CITY STATE  ZIPCODE  \
# 0  143480.700000  38.959214 -77.068470  WASHINGTON    DC  20015.0
# 1  137320.600003  38.903738 -77.028856  WASHINGTON    DC  20005.0
# 2  141518.950000  38.941560 -77.019416  WASHINGTON    DC  20011.0
# 3  137596.790000  38.906229 -77.014652  WASHINGTON    DC  20001.0
# 4  129792.780000  38.835928 -77.004005  WASHINGTON    DC  20032.0
# 5  129792.780000  38.835928 -77.004005  WASHINGTON    DC  20032.0
# 6  138562.500000  38.914927 -77.020132  WASHINGTON    DC  20001.0
# 7  138586.890000  38.915147 -77.018786  WASHINGTON    DC  20001.0
# 8  138586.890000  38.915147 -77.018786  WASHINGTON    DC  20001.0
# 9  138649.350000  38.915711 -77.011542  WASHINGTON    DC  20001.0
#
#   MARADDRESSREPOSITORYID WARD  \
# 0               262895.0  3.0
# 1               812754.0  2.0
# 2               247564.0  4.0
# 3               238344.0  6.0
# 4                66302.0  8.0
# 5                66302.0  8.0
# 6               238452.0  6.0
# 7               229894.0  1.0
# 8               229894.0  1.0
# 9               300722.0  5.0
#
#                                              DETAILS
# 0                                                NaN
# 1                              Need More Information
# 2                                                NaN
# 3  By BANUA, SIMOUN: 5/2/2016 12:48:15 PM\nthis t...
# 4  w riggans collected bulk on 5/12/16*closed by ...
# 5  w riggans collected bulk on 5/12/16*closed by ...
# 6                                                NaN
# 7    COMPLETED BY 3/17/16 D STREET CLOSED BY NDAVALL
# 8   COMPLETED  BY D STREET 3/17/16 CLOSED BY NDAVALL
# 9  COMPLETED  BY L FERGUSON 3/17/16 CLOSED BY NDA...
#
# [10 rows x 30 columns]

# %% [markdown]
# This is sort of any annoying way to look at the data, in my opinion. I'm usually interested in looking at the list of columns and the kinds of values they have, so I usually transpose the data when I print it as a head.

# %%
df.head().T
# Out:
#                                                                             0  \
# X                                                                    -77.0685
# Y                                                                     38.9592
# OBJECTID                                                               928367
# SERVICECODE                                                             EMNPV
# SERVICECODEDESCRIPTION                      Emergency No-Parking Verification
# SERVICETYPECODEDESCRIPTION  PEMA- Parking Enforcement Management Administr...
# ORGANIZATIONACRONYM                                                       DPW
# SERVICECALLCOUNT                                                            1
# ADDDATE                                              2016-01-04T16:45:21.000Z
# RESOLUTIONDATE                                       2016-01-04T21:13:04.000Z
# SERVICEDUEDATE                                       2016-01-05T16:45:00.000Z
# SERVICEORDERDATE                                     2016-01-04T16:45:21.000Z
# INSPECTIONFLAG                                                              N
# INSPECTIONDATE                                                            NaN
# INSPECTORNAME                                                             NaN
# SERVICEORDERSTATUS                                                     CLOSED
# STATUS_CODE                                                            CLOSED
# SERVICEREQUESTID                                                  16-00353175
# PRIORITY                                                             STANDARD
# STREETADDRESS                                          3611 JENIFER STREET NW
# XCOORD                                                                 394066
# YCOORD                                                                 143481
# LATITUDE                                                              38.9592
# LONGITUDE                                                            -77.0685
# CITY                                                               WASHINGTON
# STATE                                                                      DC
# ZIPCODE                                                                 20015
# MARADDRESSREPOSITORYID                                                 262895
# WARD                                                                        3
# DETAILS                                                                   NaN
#
#                                                                    1  \
# X                                                           -77.0289
# Y                                                            38.9037
# OBJECTID                                                      947826
# SERVICECODE                                                    S0276
# SERVICECODEDESCRIPTION                          Parking Meter Repair
# SERVICETYPECODEDESCRIPTION  Transportation Operations Administration
# ORGANIZATIONACRONYM                                             DDOT
# SERVICECALLCOUNT                                                   1
# ADDDATE                                     2016-05-02T11:43:31.000Z
# RESOLUTIONDATE                              2016-05-03T01:38:10.000Z
# SERVICEDUEDATE                              2016-05-09T11:43:00.000Z
# SERVICEORDERDATE                            2016-05-02T11:43:31.000Z
# INSPECTIONFLAG                                                     N
# INSPECTIONDATE                                                   NaN
# INSPECTORNAME                                                    NaN
# SERVICEORDERSTATUS                                            CLOSED
# STATUS_CODE                                                   CLOSED
# SERVICEREQUESTID                                         16-00485849
# PRIORITY                                                    STANDARD
# STREETADDRESS                       1200 - 1299 BLOCK OF L STREET NW
# XCOORD                                                        397497
# YCOORD                                                        137321
# LATITUDE                                                     38.9037
# LONGITUDE                                                   -77.0289
# CITY                                                      WASHINGTON
# STATE                                                             DC
# ZIPCODE                                                        20005
# MARADDRESSREPOSITORYID                                        812754
# WARD                                                               2
# DETAILS                                        Need More Information
#
#                                                           2  \
# X                                                  -77.0194
# Y                                                   38.9416
# OBJECTID                                             947827
# SERVICECODE                                           S0361
# SERVICECODEDESCRIPTION                      Sidewalk Repair
# SERVICETYPECODEDESCRIPTION  Toa-Street & Bridge Maintenance
# ORGANIZATIONACRONYM                                    DDOT
# SERVICECALLCOUNT                                          1
# ADDDATE                            2016-05-02T11:47:49.000Z
# RESOLUTIONDATE                                          NaN
# SERVICEDUEDATE                     2016-09-20T11:47:00.000Z
# SERVICEORDERDATE                   2016-05-02T11:47:49.000Z
# INSPECTIONFLAG                                            N
# INSPECTIONDATE                                          NaN
# INSPECTORNAME                                           NaN
# SERVICEORDERSTATUS                              IN-PROGRESS
# STATUS_CODE                                            OPEN
# SERVICEREQUESTID                                16-00485860
# PRIORITY                                           STANDARD
# STREETADDRESS                            4120 5TH STREET NW
# XCOORD                                               398317
# YCOORD                                               141519
# LATITUDE                                            38.9416
# LONGITUDE                                          -77.0194
# CITY                                             WASHINGTON
# STATE                                                    DC
# ZIPCODE                                               20011
# MARADDRESSREPOSITORYID                               247564
# WARD                                                      4
# DETAILS                                                 NaN
#
#                                                                             3  \
# X                                                                    -77.0147
# Y                                                                     38.9062
# OBJECTID                                                               947828
# SERVICECODE                                                           PRUNING
# SERVICECODEDESCRIPTION                                           Tree Pruning
# SERVICETYPECODEDESCRIPTION                                    Urban Forrestry
# ORGANIZATIONACRONYM                                                      DDOT
# SERVICECALLCOUNT                                                            1
# ADDDATE                                              2016-05-02T10:44:23.000Z
# RESOLUTIONDATE                                       2017-01-19T11:03:08.000Z
# SERVICEDUEDATE                                       2017-05-31T10:44:00.000Z
# SERVICEORDERDATE                                     2016-05-02T10:44:23.000Z
# INSPECTIONFLAG                                                              N
# INSPECTIONDATE                                                            NaN
# INSPECTORNAME                                                             NaN
# SERVICEORDERSTATUS                                                     CLOSED
# STATUS_CODE                                                            CLOSED
# SERVICEREQUESTID                                                  16-00485852
# PRIORITY                                                             STANDARD
# STREETADDRESS                                       1219 NEW JERSEY AVENUE NW
# XCOORD                                                                 398729
# YCOORD                                                                 137597
# LATITUDE                                                              38.9062
# LONGITUDE                                                            -77.0147
# CITY                                                               WASHINGTON
# STATE                                                                      DC
# ZIPCODE                                                                 20001
# MARADDRESSREPOSITORYID                                                 238344
# WARD                                                                        6
# DETAILS                     By BANUA, SIMOUN: 5/2/2016 12:48:15 PM\nthis t...
#
#                                                                             4
# X                                                                     -77.004
# Y                                                                     38.8359
# OBJECTID                                                               947829
# SERVICECODE                                                             S0031
# SERVICECODEDESCRIPTION                                        Bulk Collection
# SERVICETYPECODEDESCRIPTION          SWMA- Solid Waste Management Admistration
# ORGANIZATIONACRONYM                                                       DPW
# SERVICECALLCOUNT                                                            1
# ADDDATE                                              2016-05-02T11:49:49.000Z
# RESOLUTIONDATE                                       2016-05-12T14:27:19.000Z
# SERVICEDUEDATE                                       2016-05-20T11:49:00.000Z
# SERVICEORDERDATE                                     2016-05-02T11:49:49.000Z
# INSPECTIONFLAG                                                              N
# INSPECTIONDATE                                                            NaN
# INSPECTORNAME                                                             NaN
# SERVICEORDERSTATUS                                                     CLOSED
# STATUS_CODE                                                            CLOSED
# SERVICEREQUESTID                                                  16-00485867
# PRIORITY                                                             STANDARD
# STREETADDRESS                                         135 WILMINGTON PLACE SE
# XCOORD                                                                 399652
# YCOORD                                                                 129793
# LATITUDE                                                              38.8359
# LONGITUDE                                                             -77.004
# CITY                                                               WASHINGTON
# STATE                                                                      DC
# ZIPCODE                                                                 20032
# MARADDRESSREPOSITORYID                                                  66302
# WARD                                                                        8
# DETAILS                     w riggans collected bulk on 5/12/16*closed by ...

# %% [markdown]
# Now you can get a sense of what your data looks like. What do you think some of these columns mean?
#
# ## Exercise 12
#
# Think about some of the column names and values you have. What do you think these columns are?
#
# We probably want even more information about our variables or columns, so let's learn more about them.
#
# First, we can get a quick list of column names this way also.

# %%
df.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'SERVICECODE', 'SERVICECODEDESCRIPTION',
#        'SERVICETYPECODEDESCRIPTION', 'ORGANIZATIONACRONYM', 'SERVICECALLCOUNT',
#        'ADDDATE', 'RESOLUTIONDATE', 'SERVICEDUEDATE', 'SERVICEORDERDATE',
#        'INSPECTIONFLAG', 'INSPECTIONDATE', 'INSPECTORNAME',
#        'SERVICEORDERSTATUS', 'STATUS_CODE', 'SERVICEREQUESTID', 'PRIORITY',
#        'STREETADDRESS', 'XCOORD', 'YCOORD', 'LATITUDE', 'LONGITUDE', 'CITY',
#        'STATE', 'ZIPCODE', 'MARADDRESSREPOSITORYID', 'WARD', 'DETAILS'],
#       dtype='object')

# %% [markdown]
# The columns command provides us with a list of column names.
#
# We can also use this command to find out how many columns we have by taking its length.

# %%
len(df.columns)
# Out:
# 30

# %% [markdown]
# Note that this returns the same value as df.shape[1].
#
# We can also get column data types.

# %%
df.dtypes
# Out:
# X                             float64
# Y                             float64
# OBJECTID                        int64
# SERVICECODE                    object
# SERVICECODEDESCRIPTION         object
# SERVICETYPECODEDESCRIPTION     object
# ORGANIZATIONACRONYM            object
# SERVICECALLCOUNT                int64
# ADDDATE                        object
# RESOLUTIONDATE                 object
# SERVICEDUEDATE                 object
# SERVICEORDERDATE               object
# INSPECTIONFLAG                 object
# INSPECTIONDATE                 object
# INSPECTORNAME                 float64
# SERVICEORDERSTATUS             object
# STATUS_CODE                    object
# SERVICEREQUESTID               object
# PRIORITY                       object
# STREETADDRESS                  object
# XCOORD                        float64
# YCOORD                        float64
# LATITUDE                      float64
# LONGITUDE                     float64
# CITY                           object
# STATE                          object
# ZIPCODE                       float64
# MARADDRESSREPOSITORYID        float64
# WARD                          float64
# DETAILS                        object
# dtype: object

# %% [markdown]
# We see three data types here. What does each mean? Why aren't there any "date" types?

# %% [markdown]
# ## Exercise 13
#
# We'd like to know even more about our data.
#
# Use the describe function to learn more about your data. I like to transpose this, too. Try transposing it.
#
# Do you notice any columns missing from the output? Why do you think they're missing?
#
# You may notice some values are 'NaN'. What does that mean? How might we handle these values?

# %%
df.describe().T
#Because they are objects, I guess
# Out:
#                            count          mean            std            min  \
# X                       302985.0 -7.701344e+01       0.037492     -77.114209
# Y                       302985.0  3.891196e+01       0.031257      38.813455
# OBJECTID                302985.0  1.335995e+06  102371.072802  928367.000000
# SERVICECALLCOUNT        302985.0  1.000000e+00       0.000000       1.000000
# INSPECTORNAME                0.0           NaN            NaN            NaN
# XCOORD                  302985.0  3.988348e+05    3251.499740  390097.460000
# YCOORD                  302985.0  1.382333e+05    3470.000502  127297.420000
# LATITUDE                302985.0  3.891195e+01       0.031258      38.813448
# LONGITUDE               302985.0 -7.701344e+01       0.037491     -77.114206
# ZIPCODE                 302983.0  2.002962e+04     867.804543   -1865.000000
# MARADDRESSREPOSITORYID  294302.0  2.912035e+05  270115.221076       1.000000
# WARD                    300924.0  4.335025e+00       2.151176       1.000000
#
#                                  25%           50%           75%           max
# X                      -7.703655e+01 -7.701731e+01 -7.698978e+01 -7.690953e+01
# Y                       3.889461e+01  3.890972e+01  3.893308e+01  3.899544e+01
# OBJECTID                1.264323e+06  1.340839e+06  1.417109e+06  1.566462e+06
# SERVICECALLCOUNT        1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# INSPECTORNAME                    NaN           NaN           NaN           NaN
# XCOORD                  3.968295e+05  3.984992e+05  4.008872e+05  4.078484e+05
# YCOORD                  1.363069e+05  1.379835e+05  1.405768e+05  1.475002e+05
# LATITUDE                3.889460e+01  3.890968e+01  3.893306e+01  3.899544e+01
# LONGITUDE              -7.703655e+01 -7.701731e+01 -7.698977e+01 -7.690976e+01
# ZIPCODE                 2.000300e+04  2.001100e+04  2.001800e+04  7.073900e+04
# MARADDRESSREPOSITORYID  6.951100e+04  2.405765e+05  2.946100e+05  9.141190e+05
# WARD                    2.000000e+00  4.000000e+00  6.000000e+00  8.000000e+00

# %% [markdown]
# The describe function provides us a ton of great information about numeric variables, like integers and floats. But categorical variables, called "object" variables in Python, do not have means, mins, maxes, or standard deviations. So how might we analyze these?
#
# One of the first steps is to take a look at the unique values of these columns. Let's start with the most interesting one: Service Code Description.

# %%
df['SERVICECODEDESCRIPTION'].unique()
# Out:
# array(['Emergency No-Parking Verification', 'Parking Meter Repair',
#        'Sidewalk Repair', 'Tree Pruning', 'Bulk Collection',
#        'Parking Enforcement', 'Trash Collection - Missed',
#        'Sanitation Enforcement', 'Tree Inspection', 'Illegal Dumping',
#        'Rodent Inspection and Treatment', 'Yard Waste - Missed',
#        'Sidewalk Shoveling Enforcement Exemption',
#        'Dead Animal Collection', 'Emergency - Trees', 'Sign Replacement',
#        'Alley Cleaning', 'Abandoned Vehicle - On Private Property',
#        'DMV - Copy of Ticket', 'Streetlight Repair Investigation',
#        'Recycling Cart Delivery', 'Out of State Parking Violation (ROSA)',
#        'DMV - Vehicle Registration Issues',
#        'DMV - Drivers License/ID Issues', 'Pothole', 'Tree Planting',
#        'Leaf Season Collection', 'Residential Snow Removal (ServeDC)',
#        'Snow Removal Complaints for Sidewalks', 'Street Cleaning',
#        'Street Repair', 'Supercan - Repair', 'Alleylight Repair',
#        'Public Space Litter Can- Installation/Removal/Repair',
#        'Snow/Ice Removal', 'Residential Parking Permit Violation',
#        'Abandoned Vehicle - On Public Property',
#        'DC Government Information', 'Trash Cart - Delivery',
#        'Recycling Collection - Missed', 'Sign New Investigation',
#        'Wire Down/Power Outage', 'Vacant Lot', 'Bicycle Issues',
#        'How Is My Driving - Complaint', 'Signs Conflicting',
#        'Snow/Ice Removal (Roadways AND Bridge walkways ONLY)',
#        'DMV - Forms, Applications, and Manuals Request', 'Tree Removal',
#        'Christmas Tree Removal-Seasonal', 'Sign Removal investigation',
#        'TRU Report', 'DMV - Processing Center Manager',
#        'FEMS - Community Events', 'Traffic Signal Maintanence',
#        'Resident Parking Permit', 'Container Removal',
#        'Supercan - Delivery', 'Bus/Rail Issues',
#        'Homeless Services - Winter/Hypothermia Season',
#        'Sign Missing Investigation', 'Snow Metro Bus Shelter/Stop',
#        'Snow Ticket Reimbursement', 'DMV - Vehicle Title Issues',
#        'DOEE - Engine Idling Tips', 'Abandoned Bicycle',
#        'FEMS - Smoke Alarm Application', 'Traffic Calming',
#        'Graffiti Removal', 'Utility Repair Investigation', 'Snow Towing',
#        'Marking Installation', 'Public Space Litter Can-Collection',
#        'DMV - Driver Record Issues', 'DOEE - Nuisance Odor Complaints',
#        'Trash Cart Repair', 'DMV - Vehicle Insurance Lapse',
#        'Insect Treatment', 'Alley Repair',
#        'DMV - Online Processing Issues', 'Marking Removal',
#        'DMV - Ticket Payment Dispute', 'Recycling Cart - Repair',
#        'Illegal Poster', 'Curb and Gutter Repair', 'Marking Modification',
#        'DOEE - Ban on Foam Food Containers',
#        'DOEE - Construction – Erosion Runoff',
#        'DMV - eTIMS Ticket Alert Services Issues',
#        'How Is My Driving - Compliment', 'DMV - Refunds - Tickets',
#        'Marking Maintenance', 'DMV - Hearings',
#        'Traffic Safety Investigation', 'DOEE - Foam Ban Tips',
#        'Recycling- Information Request',
#        'DOEE - General Environmental Concerns',
#        'DMV - Adjudication Supervisor', 'Safe Routes to School',
#        'Roadway Repair', 'DMV - Driver and Vehicle Services Refund',
#        'DMV - Vehicle Inspection Issues',
#        'Curb and Gutter Repair Investigation', 'Light-Light Pole',
#        'DMV - Drivers License/ID Reinstatement',
#        'Emergency - Power Outage/Wires Down', 'Snow Other',
#        'DMV - Offset Tracking', 'Roadway Marking Maintenance',
#        '311Force Reported Issues', 'Alleylight Repair Investigation',
#        'Signed Street Sweeping Missed', 'Insects', 'Traffic Signal Issue',
#        'Grass and Weeds Mowing', 'OUC NYE Test',
#        'Roadway Striping / Markings', 'Child Safety Seat Program',
#        'School Crossing Guard', 'Streetcar',
#        'Light-Tunnel/Underpass Light Repair',
#        'General Environmental Concerns (DOEE)', 'Roadway Signs',
#        'DPW Correspondence Tracking', 'DMV - Appeal',
#        'Recycling - Commercial Only', 'Roadway Marking Modification',
#        'Utility Repair Issue', 'DOEE - Bag Law Tips',
#        'Light-Overhead Guide Sign Lighting Repair', 'Illegal Fireworks',
#        'Emergency - Heating and Cooling', 'Emergency - Senior Assistance',
#        'Emergency - Supplies', 'Report Invalid Address to GIS Dept',
#        'FEMS - Fire Safety Education', 'Recycling - School Program',
#        'School Transit Subsidy Program', 'Citation',
#        'Emergency - Flooding', 'Roadway Marking Removal',
#        'Bicycle Services', 'Ticket Ombudsman',
#        'School Crossing Guard Program', 'DDS - Serious Medication Error',
#        'SalesForce DC311 Application Request',
#        'Hypothermia Shelter Information'], dtype=object)

# %% [markdown]
# We just did two new things right here: we called a column by using its column name, and we called its unique values.
#
# There's another way to call columns from a Pandas DataFrame if you're feeling lazy and don't want to mess around with brackets.

# %%
df.SERVICECODEDESCRIPTION.unique()
# Out:
# array(['Emergency No-Parking Verification', 'Parking Meter Repair',
#        'Sidewalk Repair', 'Tree Pruning', 'Bulk Collection',
#        'Parking Enforcement', 'Trash Collection - Missed',
#        'Sanitation Enforcement', 'Tree Inspection', 'Illegal Dumping',
#        'Rodent Inspection and Treatment', 'Yard Waste - Missed',
#        'Sidewalk Shoveling Enforcement Exemption',
#        'Dead Animal Collection', 'Emergency - Trees', 'Sign Replacement',
#        'Alley Cleaning', 'Abandoned Vehicle - On Private Property',
#        'DMV - Copy of Ticket', 'Streetlight Repair Investigation',
#        'Recycling Cart Delivery', 'Out of State Parking Violation (ROSA)',
#        'DMV - Vehicle Registration Issues',
#        'DMV - Drivers License/ID Issues', 'Pothole', 'Tree Planting',
#        'Leaf Season Collection', 'Residential Snow Removal (ServeDC)',
#        'Snow Removal Complaints for Sidewalks', 'Street Cleaning',
#        'Street Repair', 'Supercan - Repair', 'Alleylight Repair',
#        'Public Space Litter Can- Installation/Removal/Repair',
#        'Snow/Ice Removal', 'Residential Parking Permit Violation',
#        'Abandoned Vehicle - On Public Property',
#        'DC Government Information', 'Trash Cart - Delivery',
#        'Recycling Collection - Missed', 'Sign New Investigation',
#        'Wire Down/Power Outage', 'Vacant Lot', 'Bicycle Issues',
#        'How Is My Driving - Complaint', 'Signs Conflicting',
#        'Snow/Ice Removal (Roadways AND Bridge walkways ONLY)',
#        'DMV - Forms, Applications, and Manuals Request', 'Tree Removal',
#        'Christmas Tree Removal-Seasonal', 'Sign Removal investigation',
#        'TRU Report', 'DMV - Processing Center Manager',
#        'FEMS - Community Events', 'Traffic Signal Maintanence',
#        'Resident Parking Permit', 'Container Removal',
#        'Supercan - Delivery', 'Bus/Rail Issues',
#        'Homeless Services - Winter/Hypothermia Season',
#        'Sign Missing Investigation', 'Snow Metro Bus Shelter/Stop',
#        'Snow Ticket Reimbursement', 'DMV - Vehicle Title Issues',
#        'DOEE - Engine Idling Tips', 'Abandoned Bicycle',
#        'FEMS - Smoke Alarm Application', 'Traffic Calming',
#        'Graffiti Removal', 'Utility Repair Investigation', 'Snow Towing',
#        'Marking Installation', 'Public Space Litter Can-Collection',
#        'DMV - Driver Record Issues', 'DOEE - Nuisance Odor Complaints',
#        'Trash Cart Repair', 'DMV - Vehicle Insurance Lapse',
#        'Insect Treatment', 'Alley Repair',
#        'DMV - Online Processing Issues', 'Marking Removal',
#        'DMV - Ticket Payment Dispute', 'Recycling Cart - Repair',
#        'Illegal Poster', 'Curb and Gutter Repair', 'Marking Modification',
#        'DOEE - Ban on Foam Food Containers',
#        'DOEE - Construction – Erosion Runoff',
#        'DMV - eTIMS Ticket Alert Services Issues',
#        'How Is My Driving - Compliment', 'DMV - Refunds - Tickets',
#        'Marking Maintenance', 'DMV - Hearings',
#        'Traffic Safety Investigation', 'DOEE - Foam Ban Tips',
#        'Recycling- Information Request',
#        'DOEE - General Environmental Concerns',
#        'DMV - Adjudication Supervisor', 'Safe Routes to School',
#        'Roadway Repair', 'DMV - Driver and Vehicle Services Refund',
#        'DMV - Vehicle Inspection Issues',
#        'Curb and Gutter Repair Investigation', 'Light-Light Pole',
#        'DMV - Drivers License/ID Reinstatement',
#        'Emergency - Power Outage/Wires Down', 'Snow Other',
#        'DMV - Offset Tracking', 'Roadway Marking Maintenance',
#        '311Force Reported Issues', 'Alleylight Repair Investigation',
#        'Signed Street Sweeping Missed', 'Insects', 'Traffic Signal Issue',
#        'Grass and Weeds Mowing', 'OUC NYE Test',
#        'Roadway Striping / Markings', 'Child Safety Seat Program',
#        'School Crossing Guard', 'Streetcar',
#        'Light-Tunnel/Underpass Light Repair',
#        'General Environmental Concerns (DOEE)', 'Roadway Signs',
#        'DPW Correspondence Tracking', 'DMV - Appeal',
#        'Recycling - Commercial Only', 'Roadway Marking Modification',
#        'Utility Repair Issue', 'DOEE - Bag Law Tips',
#        'Light-Overhead Guide Sign Lighting Repair', 'Illegal Fireworks',
#        'Emergency - Heating and Cooling', 'Emergency - Senior Assistance',
#        'Emergency - Supplies', 'Report Invalid Address to GIS Dept',
#        'FEMS - Fire Safety Education', 'Recycling - School Program',
#        'School Transit Subsidy Program', 'Citation',
#        'Emergency - Flooding', 'Roadway Marking Removal',
#        'Bicycle Services', 'Ticket Ombudsman',
#        'School Crossing Guard Program', 'DDS - Serious Medication Error',
#        'SalesForce DC311 Application Request',
#        'Hypothermia Shelter Information'], dtype=object)

# %% [markdown]
# ## Exercise 14
#
# We can figure out how many unique values we have by getting the length of this object. Try it.

# %%
len(Out[18])
# Out:
# 147

# %% [markdown]
# We can also get value counts for each unique value of a categorical variable using value_counts.

# %%
df.SERVICECODEDESCRIPTION.value_counts()
# Out:
# Bulk Collection                                         45405
# Parking Meter Repair                                    34077
# Parking Enforcement                                     33733
# Emergency No-Parking Verification                       12644
# Streetlight Repair Investigation                        12344
# Pothole                                                 11225
# Trash Collection - Missed                                8159
# Alley Cleaning                                           7285
# Residential Parking Permit Violation                     6680
# Sanitation Enforcement                                   6423
# Sidewalk Shoveling Enforcement Exemption                 5777
# Snow/Ice Removal                                         5648
# Illegal Dumping                                          5542
# Recycling Collection - Missed                            5431
# Sidewalk Repair                                          5403
# Street Cleaning                                          5386
# Residential Snow Removal (ServeDC)                       5336
# Graffiti Removal                                         4972
# Abandoned Vehicle - On Public Property                   4667
# Tree Pruning                                             4071
# DMV - Drivers License/ID Issues                          3993
# Tree Inspection                                          3867
# Rodent Inspection and Treatment                          3531
# Out of State Parking Violation (ROSA)                    2945
# Snow/Ice Removal (Roadways AND Bridge walkways ONLY)     2858
# Tree Planting                                            2673
# Dead Animal Collection                                   2654
# DMV - Vehicle Registration Issues                        2600
# TRU Report                                               2500
# Tree Removal                                             2404
#                                                         ...
# Light-Tunnel/Underpass Light Repair                        19
# OUC NYE Test                                               17
# Marking Removal                                            14
# Hypothermia Shelter Information                            11
# Child Safety Seat Program                                  10
# Streetcar                                                   7
# DOEE - Bag Law Tips                                         6
# Recycling - Commercial Only                                 5
# Snow Other                                                  5
# Roadway Marking Removal                                     4
# School Crossing Guard Program                               4
# Recycling - School Program                                  3
# Emergency - Senior Assistance                               3
# DPW Correspondence Tracking                                 2
# Report Invalid Address to GIS Dept                          2
# Emergency - Flooding                                        2
# Insects                                                     2
# Ticket Ombudsman                                            1
# SalesForce DC311 Application Request                        1
# DDS - Serious Medication Error                              1
# Illegal Fireworks                                           1
# Light-Overhead Guide Sign Lighting Repair                   1
# FEMS - Fire Safety Education                                1
# Emergency - Heating and Cooling                             1
# DOEE - Foam Ban Tips                                        1
# Light-Light Pole                                            1
# School Transit Subsidy Program                              1
# Emergency - Supplies                                        1
# Citation                                                    1
# General Environmental Concerns (DOEE)                       1
# Name: SERVICECODEDESCRIPTION, dtype: int64

# %% [markdown]
# ## Exercise 15
#
# What's the most common request? What does that request mean? Check out the District's online 311 portal at 311.dc.gov to learn more about the top service request.

# %% [markdown]
# https://311.dc.gov/

# %%
# %%html
# <ion-page class="show-page service-type-component">
#     <ion-header>
#       <ion-toolbar class="toolbar">
#     <div class="toolbar-background"></div>
#
#     <ion-buttons start="">
#         <button class="bar-button bar-button-default"><span class="button-inner">
#           <span primary="">Cancel</span>
#         </span><ion-button-effect></ion-button-effect></button>
#       </ion-buttons>
#     <ion-buttons end="">
#           <button class="bar-button bar-button-default"><span class="button-inner">
#             <span primary="">Submit</span>
#           </span><ion-button-effect></ion-button-effect></button>
#         </ion-buttons>
#     <div class="toolbar-content">
#
#
#         <ion-title><div class="toolbar-title">
#           Residential Bulk Collection
#         </div></ion-title>
#
#
#     </div>
#   </ion-toolbar>
#     </ion-header>
#
#     <ion-content padding=""><scroll-content style="margin-top: 56px;">
#       <ion-list>
#         <!--template bindings={}--><div class="service-type-description">
#           <div>
#             <p>Servicing Agency</p>
#             <h4>DPW</h4>
#           </div>
#           <div>
#             <p>Service Resolution Estimate</p>
#             <h4>14 Business days</h4>
#           </div>
#           <div>
#             <p>Please use this service request type to schedule pick up of up to 7 bulk items, such as household furniture, appliances, water heaters, mattresses, bed frames and tree limbs. Prohibited Items include hazardous materials, construction debris and tires. These items should be disposed of at the Ft. Totten Transfer Station which is located at 4900 John F. McCormack Road, N.E.</p>
#           </div>
#         </div>
#       </ion-list>
#     </scroll-content></ion-content>
#   </ion-page>
# Out:
# <ion-page class="show-page service-type-component">
#     <ion-header>
#       <ion-toolbar class="toolbar">
#     <div class="toolbar-background"></div>
#
#     <ion-buttons start="">
#         <button class="bar-button bar-button-default"><span class="button-inner">
#           <span primary="">Cancel</span>
#         </span><ion-button-effect></ion-button-effect></button>
#       </ion-buttons>
#     <ion-buttons end="">
#           <button class="bar-button bar-button-default"><span class="button-inner">
#             <span primary="">Submit</span>
#           </span><ion-button-effect></ion-button-effect></button>
#         </ion-buttons>
#     <div class="toolbar-content">
#
#
#         <ion-title><div class="toolbar-title">
#           Residential Bulk Collection
#         </div></ion-title>
#
#
#     </div>
#   </ion-toolbar>
#     </ion-header>
#
#     <ion-content padding=""><scroll-content style="margin-top: 56px;">
#       <ion-list>
#         <!--template bindings={}--><div class="service-type-description">
#           <div>
#             <p>Servicing Agency</p>
#             <h4>DPW</h4>
#           </div>
#           <div>
#             <p>Service Resolution Estimate</p>
#             <h4>14 Business days</h4>
#           </div>
#           <div>
#             <p>Please use this service request type to schedule pick up of up to 7 bulk items, such as household furniture, appliances, water heaters, mattresses, bed frames and tree limbs. Prohibited Items include hazardous materials, construction debris and tires. These items should be disposed of at the Ft. Totten Transfer Station which is located at 4900 John F. McCormack Road, N.E.</p>
#           </div>
#         </div>
#       </ion-list>
#     </scroll-content></ion-content>
#   </ion-page>

# %% [markdown]
# You can use the markdown hyperlink convention to link a website. You can embed HTML with the HTML cell magic --CDL

# %% [markdown]
# ## Exercise 16
# Take a look at the data using some of the techniques including shape, head, and describe.
#
# Recall that we saw that date variables are stored as object data types in Pandas Data Frames.
# However, we CAN turn them in to datetime types using Pandas's nifty datetime commands.
# Let's begin by converting the service order date into a new datetime column in our DataFrame called "request_date".

# %%
df['request_date'] = pd.to_datetime(df['SERVICEORDERDATE'])

# %% [markdown]
# With any datetime object, we can use dt to pull the particulare date time that we're interested in.
# Here we use the value_counts function to look at the data by month.

# %%
df.request_date.dt.month.value_counts() #This is cool, I never use this when I should.
# Out:
# 1     34542
# 8     29892
# 9     26935
# 6     26253
# 7     25881
# 5     24289
# 10    24236
# 3     23892
# 4     23725
# 2     21541
# 11    20990
# 12    20809
# Name: request_date, dtype: int64

# %% [markdown]
# Notice that January is the month in which the city received the most service requests. However, the other top months for service requests are all summer months, and our winter months (December, November, February) are those with the least service requests. Does January seem to be an anomaly? Let's look closer.
# The value_counts function returns to pieces of information: the values, which are the actual counts of rows or observations, and the index, which the values are grouped by. In this case, the index is the set of months and the values are the number of service requests each month. The value_counts function returns an output that is sorted by the values, but we can also sort by the index using the sort_index function.

# %%
df.request_date.dt.month.value_counts().sort_index()
# Out:
# 1     34542
# 2     21541
# 3     23892
# 4     23725
# 5     24289
# 6     26253
# 7     25881
# 8     29892
# 9     26935
# 10    24236
# 11    20990
# 12    20809
# Name: request_date, dtype: int64

# %% [markdown]
# It may be helpful to plot this output to help us visualize the number of service requests made throughout the year.

# %%
requests_per_month = df.request_date.dt.month.value_counts()
requests_per_month.sort_index().plot()

# %% [markdown]
# We can see that January does, indeed, look anomalous. After spiking in January, service requests are low throughout the winter months, increasing as we move into the warmer months and peaking in August, after which they dip down again as we return to winter.
# Let's take a look at what's happening in January. We can focus in on January by selecting the subset of our service requests that came in January.

# %%
jan_requests = df[df.request_date.dt.month==1]
print(jan_requests.request_date.min())
print(jan_requests.request_date.max())
# Out:
# 2016-01-01 00:30:30
# 2016-01-31 23:43:20

# %% [markdown]
# Here, we've fed Python a logical statement telling it to return values from df where the date-part month in the column 'request_date' is equal to 1 (or January).
# # Exercise 4
# To better understand how this works, try taking the command out of the square brackets and running it. What does it return?

# %%
df.request_date.dt.month==1
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13         True
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23         True
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 302955    False
# 302956    False
# 302957    False
# 302958    False
# 302959    False
# 302960    False
# 302961    False
# 302962    False
# 302963    False
# 302964    False
# 302965    False
# 302966    False
# 302967    False
# 302968    False
# 302969    False
# 302970    False
# 302971    False
# 302972    False
# 302973    False
# 302974    False
# 302975    False
# 302976    False
# 302977    False
# 302978    False
# 302979    False
# 302980    False
# 302981    False
# 302982    False
# 302983    False
# 302984    False
# Name: request_date, dtype: bool

# %% [markdown]
# This returns a string of True and False statements. The 'True' values are the ones the DataFrame keeps, and the 'False' ones, it discards.
# Now that we have the January data, let's look at what kinds of requests were being made in January.
#
# ## Exercise 17
#
# Get value counts for the service code description from the subsample of January service requests. What where the most common requests?
#
# The city received a TON of snow removal requests in January 2016, but received very few other requests. It seems that these requests for snow removal are driving the high number of requests in January.
# If you were living in the District in January 2016, you'll remember this was the month that Snowzilla hit the city. This was a record-breaking snowstorm that dumped feet of snow on the city from January 22nd to January 23rd.
# Let's take a look at the top request in January, Snow/Ice Removal.

# %%
jan_requests['SERVICECODEDESCRIPTION'].value_counts()
# Out:
# Snow/Ice Removal                                        5347
# Residential Snow Removal (ServeDC)                      5278
# Sidewalk Shoveling Enforcement Exemption                5266
# Snow/Ice Removal (Roadways AND Bridge walkways ONLY)    2768
# Bulk Collection                                         2352
# Parking Enforcement                                     2079
# Parking Meter Repair                                    1997
# Snow Removal Complaints for Sidewalks                   1030
# Streetlight Repair Investigation                         817
# Emergency No-Parking Verification                        558
# Pothole                                                  543
# Trash Collection - Missed                                444
# Sanitation Enforcement                                   372
# Residential Parking Permit Violation                     357
# Abandoned Vehicle - On Public Property                   324
# Alley Cleaning                                           309
# DMV - Drivers License/ID Issues                          290
# Illegal Dumping                                          269
# Recycling Collection - Missed                            239
# DMV - Vehicle Registration Issues                        238
# Street Cleaning                                          226
# Alleylight Repair                                        210
# Sidewalk Repair                                          207
# TRU Report                                               169
# Out of State Parking Violation (ROSA)                    167
# Dead Animal Collection                                   146
# Christmas Tree Removal-Seasonal                          133
# Sign Replacement                                         131
# Traffic Signal Maintanence                               127
# Street Repair                                            124
#                                                         ...
# DOEE - Construction – Erosion Runoff                       6
# DOEE - Engine Idling Tips                                  5
# DC Government Information                                  5
# Safe Routes to School                                      5
# DMV - Driver and Vehicle Services Refund                   4
# Snow Other                                                 4
# Marking Modification                                       4
# DMV - Vehicle Inspection Issues                            4
# DOEE - Ban on Foam Food Containers                         4
# Illegal Poster                                             4
# Recycling- Information Request                             3
# DMV - eTIMS Ticket Alert Services Issues                   2
# Signed Street Sweeping Missed                              2
# Emergency - Power Outage/Wires Down                        2
# Curb and Gutter Repair Investigation                       2
# Insect Treatment                                           2
# OUC NYE Test                                               1
# Light-Overhead Guide Sign Lighting Repair                  1
# Traffic Safety Investigation                               1
# Marking Removal                                            1
# DMV - Offset Tracking                                      1
# Roadway Striping / Markings                                1
# DMV - Adjudication Supervisor                              1
# Grass and Weeds Mowing                                     1
# School Crossing Guard                                      1
# Roadway Marking Maintenance                                1
# How Is My Driving - Compliment                             1
# Alleylight Repair Investigation                            1
# Light-Light Pole                                           1
# DOEE - Foam Ban Tips                                       1
# Name: SERVICECODEDESCRIPTION, dtype: int64

# %% [markdown]
# ## Exercise 18
#
# Get the subsample of service requests for Snow/Ice Removal. Get the number of requests for each day in January 2016, then plot those requests so we can look at them over the course of the month.

# %%
snow_df = jan_requests[jan_requests['SERVICECODEDESCRIPTION']== "Snow/Ice Removal"]

# %%
requests_per_day = snow_df.request_date.dt.day.value_counts()
requests_per_day.sort_index().plot()

# %% [markdown]
# We can see that almost all of the requests for snow and ice removal came in the days following Snowzilla.
# Now let's take a look at WHERE those requests were coming from. DC is organized into 8 wards. These wards are the largest political geographies in the District. Each ward has a representative on the District Council who is elected directly by the residents of that ward.

# %% [markdown]
# ## Exercise 19
#
# Get the number of requests for snow and ice removal from each of the wards in January 2016.

# %%
all_snow = df[df['SERVICECODEDESCRIPTION']== "Snow/Ice Removal"]
request_per_ward = all_snow.WARD.value_counts()
request_per_ward
# Out:
# 7.0    1193
# 5.0     881
# 8.0     874
# 4.0     835
# 3.0     688
# 6.0     442
# 1.0     419
# 2.0     279
# Name: WARD, dtype: int64

# %% [markdown]
# By far, the most requests for snow and ice removal came from Ward 7, while the fewest (almost a thousand fewer) came from Ward 2.
# Now let's take a look at response times. Ward 7 had the most requests, but is that an indication that the city was slower to plot roads in Ward 7 than it was in other wards?

# %% [markdown]
# ## Exercise 20
# Create a new date column from the resolution date column in our DataFrame of requests for snow and ice removal in January.

# %%
df['RESOLUTIONDATE']= pd.to_datetime(df['RESOLUTIONDATE'])
df['ADDDATE']= pd.to_datetime(df['ADDDATE'])

# %% [markdown]
# Because the resolution date comes AFTER the service request, the resolution date will always be 'greater' than the request date. We can get the amount of time took the city to respond to each service request by taking the difference between the resolution date and the request date.
#
# ## Exercise 21
#
# Subtract the request date from the resolution date and assign that to an object called "time_diff". Print time_diff.

# %%
time_diff = df['RESOLUTIONDATE']-df['ADDDATE']
time_diff
# Out:
# 0          0 days 04:27:43
# 1          0 days 13:54:39
# 2                      NaT
# 3        262 days 00:18:45
# 4         10 days 02:37:30
# 5         10 days 02:36:34
# 6          0 days 02:51:04
# 7          2 days 03:07:29
# 8          2 days 03:10:14
# 9          9 days 00:03:28
# 10         2 days 00:12:12
# 11                     NaT
# 12       149 days 00:39:26
# 13         0 days 01:22:42
# 14         0 days 11:58:39
# 15         0 days 10:01:25
# 16        16 days 05:00:36
# 17         7 days 05:44:36
# 18         9 days 00:07:17
# 19         0 days 21:42:16
# 20         0 days 04:05:57
# 21         9 days 17:49:17
# 22         0 days 04:02:51
# 23        38 days 01:41:44
# 24         1 days 04:07:38
# 25         0 days 00:01:56
# 26         8 days 02:38:48
# 27        10 days 05:41:41
# 28         0 days 02:48:46
# 29         0 days 00:00:00
#                 ...
# 302955                 NaT
# 302956                 NaT
# 302957                 NaT
# 302958                 NaT
# 302959   215 days 23:17:52
# 302960   211 days 18:09:18
# 302961    46 days 19:02:21
# 302962                 NaT
# 302963   175 days 03:13:28
# 302964   152 days 21:24:42
# 302965   359 days 00:56:56
# 302966   222 days 00:27:17
# 302967                 NaT
# 302968                 NaT
# 302969                 NaT
# 302970   246 days 02:33:18
# 302971   252 days 00:34:41
# 302972   134 days 03:34:06
# 302973                 NaT
# 302974   105 days 17:38:11
# 302975                 NaT
# 302976   173 days 09:24:27
# 302977   332 days 06:19:59
# 302978                 NaT
# 302979                 NaT
# 302980   102 days 14:17:36
# 302981                 NaT
# 302982                 NaT
# 302983                 NaT
# 302984    61 days 19:19:21
# dtype: timedelta64[ns]

# %% [markdown]
# Great! Now let's convert time_diff to the number of hours it took to respond using the astype function. This function can be used to change the data type of a column. The timedelta64 function lets us convert to the datetime part we're interested in.

# %%
df['response_time']= time_diff.astype('timedelta64[h]')

# %% [markdown]
# ## Exercise 22
# Create a new column in our DataFrame calls "response_time" that is the time difference between resolution date and request date in hours.

# %%
df['response_time']
# Out:
# 0            4.0
# 1           13.0
# 2            NaN
# 3         6288.0
# 4          242.0
# 5          242.0
# 6            2.0
# 7           51.0
# 8           51.0
# 9          216.0
# 10          48.0
# 11           NaN
# 12        3576.0
# 13           1.0
# 14          11.0
# 15          10.0
# 16         389.0
# 17         173.0
# 18         216.0
# 19          21.0
# 20           4.0
# 21         233.0
# 22           4.0
# 23         913.0
# 24          28.0
# 25           0.0
# 26         194.0
# 27         245.0
# 28           2.0
# 29           0.0
#            ...
# 302955       NaN
# 302956       NaN
# 302957       NaN
# 302958       NaN
# 302959    5183.0
# 302960    5082.0
# 302961    1123.0
# 302962       NaN
# 302963    4203.0
# 302964    3669.0
# 302965    8616.0
# 302966    5328.0
# 302967       NaN
# 302968       NaN
# 302969       NaN
# 302970    5906.0
# 302971    6048.0
# 302972    3219.0
# 302973       NaN
# 302974    2537.0
# 302975       NaN
# 302976    4161.0
# 302977    7974.0
# 302978       NaN
# 302979       NaN
# 302980    2462.0
# 302981       NaN
# 302982       NaN
# 302983       NaN
# 302984    1483.0
# Name: response_time, dtype: float64

# %% [markdown]
# Now that we have our response times, let's use the groupby function to get the average response time by ward.

# %%
df.groupby('WARD').response_time.mean()
# Out:
# WARD
# 1.0    353.708141
# 2.0    453.247920
# 3.0    416.287066
# 4.0    509.956321
# 5.0    508.200059
# 6.0    376.486354
# 7.0    545.118179
# 8.0    490.214803
# Name: response_time, dtype: float64

# %% [markdown]
# This looks a lot like the output from the value_counts function. In fact, value_counts is a type of groupby function that simply returns counts for each of the unique values in a column.
# The groupby function allows us to aggregate the data by the unique values of a column (or multiple columns) and return various statistics, including mean, median, minimum (min), maximum (max), counts, etc.
# Again, we have two parts to the output: the index, in this case the ward, and the values, in this case the average hours it to the city to respond to a request for snow and ice removal. The groupby function returns the values sorted by the index. However, we can sort the values by the value using the sort_values function.

# %% [markdown]
# ## Exercise 23
# Get the average response times by ward again and sort the values by the average response time in ascending order (from highest to lowest). Which ward had the longest response times? Which had the lowest?
#
# Now we know which wards made the mo

# %%
group = df.groupby('WARD').response_time.mean()
group.sort_values(ascending=False)
# Out:
# WARD
# 7.0    545.118179
# 4.0    509.956321
# 5.0    508.200059
# 8.0    490.214803
# 2.0    453.247920
# 3.0    416.287066
# 6.0    376.486354
# 1.0    353.708141
# Name: response_time, dtype: float64

# %% [markdown]
# Now we know which wards made the most requests for snow and ice removal following the historic snowstorm in January 2016. Why do you think some wards received faster service than others? Do you think you could build a model predicting which requests would receive the fastest response?

# %%
#Worth a try
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib
import sklearn as sm
# Out:
# Using matplotlib backend: Qt5Agg

# %%
df_09 = pd.read_csv('https://opendata.arcgis.com/datasets/7c9ac81c00c14f4ba8c96df107f45e9d_0.csv',
                   low_memory=False, parse_dates=[9])
df_10 = pd.read_csv('https://opendata.arcgis.com/datasets/ba150a4170bc484b8cc204be308fa70c_1.csv',
                   low_memory=False, parse_dates=[9])
df_11 = pd.read_csv('https://opendata.arcgis.com/datasets/310e9e84ad7f4af7a31e7115395d7b57_2.csv',
                   low_memory=False, parse_dates=[9])
df_12 = pd.read_csv('https://opendata.arcgis.com/datasets/65a81d0a91654b9692c08ca37809c3c3_3.csv',
                   low_memory=False, parse_dates=[9])
df_13 = pd.read_csv('https://opendata.arcgis.com/datasets/20dc3ba98d494e51bee18a42f8430824_4.csv',
                   low_memory=False, parse_dates=[9])
df_14 = pd.read_csv('https://opendata.arcgis.com/datasets/17cafb3ffab347409def7e85e14c56bd_5.csv',
                   low_memory=False, parse_dates=[9])
df_15 = pd.read_csv('https://opendata.arcgis.com/datasets/b93ec7fc97734265a2da7da341f1bba2_6.csv',
                   low_memory=False, parse_dates=[9])
df_16 = pd.read_csv('https://opendata.arcgis.com/datasets/0e4b7d3a83b94a178b3d1f015db901ee_7.csv',
                   low_memory=False, parse_dates=[9])
df_17 = pd.read_csv('https://opendata.arcgis.com/datasets/19905e2b0e1140ec9ce8437776feb595_8.csv',
                   low_memory=False, parse_dates=[9])

data = [df_09, df_10, df_11, df_12, df_13, df_14, df_15, df_16, df_17]

# %%
#I was annoyed at how many NaTs I was getting in my data, but I did the visualization
#and realized how little it really is.
nans= [(i.RESOLUTIONDATE.value_counts(dropna=False)[0]/i.shape[0],
        i.RESOLUTIONDATE.value_counts(dropna=False)[0], i.shape[0]) for i in data]
print(sum([i[1] for i in nans]))
nans
# Out:
# 144209
# [(0.0025905537308599713, 56, 21617),
#  (0.009834437086092716, 297, 30200),
#  (0.014785328404890531, 156, 10551),
#  (0.13422458251473476, 34980, 260608),
#  (0.065158775797073673, 15297, 234765),
#  (0.068667065671428884, 22143, 322469),
#  (0.078049473502619801, 23074, 295633),
#  (0.061788537386339257, 18721, 302985),
#  (0.13624853285029065, 29485, 216406)]

# %%
#Ok the easy part is done I guess. Time to get my timedeltas
big = pd.concat(data)
dx= big.shape[0]

# %%
big['ADDDATE'] = pd.to_datetime(big['ADDDATE'], errors='coerce')
big['ADDDATE'].value_counts(dropna=False);

# %%
big.dtypes;

# %%
big['DELTARES'] = big['RESOLUTIONDATE']-big['ADDDATE']
big['DELTARES'] = big['DELTARES'].astype('timedelta64[s]')
big = big.dropna(subset=['DELTARES'])

big.head()
# Out:
#            X          Y  OBJECTID SERVICECODE SERVICECODEDESCRIPTION  \
# 0 -77.036490  38.922740    599288       S0406          Street Repair
# 1 -77.005626  38.836069    605933       S0016           Alley Repair
# 2 -77.026395  38.934559    612172       S0361        Sidewalk Repair
# 3 -77.020725  38.920107    614299       S0361        Sidewalk Repair
# 4 -77.034179  38.947001    616895       S0361        Sidewalk Repair
#
#   SERVICETYPECODEDESCRIPTION ORGANIZATIONACRONYM  SERVICECALLCOUNT  \
# 0                      SIOD                 DDOT                 1
# 1                      SIOD                 DDOT                 1
# 2                      SIOD                 DDOT                 1
# 3                      SIOD                 DDOT                 1
# 4                      SIOD                 DDOT                 1
#
#               ADDDATE      RESOLUTIONDATE     ...              YCOORD  \
# 0 2009-12-06 06:50:42 2015-05-01 14:32:36     ...       139429.399999
# 1 2009-10-30 12:54:23 2015-05-01 14:28:07     ...       129807.610000
# 2 2009-12-21 12:03:10 2015-05-01 14:33:19     ...       140741.130000
# 3 2009-10-20 11:46:48 2015-05-01 14:27:07     ...       139136.719999
# 4 2009-12-04 09:37:47 2015-05-01 14:32:24     ...       142122.450000
#
#     LATITUDE  LONGITUDE        CITY STATE  ZIPCODE MARADDRESSREPOSITORYID  \
# 0  38.922732 -77.036488  WASHINGTON    DC  20009.0                    NaN
# 1  38.836061 -77.005624  WASHINGTON    DC  20032.0                30914.0
# 2  38.934551 -77.026392  WASHINGTON    DC  20010.0               230546.0
# 3  38.920100 -77.020723  WASHINGTON    DC  20059.0                    NaN
# 4  38.946993 -77.034177  WASHINGTON    DC  20011.0               255554.0
#
#   WARD                                            DETAILS     DELTARES
# 0    1  southbound lanes of traffic in intersection, m...  170408514.0
# 1    8                                                NaN  173583224.0
# 2    1                      Sidewalk needs to be repaired  169093809.0
# 3    1  on the corner there is hole just above the sto...  174451219.0
# 4    4  caller reports that the sidewalk has been upro...  170571277.0
#
# [5 rows x 31 columns]

# %%
def reduction_measure(big, dx):
    #Given a big dataset and the orignal len, return the difference and percent remaining.
    dy = big.shape[0]
    return [(dx-dy), (dy/dx)]
reduction_measure(big, dx)
#I managed to parse and compute 91.5% of the rows
# Out:
# [143713, 0.9152252727352094]

# %%
#Dropna in all the variables I want to load into the model
big.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'SERVICECODE', 'SERVICECODEDESCRIPTION',
#        'SERVICETYPECODEDESCRIPTION', 'ORGANIZATIONACRONYM', 'SERVICECALLCOUNT',
#        'ADDDATE', 'RESOLUTIONDATE', 'SERVICEDUEDATE', 'SERVICEORDERDATE',
#        'INSPECTIONFLAG', 'INSPECTIONDATE', 'INSPECTORNAME',
#        'SERVICEORDERSTATUS', 'STATUS_CODE', 'SERVICEREQUESTID', 'PRIORITY',
#        'STREETADDRESS', 'XCOORD', 'YCOORD', 'LATITUDE', 'LONGITUDE', 'CITY',
#        'STATE', 'ZIPCODE', 'MARADDRESSREPOSITORYID', 'WARD', 'DETAILS',
#        'DELTARES'],
#       dtype='object')

# %%
model_vars= ['X', 'Y', 'WARD', 'SERVICECODEDESCRIPTION', 'DELTARES', 'ADDDATE']

# %%
#Now that I look, it appears that there is are 6 latlong vars.
latlongs = ['XCOORD', 'YCOORD', 'LATITUDE', 'LONGITUDE', 'X', 'Y']
big[latlongs].head().T
# Out:
#                        0              1              2              3  \
# XCOORD     396835.910011  399511.740000  397711.740000  398202.899996
# YCOORD     139429.399999  129807.610000  140741.130000  139136.719999
# LATITUDE       38.922732      38.836061      38.934551      38.920100
# LONGITUDE     -77.036488     -77.005624     -77.026392     -77.020723
# X             -77.036490     -77.005626     -77.026395     -77.020725
# Y              38.922740      38.836069      38.934559      38.920107
#
#                        4
# XCOORD     397037.350000
# YCOORD     142122.450000
# LATITUDE       38.946993
# LONGITUDE     -77.034177
# X             -77.034179
# Y              38.947001

# %%
#X and Y COORD aren't for me, but a quick fillna on X/Y might help.
big.X.fillna(big['LONGITUDE'])
big.Y.fillna(big['LATITUDE'])
new_dx = big.shape[0]
for i in model_vars:
    bigna= big.dropna(subset=[i])
    print(reduction_measure(bigna, new_dx))
# Out:
# [0, 1.0]
# [0, 1.0]
# [23290, 0.9849889237722209]
# [0, 1.0]
# [0, 1.0]
# [0, 1.0]

# %% [markdown]
# Dropna on 'WARD' will cause my remaining dataset to shrink by 1.6%, but I know the District tracks ward. I'm going to elect to keep it.

# %%
for i in model_vars:
    big= big.dropna(subset=[i])

# %%
big = big[model_vars]

# %%
#I don't really care about service codes that occur only a few times in the dataset, do I?
counts = pd.DataFrame(big.SERVICECODEDESCRIPTION.value_counts())
counts.shape[0]
# Out:
# 302

# %%
#We can drop more than half the service codes without losing many observations.
hds = counts[counts['SERVICECODEDESCRIPTION'] > 150]
print("Remaining Code Descriptions:",hds.shape[0])
print("Dropped lines:", counts.SERVICECODEDESCRIPTION.sum()-hds.SERVICECODEDESCRIPTION.sum())
print("% lines remaining:", hds.SERVICECODEDESCRIPTION.sum()/counts.SERVICECODEDESCRIPTION.sum())
# Out:
# Remaining Code Descriptions: 145
# Dropped lines: 4083
# % lines remaining: 0.9973282834859389

# %%
heads = hds.index
heads.tolist();
#Now I can look at all the headers that remain...

# %%
#Looks like a bunch of these codes are not for actual services. Noisy data has to go.
print(len(heads))
heads = [i for i in heads if i[0:3]!="xxx"]
print(len(heads))
# Out:
# 145
# 135

# %%
heads;

# %%
big= big[big.SERVICECODEDESCRIPTION.isin(heads)]
# Out:
#                                      0                    1       \
# X                                  -77.0365             -77.0056
# Y                                   38.9227              38.8361
# WARD                                      1                    8
# SERVICECODEDESCRIPTION        Street Repair         Alley Repair
# DELTARES                        1.70409e+08          1.73583e+08
# ADDDATE                 2009-12-06 06:50:42  2009-10-30 12:54:23
#
#                                      2                    3       \
# X                                  -77.0264             -77.0207
# Y                                   38.9346              38.9201
# WARD                                      1                    1
# SERVICECODEDESCRIPTION      Sidewalk Repair      Sidewalk Repair
# DELTARES                        1.69094e+08          1.74451e+08
# ADDDATE                 2009-12-21 12:03:10  2009-10-20 11:46:48
#
#                                      4                    5       \
# X                                  -77.0342               -77.03
# Y                                    38.947              38.9692
# WARD                                      4                    4
# SERVICECODEDESCRIPTION      Sidewalk Repair      Sidewalk Repair
# DELTARES                        1.70571e+08          1.70121e+08
# ADDDATE                 2009-12-04 09:37:47  2009-12-09 14:50:04
#
#                                      6                    7       \
# X                                  -77.0834             -76.9955
# Y                                   38.9105              38.9537
# WARD                                      3                    5
# SERVICECODEDESCRIPTION      Sidewalk Repair      Sidewalk Repair
# DELTARES                        1.74679e+08          1.72707e+08
# ADDDATE                 2009-10-17 20:31:44  2009-11-09 16:16:25
#
#                                      8                    9       \
# X                                   -76.978             -76.9866
# Y                                   38.9039              38.8966
# WARD                                      5                    6
# SERVICECODEDESCRIPTION         Tree Removal         Alley Repair
# DELTARES                        7.56208e+07          1.74779e+08
# ADDDATE                 2009-09-16 10:56:42  2009-10-16 16:35:57
#
#                                ...                        216331  \
# X                              ...                      -77.0174
# Y                              ...                       38.9063
# WARD                           ...                             6
# SERVICECODEDESCRIPTION         ...           Parking Enforcement
# DELTARES                       ...                          5085
# ADDDATE                        ...           2017-09-11 07:55:22
#
#                                      216335               216336  \
# X                                  -77.0075             -76.9824
# Y                                   38.9113              38.8626
# WARD                                      5                    8
# SERVICECODEDESCRIPTION       Alley Cleaning           TRU Report
# DELTARES                               1277                  877
# ADDDATE                 2017-09-11 07:57:04  2017-09-11 08:07:54
#
#                                      216338               216340  \
# X                                  -77.0082             -77.0297
# Y                                     38.83              38.9615
# WARD                                      8                    4
# SERVICECODEDESCRIPTION  Parking Enforcement  Parking Enforcement
# DELTARES                               4409                 1167
# ADDDATE                 2017-09-11 08:05:52  2017-09-11 08:09:48
#
#                                      216343               216354  \
# X                                  -77.0892             -77.0599
# Y                                   38.9115              38.9045
# WARD                                      3                    2
# SERVICECODEDESCRIPTION  Parking Enforcement  Parking Enforcement
# DELTARES                               2287                 2354
# ADDDATE                 2017-09-11 08:14:43  2017-09-11 08:15:10
#
#                                      216360               216362  \
# X                                  -77.0338             -77.0252
# Y                                   38.9314              38.9726
# WARD                                      1                    4
# SERVICECODEDESCRIPTION  Parking Enforcement      Street Cleaning
# DELTARES                               3308                 1181
# ADDDATE                 2017-09-11 08:22:18  2017-09-11 08:18:44
#
#                                      216369
# X                                  -77.0097
# Y                                   38.9693
# WARD                                      4
# SERVICECODEDESCRIPTION       Alley Cleaning
# DELTARES                                890
# ADDDATE                 2017-09-11 08:33:23
#
# [6 rows x 1517436 columns]

# %%
big.dtypes
# Out:
# X                                float64
# Y                                float64
# WARD                              object
# SERVICECODEDESCRIPTION            object
# DELTARES                         float64
# ADDDATE                   datetime64[ns]
# dtype: object

# %% [markdown]
# Well I've got my dataframe as set up as it's likely to ever be. Now what do I think will best answer the original question? "Do you think you could build a model predicting which requests would receive the fastest response?"
#
# Well if I build a reasonably effective model then my coefficients will tell me something like "on average requests from WARD X get a X hour different response time compared to other WARD." Right?
#
# And we want a model that tries to predict the future right? So I should start feeding in more data, then create a train/test split with the test data all in the future right?

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar

# %%
#Now that I have that...let's get a dummy var to flag every day on or adjacent to a holiday
#Some of this is snipped from the Python Datascience Handbook, Jake VanderPlas
USFederalHolidayCalendar()
cal = USFederalHolidayCalendar()
holidays = cal.holidays('2009', '2017')

# %%
holidays= pd.to_datetime(holidays)
holidays= pd.Series(holidays)
holidays.dt.date;

# %%
big['HOLIDAY']= 0
big['HOLIDAY'][big['ADDDATE'].dt.date.isin(holidays.dt.date.add(pd.Timedelta(1, 'D')))]= 1
big['HOLIDAY'][big['ADDDATE'].dt.date.isin(holidays.dt.date.subtract(pd.Timedelta(1, 'D')))]= 1
big['HOLIDAY'][big['ADDDATE'].dt.date.isin(holidays.dt.date)]= 1
big.HOLIDAY.value_counts()
# Out:
# C:\Users\CDL\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\CDL\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\CDL\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#NOAA has some summary weather data at Reagan
noaa_df = pd.read_csv('data/clim_data.csv')

# %%
#Let's see what we got
noaa_df.T
# Out:
#                                                       0     \
# STATION                                        USW00013743
# NAME             WASHINGTON REAGAN NATIONAL AIRPORT, VA US
# DATE                                            2008-12-31
# AWND                                                 16.11
# AWND_ATTRIBUTES                                        ,,W
# FMTM                                                  1924
# FMTM_ATTRIBUTES                                        ,,X
# PGTM                                                  1237
# PGTM_ATTRIBUTES                                        ,,W
# PRCP                                                     0
# PRCP_ATTRIBUTES                                  T,,0,2400
# SNOW                                                     0
# SNOW_ATTRIBUTES                                      T,,0,
# SNWD                                                     0
# SNWD_ATTRIBUTES                                       ,,0,
# TAVG                                                   NaN
# TAVG_ATTRIBUTES                                        NaN
# TMAX                                                    47
# TMAX_ATTRIBUTES                                        ,,0
# TMIN                                                    25
# TMIN_ATTRIBUTES                                        ,,0
# WDF2                                                   330
# WDF2_ATTRIBUTES                                        ,,X
# WDF5                                                   320
# WDF5_ATTRIBUTES                                        ,,X
# WESD                                                     0
# WESD_ATTRIBUTES                                        ,,0
# WSF2                                                  38.9
# WSF2_ATTRIBUTES                                        ,,X
# WSF5                                                    55
# ...                                                    ...
# WT04                                                   NaN
# WT04_ATTRIBUTES                                        NaN
# WT05                                                   NaN
# WT05_ATTRIBUTES                                        NaN
# WT06                                                   NaN
# WT06_ATTRIBUTES                                        NaN
# WT07                                                   NaN
# WT07_ATTRIBUTES                                        NaN
# WT08                                                   NaN
# WT08_ATTRIBUTES                                        NaN
# WT09                                                   NaN
# WT09_ATTRIBUTES                                        NaN
# WT11                                                   NaN
# WT11_ATTRIBUTES                                        NaN
# WT13                                                   NaN
# WT13_ATTRIBUTES                                        NaN
# WT14                                                   NaN
# WT14_ATTRIBUTES                                        NaN
# WT15                                                   NaN
# WT15_ATTRIBUTES                                        NaN
# WT16                                                     1
# WT16_ATTRIBUTES                                        ,,X
# WT17                                                   NaN
# WT17_ATTRIBUTES                                        NaN
# WT18                                                     1
# WT18_ATTRIBUTES                                        ,,X
# WT21                                                   NaN
# WT21_ATTRIBUTES                                        NaN
# WT22                                                   NaN
# WT22_ATTRIBUTES                                        NaN
#
#                                                       1     \
# STATION                                        USW00013743
# NAME             WASHINGTON REAGAN NATIONAL AIRPORT, VA US
# DATE                                            2009-01-01
# AWND                                                  9.62
# AWND_ATTRIBUTES                                        ,,W
# FMTM                                                   254
# FMTM_ATTRIBUTES                                        ,,X
# PGTM                                                   113
# PGTM_ATTRIBUTES                                        ,,W
# PRCP                                                     0
# PRCP_ATTRIBUTES                                   ,,0,2400
# SNOW                                                     0
# SNOW_ATTRIBUTES                                       ,,0,
# SNWD                                                     0
# SNWD_ATTRIBUTES                                       ,,0,
# TAVG                                                   NaN
# TAVG_ATTRIBUTES                                        NaN
# TMAX                                                    34
# TMAX_ATTRIBUTES                                        ,,0
# TMIN                                                    23
# TMIN_ATTRIBUTES                                        ,,0
# WDF2                                                   300
# WDF2_ATTRIBUTES                                        ,,X
# WDF5                                                   330
# WDF5_ATTRIBUTES                                        ,,X
# WESD                                                     0
# WESD_ATTRIBUTES                                        ,,0
# WSF2                                                  19.9
# WSF2_ATTRIBUTES                                        ,,X
# WSF5                                                  31.1
# ...                                                    ...
# WT04                                                   NaN
# WT04_ATTRIBUTES                                        NaN
# WT05                                                   NaN
# WT05_ATTRIBUTES                                        NaN
# WT06                                                   NaN
# WT06_ATTRIBUTES                                        NaN
# WT07                                                   NaN
# WT07_ATTRIBUTES                                        NaN
# WT08                                                   NaN
# WT08_ATTRIBUTES                                        NaN
# WT09                                                   NaN
# WT09_ATTRIBUTES                                        NaN
# WT11                                                   NaN
# WT11_ATTRIBUTES                                        NaN
# WT13                                                   NaN
# WT13_ATTRIBUTES                                        NaN
# WT14                                                   NaN
# WT14_ATTRIBUTES                                        NaN
# WT15                                                   NaN
# WT15_ATTRIBUTES                                        NaN
# WT16                                                   NaN
# WT16_ATTRIBUTES                                        NaN
# WT17                                                   NaN
# WT17_ATTRIBUTES                                        NaN
# WT18                                                   NaN
# WT18_ATTRIBUTES                                        NaN
# WT21                                                   NaN
# WT21_ATTRIBUTES                                        NaN
# WT22                                                   NaN
# WT22_ATTRIBUTES                                        NaN
#
#                                                       2     \
# STATION                                        USW00013743
# NAME             WASHINGTON REAGAN NATIONAL AIRPORT, VA US
# DATE                                            2009-01-02
# AWND                                                 10.51
# AWND_ATTRIBUTES                                        ,,W
# FMTM                                                   155
# FMTM_ATTRIBUTES                                        ,,X
# PGTM                                                   539
# PGTM_ATTRIBUTES                                        ,,W
# PRCP                                                     0
# PRCP_ATTRIBUTES                                   ,,0,2400
# SNOW                                                     0
# SNOW_ATTRIBUTES                                       ,,0,
# SNWD                                                     0
# SNWD_ATTRIBUTES                                       ,,0,
# TAVG                                                   NaN
# TAVG_ATTRIBUTES                                        NaN
# TMAX                                                    43
# TMAX_ATTRIBUTES                                        ,,0
# TMIN                                                    30
# TMIN_ATTRIBUTES                                        ,,0
# WDF2                                                   190
# WDF2_ATTRIBUTES                                        ,,X
# WDF5                                                   200
# WDF5_ATTRIBUTES                                        ,,X
# WESD                                                     0
# WESD_ATTRIBUTES                                        ,,0
# WSF2                                                  17.9
# WSF2_ATTRIBUTES                                        ,,X
# WSF5                                                  23.9
# ...                                                    ...
# WT04                                                   NaN
# WT04_ATTRIBUTES                                        NaN
# WT05                                                   NaN
# WT05_ATTRIBUTES                                        NaN
# WT06                                                   NaN
# WT06_ATTRIBUTES                                        NaN
# WT07                                                   NaN
# WT07_ATTRIBUTES                                        NaN
# WT08                                                   NaN
# WT08_ATTRIBUTES                                        NaN
# WT09                                                   NaN
# WT09_ATTRIBUTES                                        NaN
# WT11                                                   NaN
# WT11_ATTRIBUTES                                        NaN
# WT13                                                   NaN
# WT13_ATTRIBUTES                                        NaN
# WT14                                                   NaN
# WT14_ATTRIBUTES                                        NaN
# WT15                                                   NaN
# WT15_ATTRIBUTES                                        NaN
# WT16                                                   NaN
# WT16_ATTRIBUTES                                        NaN
# WT17                                                   NaN
# WT17_ATTRIBUTES                                        NaN
# WT18                                                   NaN
# WT18_ATTRIBUTES                                        NaN
# WT21                                                   NaN
# WT21_ATTRIBUTES                                        NaN
# WT22                                                   NaN
# WT22_ATTRIBUTES                                        NaN
#
#                                                       3     \
# STATION                                        USW00013743
# NAME             WASHINGTON REAGAN NATIONAL AIRPORT, VA US
# DATE                                            2009-01-03
# AWND                                                  7.16
# AWND_ATTRIBUTES                                        ,,W
# FMTM                                                   504
# FMTM_ATTRIBUTES                                        ,,X
# PGTM                                                   504
# PGTM_ATTRIBUTES                                        ,,W
# PRCP                                                     0
# PRCP_ATTRIBUTES                                   ,,0,2400
# SNOW                                                     0
# SNOW_ATTRIBUTES                                       ,,0,
# SNWD                                                     0
# SNWD_ATTRIBUTES                                       ,,0,
# TAVG                                                   NaN
# TAVG_ATTRIBUTES                                        NaN
# TMAX                                                    47
# TMAX_ATTRIBUTES                                        ,,0
# TMIN                                                    31
# TMIN_ATTRIBUTES                                        ,,0
# WDF2                                                   350
# WDF2_ATTRIBUTES                                        ,,X
# WDF5                                                   350
# WDF5_ATTRIBUTES                                        ,,X
# WESD                                                     0
# WESD_ATTRIBUTES                                        ,,0
# WSF2                                                  16.1
# WSF2_ATTRIBUTES                                        ,,X
# WSF5                                                    21
# ...                                                    ...
# WT04                                                   NaN
# WT04_ATTRIBUTES                                        NaN
# WT05                                                   NaN
# WT05_ATTRIBUTES                                        NaN
# WT06                                                   NaN
# WT06_ATTRIBUTES                                        NaN
# WT07                                                   NaN
# WT07_ATTRIBUTES                                        NaN
# WT08                                                   NaN
# WT08_ATTRIBUTES                                        NaN
# WT09                                                   NaN
# WT09_ATTRIBUTES                                        NaN
# WT11                                                   NaN
# WT11_ATTRIBUTES                                        NaN
# WT13                                                   NaN
# WT13_ATTRIBUTES                                        NaN
# WT14                                                   NaN
# WT14_ATTRIBUTES                                        NaN
# WT15                                                   NaN
# WT15_ATTRIBUTES                                        NaN
# WT16                                                   NaN
# WT16_ATTRIBUTES                                        NaN
# WT17                                                   NaN
# WT17_ATTRIBUTES                                        NaN
# WT18                                                   NaN
# WT18_ATTRIBUTES                                        NaN
# WT21                                                   NaN
# WT21_ATTRIBUTES                                        NaN
# WT22                                                   NaN
# WT22_ATTRIBUTES                                        NaN
#
#                                                       4     \
# STATION                                        USW00013743
# NAME             WASHINGTON REAGAN NATIONAL AIRPORT, VA US
# DATE                                            2009-01-04
# AWND                                                   3.8
# AWND_ATTRIBUTES                                        ,,W
# FMTM                                                  1242
# FMTM_ATTRIBUTES                                        ,,X
# PGTM                                                  1540
# PGTM_ATTRIBUTES                                        ,,W
# PRCP                                                     0
# PRCP_ATTRIBUTES                                   ,,0,2400
# SNOW                                                     0
# SNOW_ATTRIBUTES                                       ,,0,
# SNWD                                                     0
# SNWD_ATTRIBUTES                                       ,,0,
# TAVG                                                   NaN
# TAVG_ATTRIBUTES                                        NaN
# TMAX                                                    45
# TMAX_ATTRIBUTES                                        ,,0
# TMIN                                                    27
# TMIN_ATTRIBUTES                                        ,,0
# WDF2                                                   160
# WDF2_ATTRIBUTES                                        ,,X
# WDF5                                                   200
# WDF5_ATTRIBUTES                                        ,,X
# WESD                                                     0
# WESD_ATTRIBUTES                                        ,,0
# WSF2                                                  10.1
# WSF2_ATTRIBUTES                                        ,,X
# WSF5                                                  12.1
# ...                                                    ...
# WT04                                                   NaN
# WT04_ATTRIBUTES                                        NaN
# WT05                                                   NaN
# WT05_ATTRIBUTES                                        NaN
# WT06                                                   NaN
# WT06_ATTRIBUTES                                        NaN
# WT07                                                   NaN
# WT07_ATTRIBUTES                                        NaN
# WT08                                                   NaN
# WT08_ATTRIBUTES                                        NaN
# WT09                                                   NaN
# WT09_ATTRIBUTES                                        NaN
# WT11                                                   NaN
# WT11_ATTRIBUTES                                        NaN
# WT13                                                   NaN
# WT13_ATTRIBUTES                                        NaN
# WT14                                                   NaN
# WT14_ATTRIBUTES                                        NaN
# WT15                                                   NaN
# WT15_ATTRIBUTES                                        NaN
# WT16                                                   NaN
# WT16_ATTRIBUTES                                        NaN
# WT17                                                   NaN
# WT17_ATTRIBUTES                                        NaN
# WT18                                                   NaN
# WT18_ATTRIBUTES                                        NaN
# WT21                                                   NaN
# WT21_ATTRIBUTES                                        NaN
# WT22                                                   NaN
# WT22_ATTRIBUTES                                        NaN
#
#                                                       5     \
# STATION                                        USW00013743
# NAME             WASHINGTON REAGAN NATIONAL AIRPORT, VA US
# DATE                                            2009-01-05
# AWND                                                  6.93
# AWND_ATTRIBUTES                                        ,,W
# FMTM                                                  1234
# FMTM_ATTRIBUTES                                        ,,X
# PGTM                                                  1234
# PGTM_ATTRIBUTES                                        ,,W
# PRCP                                                     0
# PRCP_ATTRIBUTES                                  T,,0,2400
# SNOW                                                     0
# SNOW_ATTRIBUTES                                       ,,0,
# SNWD                                                     0
# SNWD_ATTRIBUTES                                       ,,0,
# TAVG                                                   NaN
# TAVG_ATTRIBUTES                                        NaN
# TMAX                                                    51
# TMAX_ATTRIBUTES                                        ,,0
# TMIN                                                    37
# TMIN_ATTRIBUTES                                        ,,0
# WDF2                                                   330
# WDF2_ATTRIBUTES                                        ,,X
# WDF5                                                   330
# WDF5_ATTRIBUTES                                        ,,X
# WESD                                                     0
# WESD_ATTRIBUTES                                        ,,0
# WSF2                                                  17.9
# WSF2_ATTRIBUTES                                        ,,X
# WSF5                                                  21.9
# ...                                                    ...
# WT04                                                   NaN
# WT04_ATTRIBUTES                                        NaN
# WT05                                                     1
# WT05_ATTRIBUTES                                        ,,0
# WT06                                                   NaN
# WT06_ATTRIBUTES                                        NaN
# WT07                                                   NaN
# WT07_ATTRIBUTES                                        NaN
# WT08                                                   NaN
# WT08_ATTRIBUTES                                        NaN
# WT09                                                   NaN
# WT09_ATTRIBUTES                                        NaN
# WT11                                                   NaN
# WT11_ATTRIBUTES                                        NaN
# WT13                                                   NaN
# WT13_ATTRIBUTES                                        NaN
# WT14                                                   NaN
# WT14_ATTRIBUTES                                        NaN
# WT15                                                   NaN
# WT15_ATTRIBUTES                                        NaN
# WT16                                                     1
# WT16_ATTRIBUTES                                        ,,X
# WT17                                                   NaN
# WT17_ATTRIBUTES                                        NaN
# WT18                                                   NaN
# WT18_ATTRIBUTES                                        NaN
# WT21                                                   NaN
# WT21_ATTRIBUTES                                        NaN
# WT22                                                   NaN
# WT22_ATTRIBUTES                                        NaN
#
#                                                       6     \
# STATION                                        USW00013743
# NAME             WASHINGTON REAGAN NATIONAL AIRPORT, VA US
# DATE                                            2009-01-06
# AWND                                                  7.61
# AWND_ATTRIBUTES                                        ,,W
# FMTM                                                  1719
# FMTM_ATTRIBUTES                                        ,,X
# PGTM                                                  1718
# PGTM_ATTRIBUTES                                        ,,W
# PRCP                                                  0.52
# PRCP_ATTRIBUTES                                   ,,0,2400
# SNOW                                                     0
# SNOW_ATTRIBUTES                                      T,,0,
# SNWD                                                     0
# SNWD_ATTRIBUTES                                       ,,0,
# TAVG                                                   NaN
# TAVG_ATTRIBUTES                                        NaN
# TMAX                                                    41
# TMAX_ATTRIBUTES                                        ,,0
# TMIN                                                    32
# TMIN_ATTRIBUTES                                        ,,0
# WDF2                                                    70
# WDF2_ATTRIBUTES                                        ,,X
# WDF5                                                    70
# WDF5_ATTRIBUTES                                        ,,X
# WESD                                                     0
# WESD_ATTRIBUTES                                        ,,0
# WSF2                                                    13
# WSF2_ATTRIBUTES                                        ,,X
# WSF5                                                    15
# ...                                                    ...
# WT04                                                     1
# WT04_ATTRIBUTES                                        ,,X
# WT05                                                     1
# WT05_ATTRIBUTES                                        ,,0
# WT06                                                   NaN
# WT06_ATTRIBUTES                                        NaN
# WT07                                                   NaN
# WT07_ATTRIBUTES                                        NaN
# WT08                                                   NaN
# WT08_ATTRIBUTES                                        NaN
# WT09                                                   NaN
# WT09_ATTRIBUTES                                        NaN
# WT11                                                   NaN
# WT11_ATTRIBUTES                                        NaN
# WT13                                                     1
# WT13_ATTRIBUTES                                        ,,X
# WT14                                                     1
# WT14_ATTRIBUTES                                        ,,X
# WT15                                                   NaN
# WT15_ATTRIBUTES                                        NaN
# WT16                                                     1
# WT16_ATTRIBUTES                                        ,,X
# WT17                                                   NaN
# WT17_ATTRIBUTES                                        NaN
# WT18                                                   NaN
# WT18_ATTRIBUTES                                        NaN
# WT21                                                   NaN
# WT21_ATTRIBUTES                                        NaN
# WT22                                                   NaN
# WT22_ATTRIBUTES                                        NaN
#
#                                                       7     \
# STATION                                        USW00013743
# NAME             WASHINGTON REAGAN NATIONAL AIRPORT, VA US
# DATE                                            2009-01-07
# AWND                                                  4.25
# AWND_ATTRIBUTES                                        ,,W
# FMTM                                                  1351
# FMTM_ATTRIBUTES                                        ,,X
# PGTM                                                  1350
# PGTM_ATTRIBUTES                                        ,,W
# PRCP                                                  1.26
# PRCP_ATTRIBUTES                                   ,,0,2400
# SNOW                                                     0
# SNOW_ATTRIBUTES                                       ,,0,
# SNWD                                                     0
# SNWD_ATTRIBUTES                                       ,,0,
# TAVG                                                   NaN
# TAVG_ATTRIBUTES                                        NaN
# TMAX                                                    42
# TMAX_ATTRIBUTES                                        ,,0
# TMIN                                                    33
# TMIN_ATTRIBUTES                                        ,,0
# WDF2                                                   330
# WDF2_ATTRIBUTES                                        ,,X
# WDF5                                                   330
# WDF5_ATTRIBUTES                                        ,,X
# WESD                                                     0
# WESD_ATTRIBUTES                                        ,,0
# WSF2                                                  17.9
# WSF2_ATTRIBUTES                                        ,,X
# WSF5                                                  21.9
# ...                                                    ...
# WT04                                                   NaN
# WT04_ATTRIBUTES                                        NaN
# WT05                                                     1
# WT05_ATTRIBUTES                                        ,,0
# WT06                                                   NaN
# WT06_ATTRIBUTES                                        NaN
# WT07                                                   NaN
# WT07_ATTRIBUTES                                        NaN
# WT08                                                   NaN
# WT08_ATTRIBUTES                                        NaN
# WT09                                                   NaN
# WT09_ATTRIBUTES                                        NaN
# WT11                                                   NaN
# WT11_ATTRIBUTES                                        NaN
# WT13                                                     1
# WT13_ATTRIBUTES                                        ,,X
# WT14                                                     1
# WT14_ATTRIBUTES                                        ,,X
# WT15                                                   NaN
# WT15_ATTRIBUTES                                        NaN
# WT16                                                     1
# WT16_ATTRIBUTES                                        ,,X
# WT17                                                   NaN
# WT17_ATTRIBUTES                                        NaN
# WT18                                                   NaN
# WT18_ATTRIBUTES                                        NaN
# WT21                                                   NaN
# WT21_ATTRIBUTES                                        NaN
# WT22                                                   NaN
# WT22_ATTRIBUTES                                        NaN
#
#                                                       8     \
# STATION                                        USW00013743
# NAME             WASHINGTON REAGAN NATIONAL AIRPORT, VA US
# DATE                                            2009-01-08
# AWND                                                  12.3
# AWND_ATTRIBUTES                                        ,,W
# FMTM                                                  1033
# FMTM_ATTRIBUTES                                        ,,X
# PGTM                                                  1032
# PGTM_ATTRIBUTES                                        ,,W
# PRCP                                                     0
# PRCP_ATTRIBUTES                                  T,,0,2400
# SNOW                                                     0
# SNOW_ATTRIBUTES                                      T,,0,
# SNWD                                                     0
# SNWD_ATTRIBUTES                                       ,,0,
# TAVG                                                   NaN
# TAVG_ATTRIBUTES                                        NaN
# TMAX                                                    42
# TMAX_ATTRIBUTES                                        ,,0
# TMIN                                                    30
# TMIN_ATTRIBUTES                                        ,,0
# WDF2                                                   300
# WDF2_ATTRIBUTES                                        ,,X
# WDF5                                                   290
# WDF5_ATTRIBUTES                                        ,,X
# WESD                                                     0
# WESD_ATTRIBUTES                                        ,,0
# WSF2                                                  25.1
# WSF2_ATTRIBUTES                                        ,,X
# WSF5                                                  36.9
# ...                                                    ...
# WT04                                                   NaN
# WT04_ATTRIBUTES                                        NaN
# WT05                                                   NaN
# WT05_ATTRIBUTES                                        NaN
# WT06                                                   NaN
# WT06_ATTRIBUTES                                        NaN
# WT07                                                   NaN
# WT07_ATTRIBUTES                                        NaN
# WT08                                                   NaN
# WT08_ATTRIBUTES                                        NaN
# WT09                                                   NaN
# WT09_ATTRIBUTES                                        NaN
# WT11                                                   NaN
# WT11_ATTRIBUTES                                        NaN
# WT13                                                   NaN
# WT13_ATTRIBUTES                                        NaN
# WT14                                                   NaN
# WT14_ATTRIBUTES                                        NaN
# WT15                                                   NaN
# WT15_ATTRIBUTES                                        NaN
# WT16                                                   NaN
# WT16_ATTRIBUTES                                        NaN
# WT17                                                   NaN
# WT17_ATTRIBUTES                                        NaN
# WT18                                                     1
# WT18_ATTRIBUTES                                        ,,X
# WT21                                                   NaN
# WT21_ATTRIBUTES                                        NaN
# WT22                                                   NaN
# WT22_ATTRIBUTES                                        NaN
#
#                                                       9     \
# STATION                                        USW00013743
# NAME             WASHINGTON REAGAN NATIONAL AIRPORT, VA US
# DATE                                            2009-01-09
# AWND                                                  7.83
# AWND_ATTRIBUTES                                        ,,W
# FMTM                                                   125
# FMTM_ATTRIBUTES                                        ,,X
# PGTM                                                   120
# PGTM_ATTRIBUTES                                        ,,W
# PRCP                                                     0
# PRCP_ATTRIBUTES                                   ,,0,2400
# SNOW                                                     0
# SNOW_ATTRIBUTES                                       ,,0,
# SNWD                                                     0
# SNWD_ATTRIBUTES                                       ,,0,
# TAVG                                                   NaN
# TAVG_ATTRIBUTES                                        NaN
# TMAX                                                    39
# TMAX_ATTRIBUTES                                        ,,0
# TMIN                                                    27
# TMIN_ATTRIBUTES                                        ,,0
# WDF2                                                   320
# WDF2_ATTRIBUTES                                        ,,X
# WDF5                                                   320
# WDF5_ATTRIBUTES                                        ,,X
# WESD                                                     0
# WESD_ATTRIBUTES                                        ,,0
# WSF2                                                    21
# WSF2_ATTRIBUTES                                        ,,X
# WSF5                                                    28
# ...                                                    ...
# WT04                                                   NaN
# WT04_ATTRIBUTES                                        NaN
# WT05                                                   NaN
# WT05_ATTRIBUTES                                        NaN
# WT06                                                   NaN
# WT06_ATTRIBUTES                                        NaN
# WT07                                                   NaN
# WT07_ATTRIBUTES                                        NaN
# WT08                                                   NaN
# WT08_ATTRIBUTES                                        NaN
# WT09                                                   NaN
# WT09_ATTRIBUTES                                        NaN
# WT11                                                   NaN
# WT11_ATTRIBUTES                                        NaN
# WT13                                                   NaN
# WT13_ATTRIBUTES                                        NaN
# WT14                                                   NaN
# WT14_ATTRIBUTES                                        NaN
# WT15                                                   NaN
# WT15_ATTRIBUTES                                        NaN
# WT16                                                   NaN
# WT16_ATTRIBUTES                                        NaN
# WT17                                                   NaN
# WT17_ATTRIBUTES                                        NaN
# WT18                                                   NaN
# WT18_ATTRIBUTES                                        NaN
# WT21                                                   NaN
# WT21_ATTRIBUTES                                        NaN
# WT22                                                   NaN
# WT22_ATTRIBUTES                                        NaN
#
#                                    ...                      \
# STATION                            ...
# NAME                               ...
# DATE                               ...
# AWND                               ...
# AWND_ATTRIBUTES                    ...
# FMTM                               ...
# FMTM_ATTRIBUTES                    ...
# PGTM                               ...
# PGTM_ATTRIBUTES                    ...
# PRCP                               ...
# PRCP_ATTRIBUTES                    ...
# SNOW                               ...
# SNOW_ATTRIBUTES                    ...
# SNWD                               ...
# SNWD_ATTRIBUTES                    ...
# TAVG                               ...
# TAVG_ATTRIBUTES                    ...
# TMAX                               ...
# TMAX_ATTRIBUTES                    ...
# TMIN                               ...
# TMIN_ATTRIBUTES                    ...
# WDF2                               ...
# WDF2_ATTRIBUTES                    ...
# WDF5                               ...
# WDF5_ATTRIBUTES                    ...
# WESD                               ...
# WESD_ATTRIBUTES                    ...
# WSF2                               ...
# WSF2_ATTRIBUTES                    ...
# WSF5                               ...
# ...                                ...
# WT04                               ...
# WT04_ATTRIBUTES                    ...
# WT05                               ...
# WT05_ATTRIBUTES                    ...
# WT06                               ...
# WT06_ATTRIBUTES                    ...
# WT07                               ...
# WT07_ATTRIBUTES                    ...
# WT08                               ...
# WT08_ATTRIBUTES                    ...
# WT09                               ...
# WT09_ATTRIBUTES                    ...
# WT11                               ...
# WT11_ATTRIBUTES                    ...
# WT13                               ...
# WT13_ATTRIBUTES                    ...
# WT14                               ...
# WT14_ATTRIBUTES                    ...
# WT15                               ...
# WT15_ATTRIBUTES                    ...
# WT16                               ...
# WT16_ATTRIBUTES                    ...
# WT17                               ...
# WT17_ATTRIBUTES                    ...
# WT18                               ...
# WT18_ATTRIBUTES                    ...
# WT21                               ...
# WT21_ATTRIBUTES                    ...
# WT22                               ...
# WT22_ATTRIBUTES                    ...
#
#                                                       3164  \
# STATION                                        USW00013743
# NAME             WASHINGTON REAGAN NATIONAL AIRPORT, VA US
# DATE                                            2017-08-30
# AWND                                                  6.26
# AWND_ATTRIBUTES                                        ,,W
# FMTM                                                   NaN
# FMTM_ATTRIBUTES                                        NaN
# PGTM                                                   NaN
# PGTM_ATTRIBUTES                                        NaN
# PRCP                                                     0
# PRCP_ATTRIBUTES                                   ,,W,2400
# SNOW                                                     0
# SNOW_ATTRIBUTES                                   ,,W,2400
# SNWD                                                     0
# SNWD_ATTRIBUTES                                   ,,W,2400
# TAVG                                                    69
# TAVG_ATTRIBUTES                                       H,,S
# TMAX                                                    79
# TMAX_ATTRIBUTES                                        ,,W
# TMIN                                                    62
# TMIN_ATTRIBUTES                                        ,,W
# WDF2                                                   330
# WDF2_ATTRIBUTES                                        ,,W
# WDF5                                                   330
# WDF5_ATTRIBUTES                                        ,,W
# WESD                                                   NaN
# WESD_ATTRIBUTES                                        NaN
# WSF2                                                    13
# WSF2_ATTRIBUTES                                        ,,W
# WSF5                                                    17
# ...                                                    ...
# WT04                                                   NaN
# WT04_ATTRIBUTES                                        NaN
# WT05                                                   NaN
# WT05_ATTRIBUTES                                        NaN
# WT06                                                   NaN
# WT06_ATTRIBUTES                                        NaN
# WT07                                                   NaN
# WT07_ATTRIBUTES                                        NaN
# WT08                                                   NaN
# WT08_ATTRIBUTES                                        NaN
# WT09                                                   NaN
# WT09_ATTRIBUTES                                        NaN
# WT11                                                   NaN
# WT11_ATTRIBUTES                                        NaN
# WT13                                                   NaN
# WT13_ATTRIBUTES                                        NaN
# WT14                                                   NaN
# WT14_ATTRIBUTES                                        NaN
# WT15                                                   NaN
# WT15_ATTRIBUTES                                        NaN
# WT16                                                   NaN
# WT16_ATTRIBUTES                                        NaN
# WT17                                                   NaN
# WT17_ATTRIBUTES                                        NaN
# WT18                                                   NaN
# WT18_ATTRIBUTES                                        NaN
# WT21                                                   NaN
# WT21_ATTRIBUTES                                        NaN
# WT22                                                   NaN
# WT22_ATTRIBUTES                                        NaN
#
#                                                       3165  \
# STATION                                        USW00013743
# NAME             WASHINGTON REAGAN NATIONAL AIRPORT, VA US
# DATE                                            2017-08-31
# AWND                                                  6.26
# AWND_ATTRIBUTES                                        ,,W
# FMTM                                                   NaN
# FMTM_ATTRIBUTES                                        NaN
# PGTM                                                   NaN
# PGTM_ATTRIBUTES                                        NaN
# PRCP                                                     0
# PRCP_ATTRIBUTES                                   ,,W,2400
# SNOW                                                     0
# SNOW_ATTRIBUTES                                   ,,W,2400
# SNWD                                                     0
# SNWD_ATTRIBUTES                                   ,,W,2400
# TAVG                                                    75
# TAVG_ATTRIBUTES                                       H,,S
# TMAX                                                    86
# TMAX_ATTRIBUTES                                        ,,W
# TMIN                                                    68
# TMIN_ATTRIBUTES                                        ,,W
# WDF2                                                    20
# WDF2_ATTRIBUTES                                        ,,W
# WDF5                                                    20
# WDF5_ATTRIBUTES                                        ,,W
# WESD                                                   NaN
# WESD_ATTRIBUTES                                        NaN
# WSF2                                                  21.9
# WSF2_ATTRIBUTES                                        ,,W
# ...
# WT16                                                   NaN
# WT16_ATTRIBUTES                                        NaN
# WT17                                                   NaN
# WT17_ATTRIBUTES                                        NaN
# WT18                                                   NaN
# WT18_ATTRIBUTES                                        NaN
# WT21                                                   NaN
# WT21_ATTRIBUTES                                        NaN
# WT22                                                   NaN
# WT22_ATTRIBUTES                                        NaN
#
#                                                       3170  \
# STATION                                        USW00013743
# NAME             WASHINGTON REAGAN NATIONAL AIRPORT, VA US
# DATE                                            2017-09-05
# AWND                                                  9.17
# AWND_ATTRIBUTES                                        ,,W
# FMTM                                                   NaN
# FMTM_ATTRIBUTES                                        NaN
# PGTM                                                   NaN
# PGTM_ATTRIBUTES                                        NaN
# PRCP                                                  0.07
# PRCP_ATTRIBUTES                                   ,,W,2400
# SNOW                                                     0
# SNOW_ATTRIBUTES                                   ,,W,2400
# SNWD                                                     0
# SNWD_ATTRIBUTES                                   ,,W,2400
# TAVG                                                    76
# TAVG_ATTRIBUTES                                       H,,S
# TMAX                                                    87
# TMAX_ATTRIBUTES                                        ,,W
# TMIN                                                    69
# TMIN_ATTRIBUTES                                        ,,W
# WDF2                                                   170
# WDF2_ATTRIBUTES                                        ,,W
# WDF5                                                   330
# WDF5_ATTRIBUTES                                        ,,W
# WESD                                                   NaN
# WESD_ATTRIBUTES                                        NaN
# WSF2                                                  21.9
# WSF2_ATTRIBUTES                                        ,,W
# WSF5                                                  27.1
# ...                                                    ...
# WT04                                                   NaN
# WT04_ATTRIBUTES                                        NaN
# WT05                                                   NaN
# WT05_ATTRIBUTES                                        NaN
# WT06                                                   NaN
# WT06_ATTRIBUTES                                        NaN
# WT07                                                   NaN
# WT07_ATTRIBUTES                                        NaN
# WT08                                                   NaN
# WT08_ATTRIBUTES                                        NaN
# WT09                                                   NaN
# WT09_ATTRIBUTES                                        NaN
# WT11                                                   NaN
# WT11_ATTRIBUTES                                        NaN
# WT13                                                   NaN
# WT13_ATTRIBUTES                                        NaN
# WT14                                                   NaN
# WT14_ATTRIBUTES                                        NaN
# WT15                                                   NaN
# WT15_ATTRIBUTES                                        NaN
# WT16                                                   NaN
# WT16_ATTRIBUTES                                        NaN
# WT17                                                   NaN
# WT17_ATTRIBUTES                                        NaN
# WT18                                                   NaN
# WT18_ATTRIBUTES                                        NaN
# WT21                                                   NaN
# WT21_ATTRIBUTES                                        NaN
# WT22                                                   NaN
# WT22_ATTRIBUTES                                        NaN
#
#                                                       3171  \
# STATION                                        USW00013743
# NAME             WASHINGTON REAGAN NATIONAL AIRPORT, VA US
# DATE                                            2017-09-06
# AWND                                                  7.61
# AWND_ATTRIBUTES                                        ,,W
# FMTM                                                   NaN
# FMTM_ATTRIBUTES                                        NaN
# PGTM                                                   NaN
# PGTM_ATTRIBUTES                                        NaN
# PRCP                                                  0.55
# PRCP_ATTRIBUTES                                   ,,W,2400
# SNOW                                                     0
# SNOW_ATTRIBUTES                                   ,,W,2400
# SNWD                                                     0
# SNWD_ATTRIBUTES                                   ,,W,2400
# TAVG                                                    68
# TAVG_ATTRIBUTES                                       H,,S
# TMAX                                                    72
# TMAX_ATTRIBUTES                                        ,,W
# TMIN                                                    61
# TMIN_ATTRIBUTES                                        ,,W
# WDF2                                                    10
# WDF2_ATTRIBUTES                                        ,,W
# WDF5                                                    10
# WDF5_ATTRIBUTES                                        ,,W
# WESD                                                   NaN
# WESD_ATTRIBUTES                                        NaN
# WSF2                                                    21
# WSF2_ATTRIBUTES                                        ,,W
# WSF5                                                  21.9
# ...                                                    ...
# WT04                                                   NaN
# WT04_ATTRIBUTES                                        NaN
# WT05                                                   NaN
# WT05_ATTRIBUTES                                        NaN
# WT06                                                   NaN
# WT06_ATTRIBUTES                                        NaN
# WT07                                                   NaN
# WT07_ATTRIBUTES                                        NaN
# WT08                                                   NaN
# WT08_ATTRIBUTES                                        NaN
# WT09                                                   NaN
# WT09_ATTRIBUTES                                        NaN
# WT11                                                   NaN
# WT11_ATTRIBUTES                                        NaN
# WT13                                                   NaN
# WT13_ATTRIBUTES                                        NaN
# WT14                                                   NaN
# WT14_ATTRIBUTES                                        NaN
# WT15                                                   NaN
# WT15_ATTRIBUTES                                        NaN
# WT16                                                   NaN
# WT16_ATTRIBUTES                                        NaN
# WT17                                                   NaN
# WT17_ATTRIBUTES                                        NaN
# WT18                                                   NaN
# WT18_ATTRIBUTES                                        NaN
# WT21                                                   NaN
# WT21_ATTRIBUTES                                        NaN
# WT22                                                   NaN
# WT22_ATTRIBUTES                                        NaN
#
#                                                       3172  \
# STATION                                        USW00013743
# NAME             WASHINGTON REAGAN NATIONAL AIRPORT, VA US
# DATE                                            2017-09-07
# AWND                                                   NaN
# AWND_ATTRIBUTES                                        NaN
# FMTM                                                   NaN
# FMTM_ATTRIBUTES                                        NaN
# PGTM                                                   NaN
# PGTM_ATTRIBUTES                                        NaN
# PRCP                                                   NaN
# PRCP_ATTRIBUTES                                        NaN
# SNOW                                                   NaN
# SNOW_ATTRIBUTES                                        NaN
# SNWD                                                   NaN
# SNWD_ATTRIBUTES                                        NaN
# TAVG                                                    65
# TAVG_ATTRIBUTES                                       H,,S
# TMAX                                                   NaN
# TMAX_ATTRIBUTES                                        NaN
# TMIN                                                   NaN
# TMIN_ATTRIBUTES                                        NaN
# WDF2                                                   NaN
# WDF2_ATTRIBUTES                                        NaN
# WDF5                                                   NaN
# WDF5_ATTRIBUTES                                        NaN
# WESD                                                   NaN
# WESD_ATTRIBUTES                                        NaN
# WSF2                                                   NaN
# WSF2_ATTRIBUTES                                        NaN
# WSF5                                                   NaN
# ...                                                    ...
# WT04                                                   NaN
# WT04_ATTRIBUTES                                        NaN
# WT05                                                   NaN
# WT05_ATTRIBUTES                                        NaN
# WT06                                                   NaN
# WT06_ATTRIBUTES                                        NaN
# WT07                                                   NaN
# WT07_ATTRIBUTES                                        NaN
# WT08                                                   NaN
# WT08_ATTRIBUTES                                        NaN
# WT09                                                   NaN
# WT09_ATTRIBUTES                                        NaN
# WT11                                                   NaN
# WT11_ATTRIBUTES                                        NaN
# WT13                                                   NaN
# WT13_ATTRIBUTES                                        NaN
# WT14                                                   NaN
# WT14_ATTRIBUTES                                        NaN
# WT15                                                   NaN
# WT15_ATTRIBUTES                                        NaN
# WT16                                                   NaN
# WT16_ATTRIBUTES                                        NaN
# WT17                                                   NaN
# WT17_ATTRIBUTES                                        NaN
# WT18                                                   NaN
# WT18_ATTRIBUTES                                        NaN
# WT21                                                   NaN
# WT21_ATTRIBUTES                                        NaN
# WT22                                                   NaN
# WT22_ATTRIBUTES                                        NaN
#
#                                                       3173
# STATION                                        USW00013743
# NAME             WASHINGTON REAGAN NATIONAL AIRPORT, VA US
# DATE                                            2017-09-08
# AWND                                                   NaN
# AWND_ATTRIBUTES                                        NaN
# FMTM                                                   NaN
# FMTM_ATTRIBUTES                                        NaN
# PGTM                                                   NaN
# PGTM_ATTRIBUTES                                        NaN
# PRCP                                                   NaN
# PRCP_ATTRIBUTES                                        NaN
# SNOW                                                   NaN
# SNOW_ATTRIBUTES                                        NaN
# SNWD                                                   NaN
# SNWD_ATTRIBUTES                                        NaN
# TAVG                                                    65
# TAVG_ATTRIBUTES                                       H,,S
# TMAX                                                   NaN
# TMAX_ATTRIBUTES                                        NaN
# TMIN                                                   NaN
# TMIN_ATTRIBUTES                                        NaN
# WDF2                                                   NaN
# WDF2_ATTRIBUTES                                        NaN
# WDF5                                                   NaN
# WDF5_ATTRIBUTES                                        NaN
# WESD                                                   NaN
# WESD_ATTRIBUTES                                        NaN
# WSF2                                                   NaN
# WSF2_ATTRIBUTES                                        NaN
# WSF5                                                   NaN
# ...                                                    ...
# WT04                                                   NaN
# WT04_ATTRIBUTES                                        NaN
# WT05                                                   NaN
# WT05_ATTRIBUTES                                        NaN
# WT06                                                   NaN
# WT06_ATTRIBUTES                                        NaN
# WT07                                                   NaN
# WT07_ATTRIBUTES                                        NaN
# WT08                                                   NaN
# WT08_ATTRIBUTES                                        NaN
# WT09                                                   NaN
# WT09_ATTRIBUTES                                        NaN
# WT11                                                   NaN
# WT11_ATTRIBUTES                                        NaN
# WT13                                                   NaN
# WT13_ATTRIBUTES                                        NaN
# WT14                                                   NaN
# WT14_ATTRIBUTES                                        NaN
# WT15                                                   NaN
# WT15_ATTRIBUTES                                        NaN
# WT16                                                   NaN
# WT16_ATTRIBUTES                                        NaN
# WT17                                                   NaN
# WT17_ATTRIBUTES                                        NaN
# WT18                                                   NaN
# WT18_ATTRIBUTES                                        NaN
# WT21                                                   NaN
# WT21_ATTRIBUTES                                        NaN
# WT22                                                   NaN
# WT22_ATTRIBUTES                                        NaN
#
# [67 rows x 3174 columns]

# %%
noaa_df.columns
# Out:
# Index(['STATION', 'NAME', 'DATE', 'AWND', 'AWND_ATTRIBUTES', 'FMTM',
#        'FMTM_ATTRIBUTES', 'PGTM', 'PGTM_ATTRIBUTES', 'PRCP', 'PRCP_ATTRIBUTES',
#        'SNOW', 'SNOW_ATTRIBUTES', 'SNWD', 'SNWD_ATTRIBUTES', 'TAVG',
#        'TAVG_ATTRIBUTES', 'TMAX', 'TMAX_ATTRIBUTES', 'TMIN', 'TMIN_ATTRIBUTES',
#        'WDF2', 'WDF2_ATTRIBUTES', 'WDF5', 'WDF5_ATTRIBUTES', 'WESD',
#        'WESD_ATTRIBUTES', 'WSF2', 'WSF2_ATTRIBUTES', 'WSF5', 'WSF5_ATTRIBUTES',
#        'WT01', 'WT01_ATTRIBUTES', 'WT02', 'WT02_ATTRIBUTES', 'WT03',
#        'WT03_ATTRIBUTES', 'WT04', 'WT04_ATTRIBUTES', 'WT05', 'WT05_ATTRIBUTES',
#        'WT06', 'WT06_ATTRIBUTES', 'WT07', 'WT07_ATTRIBUTES', 'WT08',
#        'WT08_ATTRIBUTES', 'WT09', 'WT09_ATTRIBUTES', 'WT11', 'WT11_ATTRIBUTES',
#        'WT13', 'WT13_ATTRIBUTES', 'WT14', 'WT14_ATTRIBUTES', 'WT15',
#        'WT15_ATTRIBUTES', 'WT16', 'WT16_ATTRIBUTES', 'WT17', 'WT17_ATTRIBUTES',
#        'WT18', 'WT18_ATTRIBUTES', 'WT21', 'WT21_ATTRIBUTES', 'WT22',
#        'WT22_ATTRIBUTES'],
#       dtype='object')

# %%
noaa_core = ['DATE','PRCP','SNOW', 'SNWD', 'TMAX', 'TMIN']
noaa      = noaa_df[noaa_core]
print(noaa.shape[0])
noaa_all  = noaa.dropna()
print(noaa_all.shape[0])
noaa_all.dtypes
# Out:
# 3174
# 3172
# DATE     object
# PRCP    float64
# SNOW    float64
# SNWD    float64
# TMAX    float64
# TMIN    float64
# dtype: object

# %%
noaa_all['DATE']= pd.to_datetime(noaa_all['DATE']);
# Out:
# C:\Users\CDL\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
noaa_all.dtypes
# Out:
# DATE    datetime64[ns]
# PRCP           float64
# SNOW           float64
# SNWD           float64
# TMAX           float64
# TMIN           float64
# dtype: object

# %%
#Only a couple rows drop due to NaN, I can proceed to assign daily climate data to my main data.
merg = big.copy()
print(merg.shape[0])
merg['DATEDAY']= merg['ADDDATE'].dt.date
noaa_all['DATE']= noaa_all['DATE'].dt.date
merg= pd.merge(merg, noaa_all, left_on='DATEDAY', right_on='DATE',
              how='left', sort=False)
print(merg.shape[0])
merg = merg.dropna()
print(merg.shape[0])
# Out:
# 1517436
# C:\Users\CDL\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 1517436
# 1516284

# %%
merg.T
# Out:
#                                     0                    1        \
# X                                  -77.0365             -77.0056
# Y                                   38.9227              38.8361
# WARD                                      1                    8
# SERVICECODEDESCRIPTION        Street Repair         Alley Repair
# DELTARES                        1.70409e+08          1.73583e+08
# ADDDATE                 2009-12-06 06:50:42  2009-10-30 12:54:23
# HOLIDAY                                   0                    0
# DATEDAY                          2009-12-06           2009-10-30
# DATE                             2009-12-06           2009-10-30
# PRCP                                      0                    0
# SNOW                                      0                    0
# SNWD                                      0                    0
# TMAX                                     39                   61
# TMIN                                     30                   54
#
#                                     2                    3        \
# X                                  -77.0264             -77.0207
# Y                                   38.9346              38.9201
# WARD                                      1                    1
# SERVICECODEDESCRIPTION      Sidewalk Repair      Sidewalk Repair
# DELTARES                        1.69094e+08          1.74451e+08
# ADDDATE                 2009-12-21 12:03:10  2009-10-20 11:46:48
# HOLIDAY                                   0                    0
# DATEDAY                          2009-12-21           2009-10-20
# DATE                             2009-12-21           2009-10-20
# PRCP                                      0                    0
# SNOW                                      0                    0
# SNWD                                     13                    0
# TMAX                                     41                   70
# TMIN                                     24                   41
#
#                                     4                    5        \
# X                                  -77.0342               -77.03
# Y                                    38.947              38.9692
# WARD                                      4                    4
# SERVICECODEDESCRIPTION      Sidewalk Repair      Sidewalk Repair
# DELTARES                        1.70571e+08          1.70121e+08
# ADDDATE                 2009-12-04 09:37:47  2009-12-09 14:50:04
# HOLIDAY                                   0                    0
# DATEDAY                          2009-12-04           2009-12-09
# DATE                             2009-12-04           2009-12-09
# PRCP                                      0                 1.29
# SNOW                                      0                    0
# SNWD                                      0                    0
# TMAX                                     50                   53
# TMIN                                     41                   37
#
#                                     6                    7        \
# X                                  -77.0834             -76.9955
# Y                                   38.9105              38.9537
# WARD                                      3                    5
# SERVICECODEDESCRIPTION      Sidewalk Repair      Sidewalk Repair
# DELTARES                        1.74679e+08          1.72707e+08
# ADDDATE                 2009-10-17 20:31:44  2009-11-09 16:16:25
# HOLIDAY                                   0                    0
# DATEDAY                          2009-10-17           2009-11-09
# DATE                             2009-10-17           2009-11-09
# PRCP                                    1.2                    0
# SNOW                                      0                    0
# SNWD                                      0                    0
# TMAX                                     47                   71
# TMIN                                     43                   47
#
#                                     8                    9        \
# X                                   -76.978             -76.9866
# Y                                   38.9039              38.8966
# WARD                                      5                    6
# SERVICECODEDESCRIPTION         Tree Removal         Alley Repair
# DELTARES                        7.56208e+07          1.74779e+08
# ADDDATE                 2009-09-16 10:56:42  2009-10-16 16:35:57
# HOLIDAY                                   0                    0
# DATEDAY                          2009-09-16           2009-10-16
# DATE                             2009-09-16           2009-10-16
# PRCP                                      0                 0.44
# SNOW                                      0                    0
# SNWD                                      0                    0
# TMAX                                     77                   45
# TMIN                                     66                   42
#
#                                     ...                \
# X                                   ...
# Y                                   ...
# WARD                                ...
# SERVICECODEDESCRIPTION              ...
# DELTARES                            ...
# ADDDATE                             ...
# HOLIDAY                             ...
# DATEDAY                             ...
# DATE                                ...
# PRCP                                ...
# SNOW                                ...
# SNWD                                ...
# TMAX                                ...
# TMIN                                ...
#
#                                               1516430  \
# X                                            -77.0225
# Y                                             38.9559
# WARD                                                4
# SERVICECODEDESCRIPTION  Recycling Collection - Missed
# DELTARES                                       157045
# ADDDATE                           2017-09-06 19:55:49
# HOLIDAY                                             0
# DATEDAY                                    2017-09-06
# DATE                                       2017-09-06
# PRCP                                             0.55
# SNOW                                                0
# SNWD                                                0
# TMAX                                               72
# TMIN                                               61
#
#                                                  1516431              1516432  \
# X                                               -77.0851              -76.983
# Y                                                 38.945              38.8422
# WARD                                                   3                    8
# SERVICECODEDESCRIPTION  Streetlight Repair Investigation      Illegal Dumping
# DELTARES                                          113592                67284
# ADDDATE                              2017-09-06 19:59:56  2017-09-06 20:12:44
# HOLIDAY                                                0                    0
# DATEDAY                                       2017-09-06           2017-09-06
# DATE                                          2017-09-06           2017-09-06
# PRCP                                                0.55                 0.55
# SNOW                                                   0                    0
# SNWD                                                   0                    0
# TMAX                                                  72                   72
# TMIN                                                  61                   61
#
#                                     1516433              1516434  \
# X                                  -77.0659             -77.0378
# Y                                   38.9492              38.9261
# WARD                                      3                    1
# SERVICECODEDESCRIPTION  Parking Enforcement  Parking Enforcement
# DELTARES                              11094                 7000
# ADDDATE                 2017-09-06 20:13:42  2017-09-06 20:19:22
# HOLIDAY                                   0                    0
# DATEDAY                          2017-09-06           2017-09-06
# DATE                             2017-09-06           2017-09-06
# PRCP                                   0.55                 0.55
# SNOW                                      0                    0
# SNWD                                      0                    0
# TMAX                                     72                   72
# TMIN                                     61                   61
#
#                                      1516435              1516436  \
# X                                   -77.0383              -77.036
# Y                                    38.9008                38.95
# WARD                                       2                    4
# SERVICECODEDESCRIPTION  Parking Meter Repair     Graffiti Removal
# DELTARES                               95287               147476
# ADDDATE                  2017-09-06 20:45:51  2017-09-06 21:05:30
# HOLIDAY                                    0                    0
# DATEDAY                           2017-09-06           2017-09-06
# DATE                              2017-09-06           2017-09-06
# PRCP                                    0.55                 0.55
# SNOW                                       0                    0
# SNWD                                       0                    0
# TMAX                                      72                   72
# TMIN                                      61                   61
#
#                                     1516437                           1516438  \
# X                                  -77.0364                          -77.0161
# Y                                   38.9429                            38.956
# WARD                                      4                                 4
# SERVICECODEDESCRIPTION     Graffiti Removal  Streetlight Repair Investigation
# DELTARES                             380041                            105151
# ADDDATE                 2017-09-06 21:09:17               2017-09-06 21:45:36
# HOLIDAY                                   0                                 0
# DATEDAY                          2017-09-06                        2017-09-06
# DATE                             2017-09-06                        2017-09-06
# PRCP                                   0.55                              0.55
# SNOW                                      0                                 0
# SNWD                                      0                                 0
# TMAX                                     72                                72
# TMIN                                     61                                61
#
#                                               1516439
# X                                            -77.0201
# Y                                             38.9114
# WARD                                                6
# SERVICECODEDESCRIPTION  Recycling Collection - Missed
# DELTARES                                        63352
# ADDDATE                           2017-09-06 22:08:05
# HOLIDAY                                             0
# DATEDAY                                    2017-09-06
# DATE                                       2017-09-06
# PRCP                                             0.55
# SNOW                                                0
# SNWD                                                0
# TMAX                                               72
# TMIN                                               61
#
# [14 rows x 1516284 columns]

# %%
merg['ADDHOUR']= merg['ADDDATE'].dt.hour

# %%
#merg.to_csv('data/merged_data.csv')

# %%
#merg.head(10000).to_csv('data/merged_data_head.csv')

# %% [markdown]
# Well I've fed in some data and now it's time for a train-test split, right? This should be pretty easy.
