# %% [markdown]
# # Lesson 2: Importing & Exploring Data

# %% [markdown]
# In this lesson, we'll learn to pull data into our Python environment and run some of the first diagnostics we'll need to understand our data.
#
# Why don't you kick us off by importing our two most important data analytic tools into our Jupyter notebook: Pandas and Numpy?
#
# ## Exercise 1
# Import Pandas and NumPy into your Jupyter Notebook and assign the standard aliases to them.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Exercise 2
#
# Now let's go straight into importing data into our Python environment! Check out DC's Open Data Portal at opendata.dc.gov.
#
# From here, we'll import data into our Python environment in two different ways. First, let's try downloading the data from the website and then pulling it into this notebook.
#
# Find the City Service Requests for 2016 in DC's Open Data Portal and download the spreadsheet (.csv file) to your computer.
#
# This is a data set containing requests for service through DC's 311 system. People can enter these requests by calling 311, texting DC-311 (32-311), using the 311 app, or visiting the city's online 311 portal.
#
# Now let's try pulling the data into our Python environment using Pandas.
#
#
# Pull the .csv file into your Python environment using Pandas and assign it to an object called 'df'.

# %%
pd.read_csv('City_Service_Requests_in_2016.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d8bfd2132142> in <module>()
# ----> 1 pd.read_csv('City_Service_Requests_in_2016.csv')
#
# C:\Users\CDL\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     644                     skip_blank_lines=skip_blank_lines)
#     645
# --> 646         return _read(filepath_or_buffer, kwds)
#     647
#     648     parser_f.__name__ = name
#
# C:\Users\CDL\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     387
#     388     # Create the parser.
# --> 389     parser = TextFileReader(filepath_or_buffer, **kwds)
#     390
#     391     if (nrows is not None) and (chunksize is not None):
#
# C:\Users\CDL\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     728             self.options['has_index_names'] = kwds['has_index_names']
#     729
# --> 730         self._make_engine(self.engine)
#     731
#     732     def close(self):
#
# C:\Users\CDL\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#     921     def _make_engine(self, engine='c'):
#     922         if engine == 'c':
# --> 923             self._engine = CParserWrapper(self.f, **self.options)
#     924         else:
#     925             if engine == 'python':
#
# C:\Users\CDL\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1388         kwds['allow_leading_cols'] = self.index_col is not False
#    1389
# -> 1390         self._reader = _parser.TextReader(src, **kwds)
#    1391
#    1392         # XXX
#
# pandas\parser.pyx in pandas.parser.TextReader.__cinit__ (pandas\parser.c:4184)()
#
# pandas\parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas\parser.c:8449)()
#
# FileNotFoundError: File b'City_Service_Requests_in_2016.csv' does not exist

# %% [markdown]
# What happened? You may have received an error like this: "OSError: File b'City_Service_Requests_in_2016.csv' does not exist"
#
# This means that the .csv file is not in the directory your notebook is calling from (which is, in fact, the directory the notebook is in). To find out which directory your notebook is calling from, import the os package and get the current working directory.
#
# ## Exercise 3
#
# Import the os package and get the current working directory.

# %%
# %ls 
#line magic is more I-Pythonic
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is BA59-3588
#
#  Directory of C:\Users\CDL\Documents\My python learning\assignment-02-master
#
# 09/09/2017  05:41 PM    <DIR>          .
# 09/09/2017  05:41 PM    <DIR>          ..
# 09/09/2017  11:50 AM    <DIR>          .ipynb_checkpoints
# 09/09/2017  05:38 PM           121,942 assignment-02.ipynb
# 09/09/2017  05:18 PM    <DIR>          data
# 09/09/2017  11:45 AM               842 README.md
#                2 File(s)        122,784 bytes
#                4 Dir(s)  317,672,869,888 bytes free

# %% [markdown]
# Ok, now that we know what the current working directory is, we must either change the working directory or move the file into the current working directory. I'll let you decide which you want to do, but this is how you change the working directory.

# %%
os.chdir('C:\\Users\\peter.casey\\Downloads') 
## There's this weird thing in Python where you have to use double slashes when specifying working directories.
## If you have trouble getting a file from a directory you know it's in, this is a common error.

#

# %% [markdown]
# Now you should be able to pull the data into your Jupyter Notebook. Try it again.

# %%
df = pd.read_csv("https://opendata.arcgis.com/datasets/0e4b7d3a83b94a178b3d1f015db901ee_7.csv")

# %%
mkdir data

# %%
df.to_csv('data/serv_16.csv') #more ipythonic to mkdir and save to data folder

# %% [markdown]
# We can also pull the .csv file directly from the Open Data Portal by using the link.

# %%
## I'm commenting this out because it takes a while to pull the data into the environment because it's a large file
#df = pd.read_csv('https://opendata.arcgis.com/datasets/0e4b7d3a83b94a178b3d1f015db901ee_7.csv')

# %% [markdown]
# Great! You have the data!
#
# One of the first things we'd like to know when we're dealing with a data set is its shape; that is the number of rows and columns it has.

# %%
df.shape
# Out:
# (302985, 30)

# %% [markdown]
# This data has 302,925 rows and 30 columns. Generally speaking, rows are our "observations" or "samples", while columns are our "variables" or "features".
#
# Now try getting JUST the number of rows.

# %%
df.shape[0]
# Out:
# 302985

# %% [markdown]
# When you have an item like this with multiple elements, you can often call the elements by their number. In Python, we always start counting elements with the number '0', so that the first element is always element '0'.
#
# ## Exercise 4
# Now try getting the number of columns yourself.

# %%
df.shape[1]
# Out:
# 30

# %% [markdown]
# The next thing we may want to do is actually LOOK at the data. But you probably don't want to print out all 300,000 rows of data in your notebook! (In reality, Pandas won't do that. Instead, it will show you a subset of the rows.)
#
# But to have greater control we can use the head command.

# %%
df.head()
# Out:
#            X          Y  OBJECTID SERVICECODE  \
# 0 -77.068472  38.959221    928367       EMNPV
# 1 -77.028858  38.903745    947826       S0276
# 2 -77.019418  38.941567    947827       S0361
# 3 -77.014655  38.906236    947828     PRUNING
# 4 -77.004008  38.835935    947829       S0031
#
#               SERVICECODEDESCRIPTION  \
# 0  Emergency No-Parking Verification
# 1               Parking Meter Repair
# 2                    Sidewalk Repair
# 3                       Tree Pruning
# 4                    Bulk Collection
#
#                           SERVICETYPECODEDESCRIPTION ORGANIZATIONACRONYM  \
# 0  PEMA- Parking Enforcement Management Administr...                 DPW
# 1           Transportation Operations Administration                DDOT
# 2                    Toa-Street & Bridge Maintenance                DDOT
# 3                                    Urban Forrestry                DDOT
# 4          SWMA- Solid Waste Management Admistration                 DPW
#
#    SERVICECALLCOUNT                   ADDDATE            RESOLUTIONDATE  \
# 0                 1  2016-01-04T16:45:21.000Z  2016-01-04T21:13:04.000Z
# 1                 1  2016-05-02T11:43:31.000Z  2016-05-03T01:38:10.000Z
# 2                 1  2016-05-02T11:47:49.000Z                       NaN
# 3                 1  2016-05-02T10:44:23.000Z  2017-01-19T11:03:08.000Z
# 4                 1  2016-05-02T11:49:49.000Z  2016-05-12T14:27:19.000Z
#
#                          ...                             XCOORD  \
# 0                        ...                          394065.60
# 1                        ...                          397497.09
# 2                        ...                          398316.79
# 3                        ...                          398729.12
# 4                        ...                          399652.25
#
#           YCOORD   LATITUDE  LONGITUDE        CITY STATE  ZIPCODE  \
# 0  143480.700000  38.959214 -77.068470  WASHINGTON    DC  20015.0
# 1  137320.600003  38.903738 -77.028856  WASHINGTON    DC  20005.0
# 2  141518.950000  38.941560 -77.019416  WASHINGTON    DC  20011.0
# 3  137596.790000  38.906229 -77.014652  WASHINGTON    DC  20001.0
# 4  129792.780000  38.835928 -77.004005  WASHINGTON    DC  20032.0
#
#   MARADDRESSREPOSITORYID WARD  \
# 0               262895.0  3.0
# 1               812754.0  2.0
# 2               247564.0  4.0
# 3               238344.0  6.0
# 4                66302.0  8.0
#
#                                              DETAILS
# 0                                                NaN
# 1                              Need More Information
# 2                                                NaN
# 3  By BANUA, SIMOUN: 5/2/2016 12:48:15 PM\nthis t...
# 4  w riggans collected bulk on 5/12/16*closed by ...
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Exercise 11
#
# The default head command shows us 5 rows. Try increasing the number of rows it shows us.

# %%
df.head(10)
# Out:
#            X          Y  OBJECTID SERVICECODE  \
# 0 -77.068472  38.959221    928367       EMNPV
# 1 -77.028858  38.903745    947826       S0276
# 2 -77.019418  38.941567    947827       S0361
# 3 -77.014655  38.906236    947828     PRUNING
# 4 -77.004008  38.835935    947829       S0031
# 5 -77.004008  38.835935    947830       S0031
# 6 -77.020134  38.914935    986620       S0261
# 7 -77.018788  38.915155    986621       S0441
# 8 -77.018788  38.915155    986622       S0441
# 9 -77.011544  38.915718    986623       S0441
#
#               SERVICECODEDESCRIPTION  \
# 0  Emergency No-Parking Verification
# 1               Parking Meter Repair
# 2                    Sidewalk Repair
# 3                       Tree Pruning
# 4                    Bulk Collection
# 5                    Bulk Collection
# 6                Parking Enforcement
# 7          Trash Collection - Missed
# 8          Trash Collection - Missed
# 9          Trash Collection - Missed
#
#                           SERVICETYPECODEDESCRIPTION ORGANIZATIONACRONYM  \
# 0  PEMA- Parking Enforcement Management Administr...                 DPW
# 1           Transportation Operations Administration                DDOT
# 2                    Toa-Street & Bridge Maintenance                DDOT
# 3                                    Urban Forrestry                DDOT
# 4          SWMA- Solid Waste Management Admistration                 DPW
# 5          SWMA- Solid Waste Management Admistration                 DPW
# 6  PEMA- Parking Enforcement Management Administr...                 DPW
# 7          SWMA- Solid Waste Management Admistration                 DPW
# 8          SWMA- Solid Waste Management Admistration                 DPW
# 9          SWMA- Solid Waste Management Admistration                 DPW
#
#    SERVICECALLCOUNT                   ADDDATE            RESOLUTIONDATE  \
# 0                 1  2016-01-04T16:45:21.000Z  2016-01-04T21:13:04.000Z
# 1                 1  2016-05-02T11:43:31.000Z  2016-05-03T01:38:10.000Z
# 2                 1  2016-05-02T11:47:49.000Z                       NaN
# 3                 1  2016-05-02T10:44:23.000Z  2017-01-19T11:03:08.000Z
# 4                 1  2016-05-02T11:49:49.000Z  2016-05-12T14:27:19.000Z
# 5                 1  2016-05-02T11:49:50.000Z  2016-05-12T14:26:24.000Z
# 6                 1  2016-03-16T08:10:25.000Z  2016-03-16T11:01:29.000Z
# 7                 1  2016-03-16T08:12:34.000Z  2016-03-18T11:20:03.000Z
# 8                 1  2016-03-16T08:12:35.000Z  2016-03-18T11:22:49.000Z
# 9                 1  2016-03-16T08:10:29.000Z  2016-03-25T08:13:57.000Z
#
#                          ...                             XCOORD  \
# 0                        ...                          394065.60
# 1                        ...                          397497.09
# 2                        ...                          398316.79
# 3                        ...                          398729.12
# 4                        ...                          399652.25
# 5                        ...                          399652.25
# 6                        ...                          398254.07
# 7                        ...                          398370.81
# 8                        ...                          398370.81
# 9                        ...                          398999.01
#
#           YCOORD   LATITUDE  LONGITUDE        CITY STATE  ZIPCODE  \
# 0  143480.700000  38.959214 -77.068470  WASHINGTON    DC  20015.0
# 1  137320.600003  38.903738 -77.028856  WASHINGTON    DC  20005.0
# 2  141518.950000  38.941560 -77.019416  WASHINGTON    DC  20011.0
# 3  137596.790000  38.906229 -77.014652  WASHINGTON    DC  20001.0
# 4  129792.780000  38.835928 -77.004005  WASHINGTON    DC  20032.0
# 5  129792.780000  38.835928 -77.004005  WASHINGTON    DC  20032.0
# 6  138562.500000  38.914927 -77.020132  WASHINGTON    DC  20001.0
# 7  138586.890000  38.915147 -77.018786  WASHINGTON    DC  20001.0
# 8  138586.890000  38.915147 -77.018786  WASHINGTON    DC  20001.0
# 9  138649.350000  38.915711 -77.011542  WASHINGTON    DC  20001.0
#
#   MARADDRESSREPOSITORYID WARD  \
# 0               262895.0  3.0
# 1               812754.0  2.0
# 2               247564.0  4.0
# 3               238344.0  6.0
# 4                66302.0  8.0
# 5                66302.0  8.0
# 6               238452.0  6.0
# 7               229894.0  1.0
# 8               229894.0  1.0
# 9               300722.0  5.0
#
#                                              DETAILS
# 0                                                NaN
# 1                              Need More Information
# 2                                                NaN
# 3  By BANUA, SIMOUN: 5/2/2016 12:48:15 PM\nthis t...
# 4  w riggans collected bulk on 5/12/16*closed by ...
# 5  w riggans collected bulk on 5/12/16*closed by ...
# 6                                                NaN
# 7    COMPLETED BY 3/17/16 D STREET CLOSED BY NDAVALL
# 8   COMPLETED  BY D STREET 3/17/16 CLOSED BY NDAVALL
# 9  COMPLETED  BY L FERGUSON 3/17/16 CLOSED BY NDA...
#
# [10 rows x 30 columns]

# %% [markdown]
# This is sort of any annoying way to look at the data, in my opinion. I'm usually interested in looking at the list of columns and the kinds of values they have, so I usually transpose the data when I print it as a head.

# %%
df.head().T
# Out:
#                                                                             0  \
# X                                                                    -77.0685
# Y                                                                     38.9592
# OBJECTID                                                               928367
# SERVICECODE                                                             EMNPV
# SERVICECODEDESCRIPTION                      Emergency No-Parking Verification
# SERVICETYPECODEDESCRIPTION  PEMA- Parking Enforcement Management Administr...
# ORGANIZATIONACRONYM                                                       DPW
# SERVICECALLCOUNT                                                            1
# ADDDATE                                              2016-01-04T16:45:21.000Z
# RESOLUTIONDATE                                       2016-01-04T21:13:04.000Z
# SERVICEDUEDATE                                       2016-01-05T16:45:00.000Z
# SERVICEORDERDATE                                     2016-01-04T16:45:21.000Z
# INSPECTIONFLAG                                                              N
# INSPECTIONDATE                                                            NaN
# INSPECTORNAME                                                             NaN
# SERVICEORDERSTATUS                                                     CLOSED
# STATUS_CODE                                                            CLOSED
# SERVICEREQUESTID                                                  16-00353175
# PRIORITY                                                             STANDARD
# STREETADDRESS                                          3611 JENIFER STREET NW
# XCOORD                                                                 394066
# YCOORD                                                                 143481
# LATITUDE                                                              38.9592
# LONGITUDE                                                            -77.0685
# CITY                                                               WASHINGTON
# STATE                                                                      DC
# ZIPCODE                                                                 20015
# MARADDRESSREPOSITORYID                                                 262895
# WARD                                                                        3
# DETAILS                                                                   NaN
#
#                                                                    1  \
# X                                                           -77.0289
# Y                                                            38.9037
# OBJECTID                                                      947826
# SERVICECODE                                                    S0276
# SERVICECODEDESCRIPTION                          Parking Meter Repair
# SERVICETYPECODEDESCRIPTION  Transportation Operations Administration
# ORGANIZATIONACRONYM                                             DDOT
# SERVICECALLCOUNT                                                   1
# ADDDATE                                     2016-05-02T11:43:31.000Z
# RESOLUTIONDATE                              2016-05-03T01:38:10.000Z
# SERVICEDUEDATE                              2016-05-09T11:43:00.000Z
# SERVICEORDERDATE                            2016-05-02T11:43:31.000Z
# INSPECTIONFLAG                                                     N
# INSPECTIONDATE                                                   NaN
# INSPECTORNAME                                                    NaN
# SERVICEORDERSTATUS                                            CLOSED
# STATUS_CODE                                                   CLOSED
# SERVICEREQUESTID                                         16-00485849
# PRIORITY                                                    STANDARD
# STREETADDRESS                       1200 - 1299 BLOCK OF L STREET NW
# XCOORD                                                        397497
# YCOORD                                                        137321
# LATITUDE                                                     38.9037
# LONGITUDE                                                   -77.0289
# CITY                                                      WASHINGTON
# STATE                                                             DC
# ZIPCODE                                                        20005
# MARADDRESSREPOSITORYID                                        812754
# WARD                                                               2
# DETAILS                                        Need More Information
#
#                                                           2  \
# X                                                  -77.0194
# Y                                                   38.9416
# OBJECTID                                             947827
# SERVICECODE                                           S0361
# SERVICECODEDESCRIPTION                      Sidewalk Repair
# SERVICETYPECODEDESCRIPTION  Toa-Street & Bridge Maintenance
# ORGANIZATIONACRONYM                                    DDOT
# SERVICECALLCOUNT                                          1
# ADDDATE                            2016-05-02T11:47:49.000Z
# RESOLUTIONDATE                                          NaN
# SERVICEDUEDATE                     2016-09-20T11:47:00.000Z
# SERVICEORDERDATE                   2016-05-02T11:47:49.000Z
# INSPECTIONFLAG                                            N
# INSPECTIONDATE                                          NaN
# INSPECTORNAME                                           NaN
# SERVICEORDERSTATUS                              IN-PROGRESS
# STATUS_CODE                                            OPEN
# SERVICEREQUESTID                                16-00485860
# PRIORITY                                           STANDARD
# STREETADDRESS                            4120 5TH STREET NW
# XCOORD                                               398317
# YCOORD                                               141519
# LATITUDE                                            38.9416
# LONGITUDE                                          -77.0194
# CITY                                             WASHINGTON
# STATE                                                    DC
# ZIPCODE                                               20011
# MARADDRESSREPOSITORYID                               247564
# WARD                                                      4
# DETAILS                                                 NaN
#
#                                                                             3  \
# X                                                                    -77.0147
# Y                                                                     38.9062
# OBJECTID                                                               947828
# SERVICECODE                                                           PRUNING
# SERVICECODEDESCRIPTION                                           Tree Pruning
# SERVICETYPECODEDESCRIPTION                                    Urban Forrestry
# ORGANIZATIONACRONYM                                                      DDOT
# SERVICECALLCOUNT                                                            1
# ADDDATE                                              2016-05-02T10:44:23.000Z
# RESOLUTIONDATE                                       2017-01-19T11:03:08.000Z
# SERVICEDUEDATE                                       2017-05-31T10:44:00.000Z
# SERVICEORDERDATE                                     2016-05-02T10:44:23.000Z
# INSPECTIONFLAG                                                              N
# INSPECTIONDATE                                                            NaN
# INSPECTORNAME                                                             NaN
# SERVICEORDERSTATUS                                                     CLOSED
# STATUS_CODE                                                            CLOSED
# SERVICEREQUESTID                                                  16-00485852
# PRIORITY                                                             STANDARD
# STREETADDRESS                                       1219 NEW JERSEY AVENUE NW
# XCOORD                                                                 398729
# YCOORD                                                                 137597
# LATITUDE                                                              38.9062
# LONGITUDE                                                            -77.0147
# CITY                                                               WASHINGTON
# STATE                                                                      DC
# ZIPCODE                                                                 20001
# MARADDRESSREPOSITORYID                                                 238344
# WARD                                                                        6
# DETAILS                     By BANUA, SIMOUN: 5/2/2016 12:48:15 PM\nthis t...
#
#                                                                             4
# X                                                                     -77.004
# Y                                                                     38.8359
# OBJECTID                                                               947829
# SERVICECODE                                                             S0031
# SERVICECODEDESCRIPTION                                        Bulk Collection
# SERVICETYPECODEDESCRIPTION          SWMA- Solid Waste Management Admistration
# ORGANIZATIONACRONYM                                                       DPW
# SERVICECALLCOUNT                                                            1
# ADDDATE                                              2016-05-02T11:49:49.000Z
# RESOLUTIONDATE                                       2016-05-12T14:27:19.000Z
# SERVICEDUEDATE                                       2016-05-20T11:49:00.000Z
# SERVICEORDERDATE                                     2016-05-02T11:49:49.000Z
# INSPECTIONFLAG                                                              N
# INSPECTIONDATE                                                            NaN
# INSPECTORNAME                                                             NaN
# SERVICEORDERSTATUS                                                     CLOSED
# STATUS_CODE                                                            CLOSED
# SERVICEREQUESTID                                                  16-00485867
# PRIORITY                                                             STANDARD
# STREETADDRESS                                         135 WILMINGTON PLACE SE
# XCOORD                                                                 399652
# YCOORD                                                                 129793
# LATITUDE                                                              38.8359
# LONGITUDE                                                             -77.004
# CITY                                                               WASHINGTON
# STATE                                                                      DC
# ZIPCODE                                                                 20032
# MARADDRESSREPOSITORYID                                                  66302
# WARD                                                                        8
# DETAILS                     w riggans collected bulk on 5/12/16*closed by ...

# %% [markdown]
# Now you can get a sense of what your data looks like. What do you think some of these columns mean?
#
# ## Exercise 12
#
# Think about some of the column names and values you have. What do you think these columns are?
#
# We probably want even more information about our variables or columns, so let's learn more about them.
#
# First, we can get a quick list of column names this way also.

# %%
df.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'SERVICECODE', 'SERVICECODEDESCRIPTION',
#        'SERVICETYPECODEDESCRIPTION', 'ORGANIZATIONACRONYM', 'SERVICECALLCOUNT',
#        'ADDDATE', 'RESOLUTIONDATE', 'SERVICEDUEDATE', 'SERVICEORDERDATE',
#        'INSPECTIONFLAG', 'INSPECTIONDATE', 'INSPECTORNAME',
#        'SERVICEORDERSTATUS', 'STATUS_CODE', 'SERVICEREQUESTID', 'PRIORITY',
#        'STREETADDRESS', 'XCOORD', 'YCOORD', 'LATITUDE', 'LONGITUDE', 'CITY',
#        'STATE', 'ZIPCODE', 'MARADDRESSREPOSITORYID', 'WARD', 'DETAILS'],
#       dtype='object')

# %% [markdown]
# The columns command provides us with a list of column names.
#
# We can also use this command to find out how many columns we have by taking its length.

# %%
len(df.columns)
# Out:
# 30

# %% [markdown]
# Note that this returns the same value as df.shape[1].
#
# We can also get column data types.

# %%
df.dtypes
# Out:
# X                             float64
# Y                             float64
# OBJECTID                        int64
# SERVICECODE                    object
# SERVICECODEDESCRIPTION         object
# SERVICETYPECODEDESCRIPTION     object
# ORGANIZATIONACRONYM            object
# SERVICECALLCOUNT                int64
# ADDDATE                        object
# RESOLUTIONDATE                 object
# SERVICEDUEDATE                 object
# SERVICEORDERDATE               object
# INSPECTIONFLAG                 object
# INSPECTIONDATE                 object
# INSPECTORNAME                 float64
# SERVICEORDERSTATUS             object
# STATUS_CODE                    object
# SERVICEREQUESTID               object
# PRIORITY                       object
# STREETADDRESS                  object
# XCOORD                        float64
# YCOORD                        float64
# LATITUDE                      float64
# LONGITUDE                     float64
# CITY                           object
# STATE                          object
# ZIPCODE                       float64
# MARADDRESSREPOSITORYID        float64
# WARD                          float64
# DETAILS                        object
# dtype: object

# %% [markdown]
# We see three data types here. What does each mean? Why aren't there any "date" types?

# %% [markdown]
# ## Exercise 13
#
# We'd like to know even more about our data.
#
# Use the describe function to learn more about your data. I like to transpose this, too. Try transposing it.
#
# Do you notice any columns missing from the output? Why do you think they're missing?
#
# You may notice some values are 'NaN'. What does that mean? How might we handle these values?

# %%
df.describe().T
#Because they are objects, I guess
# Out:
#                            count          mean            std            min  \
# X                       302985.0 -7.701344e+01       0.037492     -77.114209
# Y                       302985.0  3.891196e+01       0.031257      38.813455
# OBJECTID                302985.0  1.335995e+06  102371.072802  928367.000000
# SERVICECALLCOUNT        302985.0  1.000000e+00       0.000000       1.000000
# INSPECTORNAME                0.0           NaN            NaN            NaN
# XCOORD                  302985.0  3.988348e+05    3251.499740  390097.460000
# YCOORD                  302985.0  1.382333e+05    3470.000502  127297.420000
# LATITUDE                302985.0  3.891195e+01       0.031258      38.813448
# LONGITUDE               302985.0 -7.701344e+01       0.037491     -77.114206
# ZIPCODE                 302983.0  2.002962e+04     867.804543   -1865.000000
# MARADDRESSREPOSITORYID  294302.0  2.912035e+05  270115.221076       1.000000
# WARD                    300924.0  4.335025e+00       2.151176       1.000000
#
#                                  25%           50%           75%           max
# X                      -7.703655e+01 -7.701731e+01 -7.698978e+01 -7.690953e+01
# Y                       3.889461e+01  3.890972e+01  3.893308e+01  3.899544e+01
# OBJECTID                1.264323e+06  1.340839e+06  1.417109e+06  1.566462e+06
# SERVICECALLCOUNT        1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# INSPECTORNAME                    NaN           NaN           NaN           NaN
# XCOORD                  3.968295e+05  3.984992e+05  4.008872e+05  4.078484e+05
# YCOORD                  1.363069e+05  1.379835e+05  1.405768e+05  1.475002e+05
# LATITUDE                3.889460e+01  3.890968e+01  3.893306e+01  3.899544e+01
# LONGITUDE              -7.703655e+01 -7.701731e+01 -7.698977e+01 -7.690976e+01
# ZIPCODE                 2.000300e+04  2.001100e+04  2.001800e+04  7.073900e+04
# MARADDRESSREPOSITORYID  6.951100e+04  2.405765e+05  2.946100e+05  9.141190e+05
# WARD                    2.000000e+00  4.000000e+00  6.000000e+00  8.000000e+00

# %% [markdown]
# The describe function provides us a ton of great information about numeric variables, like integers and floats. But categorical variables, called "object" variables in Python, do not have means, mins, maxes, or standard deviations. So how might we analyze these?
#
# One of the first steps is to take a look at the unique values of these columns. Let's start with the most interesting one: Service Code Description.

# %%
df['SERVICECODEDESCRIPTION'].unique()
# Out:
# array(['Emergency No-Parking Verification', 'Parking Meter Repair',
#        'Sidewalk Repair', 'Tree Pruning', 'Bulk Collection',
#        'Parking Enforcement', 'Trash Collection - Missed',
#        'Sanitation Enforcement', 'Tree Inspection', 'Illegal Dumping',
#        'Rodent Inspection and Treatment', 'Yard Waste - Missed',
#        'Sidewalk Shoveling Enforcement Exemption',
#        'Dead Animal Collection', 'Emergency - Trees', 'Sign Replacement',
#        'Alley Cleaning', 'Abandoned Vehicle - On Private Property',
#        'DMV - Copy of Ticket', 'Streetlight Repair Investigation',
#        'Recycling Cart Delivery', 'Out of State Parking Violation (ROSA)',
#        'DMV - Vehicle Registration Issues',
#        'DMV - Drivers License/ID Issues', 'Pothole', 'Tree Planting',
#        'Leaf Season Collection', 'Residential Snow Removal (ServeDC)',
#        'Snow Removal Complaints for Sidewalks', 'Street Cleaning',
#        'Street Repair', 'Supercan - Repair', 'Alleylight Repair',
#        'Public Space Litter Can- Installation/Removal/Repair',
#        'Snow/Ice Removal', 'Residential Parking Permit Violation',
#        'Abandoned Vehicle - On Public Property',
#        'DC Government Information', 'Trash Cart - Delivery',
#        'Recycling Collection - Missed', 'Sign New Investigation',
#        'Wire Down/Power Outage', 'Vacant Lot', 'Bicycle Issues',
#        'How Is My Driving - Complaint', 'Signs Conflicting',
#        'Snow/Ice Removal (Roadways AND Bridge walkways ONLY)',
#        'DMV - Forms, Applications, and Manuals Request', 'Tree Removal',
#        'Christmas Tree Removal-Seasonal', 'Sign Removal investigation',
#        'TRU Report', 'DMV - Processing Center Manager',
#        'FEMS - Community Events', 'Traffic Signal Maintanence',
#        'Resident Parking Permit', 'Container Removal',
#        'Supercan - Delivery', 'Bus/Rail Issues',
#        'Homeless Services - Winter/Hypothermia Season',
#        'Sign Missing Investigation', 'Snow Metro Bus Shelter/Stop',
#        'Snow Ticket Reimbursement', 'DMV - Vehicle Title Issues',
#        'DOEE - Engine Idling Tips', 'Abandoned Bicycle',
#        'FEMS - Smoke Alarm Application', 'Traffic Calming',
#        'Graffiti Removal', 'Utility Repair Investigation', 'Snow Towing',
#        'Marking Installation', 'Public Space Litter Can-Collection',
#        'DMV - Driver Record Issues', 'DOEE - Nuisance Odor Complaints',
#        'Trash Cart Repair', 'DMV - Vehicle Insurance Lapse',
#        'Insect Treatment', 'Alley Repair',
#        'DMV - Online Processing Issues', 'Marking Removal',
#        'DMV - Ticket Payment Dispute', 'Recycling Cart - Repair',
#        'Illegal Poster', 'Curb and Gutter Repair', 'Marking Modification',
#        'DOEE - Ban on Foam Food Containers',
#        'DOEE - Construction – Erosion Runoff',
#        'DMV - eTIMS Ticket Alert Services Issues',
#        'How Is My Driving - Compliment', 'DMV - Refunds - Tickets',
#        'Marking Maintenance', 'DMV - Hearings',
#        'Traffic Safety Investigation', 'DOEE - Foam Ban Tips',
#        'Recycling- Information Request',
#        'DOEE - General Environmental Concerns',
#        'DMV - Adjudication Supervisor', 'Safe Routes to School',
#        'Roadway Repair', 'DMV - Driver and Vehicle Services Refund',
#        'DMV - Vehicle Inspection Issues',
#        'Curb and Gutter Repair Investigation', 'Light-Light Pole',
#        'DMV - Drivers License/ID Reinstatement',
#        'Emergency - Power Outage/Wires Down', 'Snow Other',
#        'DMV - Offset Tracking', 'Roadway Marking Maintenance',
#        '311Force Reported Issues', 'Alleylight Repair Investigation',
#        'Signed Street Sweeping Missed', 'Insects', 'Traffic Signal Issue',
#        'Grass and Weeds Mowing', 'OUC NYE Test',
#        'Roadway Striping / Markings', 'Child Safety Seat Program',
#        'School Crossing Guard', 'Streetcar',
#        'Light-Tunnel/Underpass Light Repair',
#        'General Environmental Concerns (DOEE)', 'Roadway Signs',
#        'DPW Correspondence Tracking', 'DMV - Appeal',
#        'Recycling - Commercial Only', 'Roadway Marking Modification',
#        'Utility Repair Issue', 'DOEE - Bag Law Tips',
#        'Light-Overhead Guide Sign Lighting Repair', 'Illegal Fireworks',
#        'Emergency - Heating and Cooling', 'Emergency - Senior Assistance',
#        'Emergency - Supplies', 'Report Invalid Address to GIS Dept',
#        'FEMS - Fire Safety Education', 'Recycling - School Program',
#        'School Transit Subsidy Program', 'Citation',
#        'Emergency - Flooding', 'Roadway Marking Removal',
#        'Bicycle Services', 'Ticket Ombudsman',
#        'School Crossing Guard Program', 'DDS - Serious Medication Error',
#        'SalesForce DC311 Application Request',
#        'Hypothermia Shelter Information'], dtype=object)

# %% [markdown]
# We just did two new things right here: we called a column by using its column name, and we called its unique values.
#
# There's another way to call columns from a Pandas DataFrame if you're feeling lazy and don't want to mess around with brackets.

# %%
df.SERVICECODEDESCRIPTION.unique()
# Out:
# array(['Emergency No-Parking Verification', 'Parking Meter Repair',
#        'Sidewalk Repair', 'Tree Pruning', 'Bulk Collection',
#        'Parking Enforcement', 'Trash Collection - Missed',
#        'Sanitation Enforcement', 'Tree Inspection', 'Illegal Dumping',
#        'Rodent Inspection and Treatment', 'Yard Waste - Missed',
#        'Sidewalk Shoveling Enforcement Exemption',
#        'Dead Animal Collection', 'Emergency - Trees', 'Sign Replacement',
#        'Alley Cleaning', 'Abandoned Vehicle - On Private Property',
#        'DMV - Copy of Ticket', 'Streetlight Repair Investigation',
#        'Recycling Cart Delivery', 'Out of State Parking Violation (ROSA)',
#        'DMV - Vehicle Registration Issues',
#        'DMV - Drivers License/ID Issues', 'Pothole', 'Tree Planting',
#        'Leaf Season Collection', 'Residential Snow Removal (ServeDC)',
#        'Snow Removal Complaints for Sidewalks', 'Street Cleaning',
#        'Street Repair', 'Supercan - Repair', 'Alleylight Repair',
#        'Public Space Litter Can- Installation/Removal/Repair',
#        'Snow/Ice Removal', 'Residential Parking Permit Violation',
#        'Abandoned Vehicle - On Public Property',
#        'DC Government Information', 'Trash Cart - Delivery',
#        'Recycling Collection - Missed', 'Sign New Investigation',
#        'Wire Down/Power Outage', 'Vacant Lot', 'Bicycle Issues',
#        'How Is My Driving - Complaint', 'Signs Conflicting',
#        'Snow/Ice Removal (Roadways AND Bridge walkways ONLY)',
#        'DMV - Forms, Applications, and Manuals Request', 'Tree Removal',
#        'Christmas Tree Removal-Seasonal', 'Sign Removal investigation',
#        'TRU Report', 'DMV - Processing Center Manager',
#        'FEMS - Community Events', 'Traffic Signal Maintanence',
#        'Resident Parking Permit', 'Container Removal',
#        'Supercan - Delivery', 'Bus/Rail Issues',
#        'Homeless Services - Winter/Hypothermia Season',
#        'Sign Missing Investigation', 'Snow Metro Bus Shelter/Stop',
#        'Snow Ticket Reimbursement', 'DMV - Vehicle Title Issues',
#        'DOEE - Engine Idling Tips', 'Abandoned Bicycle',
#        'FEMS - Smoke Alarm Application', 'Traffic Calming',
#        'Graffiti Removal', 'Utility Repair Investigation', 'Snow Towing',
#        'Marking Installation', 'Public Space Litter Can-Collection',
#        'DMV - Driver Record Issues', 'DOEE - Nuisance Odor Complaints',
#        'Trash Cart Repair', 'DMV - Vehicle Insurance Lapse',
#        'Insect Treatment', 'Alley Repair',
#        'DMV - Online Processing Issues', 'Marking Removal',
#        'DMV - Ticket Payment Dispute', 'Recycling Cart - Repair',
#        'Illegal Poster', 'Curb and Gutter Repair', 'Marking Modification',
#        'DOEE - Ban on Foam Food Containers',
#        'DOEE - Construction – Erosion Runoff',
#        'DMV - eTIMS Ticket Alert Services Issues',
#        'How Is My Driving - Compliment', 'DMV - Refunds - Tickets',
#        'Marking Maintenance', 'DMV - Hearings',
#        'Traffic Safety Investigation', 'DOEE - Foam Ban Tips',
#        'Recycling- Information Request',
#        'DOEE - General Environmental Concerns',
#        'DMV - Adjudication Supervisor', 'Safe Routes to School',
#        'Roadway Repair', 'DMV - Driver and Vehicle Services Refund',
#        'DMV - Vehicle Inspection Issues',
#        'Curb and Gutter Repair Investigation', 'Light-Light Pole',
#        'DMV - Drivers License/ID Reinstatement',
#        'Emergency - Power Outage/Wires Down', 'Snow Other',
#        'DMV - Offset Tracking', 'Roadway Marking Maintenance',
#        '311Force Reported Issues', 'Alleylight Repair Investigation',
#        'Signed Street Sweeping Missed', 'Insects', 'Traffic Signal Issue',
#        'Grass and Weeds Mowing', 'OUC NYE Test',
#        'Roadway Striping / Markings', 'Child Safety Seat Program',
#        'School Crossing Guard', 'Streetcar',
#        'Light-Tunnel/Underpass Light Repair',
#        'General Environmental Concerns (DOEE)', 'Roadway Signs',
#        'DPW Correspondence Tracking', 'DMV - Appeal',
#        'Recycling - Commercial Only', 'Roadway Marking Modification',
#        'Utility Repair Issue', 'DOEE - Bag Law Tips',
#        'Light-Overhead Guide Sign Lighting Repair', 'Illegal Fireworks',
#        'Emergency - Heating and Cooling', 'Emergency - Senior Assistance',
#        'Emergency - Supplies', 'Report Invalid Address to GIS Dept',
#        'FEMS - Fire Safety Education', 'Recycling - School Program',
#        'School Transit Subsidy Program', 'Citation',
#        'Emergency - Flooding', 'Roadway Marking Removal',
#        'Bicycle Services', 'Ticket Ombudsman',
#        'School Crossing Guard Program', 'DDS - Serious Medication Error',
#        'SalesForce DC311 Application Request',
#        'Hypothermia Shelter Information'], dtype=object)

# %% [markdown]
# ## Exercise 14
#
# We can figure out how many unique values we have by getting the length of this object. Try it.

# %%
len(Out[18])
# Out:
# 147

# %% [markdown]
# We can also get value counts for each unique value of a categorical variable using value_counts.

# %%
df.SERVICECODEDESCRIPTION.value_counts()
# Out:
# Bulk Collection                                         45405
# Parking Meter Repair                                    34077
# Parking Enforcement                                     33733
# Emergency No-Parking Verification                       12644
# Streetlight Repair Investigation                        12344
# Pothole                                                 11225
# Trash Collection - Missed                                8159
# Alley Cleaning                                           7285
# Residential Parking Permit Violation                     6680
# Sanitation Enforcement                                   6423
# Sidewalk Shoveling Enforcement Exemption                 5777
# Snow/Ice Removal                                         5648
# Illegal Dumping                                          5542
# Recycling Collection - Missed                            5431
# Sidewalk Repair                                          5403
# Street Cleaning                                          5386
# Residential Snow Removal (ServeDC)                       5336
# Graffiti Removal                                         4972
# Abandoned Vehicle - On Public Property                   4667
# Tree Pruning                                             4071
# DMV - Drivers License/ID Issues                          3993
# Tree Inspection                                          3867
# Rodent Inspection and Treatment                          3531
# Out of State Parking Violation (ROSA)                    2945
# Snow/Ice Removal (Roadways AND Bridge walkways ONLY)     2858
# Tree Planting                                            2673
# Dead Animal Collection                                   2654
# DMV - Vehicle Registration Issues                        2600
# TRU Report                                               2500
# Tree Removal                                             2404
#                                                         ...
# Light-Tunnel/Underpass Light Repair                        19
# OUC NYE Test                                               17
# Marking Removal                                            14
# Hypothermia Shelter Information                            11
# Child Safety Seat Program                                  10
# Streetcar                                                   7
# DOEE - Bag Law Tips                                         6
# Recycling - Commercial Only                                 5
# Snow Other                                                  5
# Roadway Marking Removal                                     4
# School Crossing Guard Program                               4
# Recycling - School Program                                  3
# Emergency - Senior Assistance                               3
# DPW Correspondence Tracking                                 2
# Report Invalid Address to GIS Dept                          2
# Emergency - Flooding                                        2
# Insects                                                     2
# Ticket Ombudsman                                            1
# SalesForce DC311 Application Request                        1
# DDS - Serious Medication Error                              1
# Illegal Fireworks                                           1
# Light-Overhead Guide Sign Lighting Repair                   1
# FEMS - Fire Safety Education                                1
# Emergency - Heating and Cooling                             1
# DOEE - Foam Ban Tips                                        1
# Light-Light Pole                                            1
# School Transit Subsidy Program                              1
# Emergency - Supplies                                        1
# Citation                                                    1
# General Environmental Concerns (DOEE)                       1
# Name: SERVICECODEDESCRIPTION, dtype: int64

# %% [markdown]
# ## Exercise 15
#
# What's the most common request? What does that request mean? Check out the District's online 311 portal at 311.dc.gov to learn more about the top service request.

# %% [markdown]
# https://311.dc.gov/

# %%
# %%html
# <ion-page class="show-page service-type-component">
#     <ion-header>
#       <ion-toolbar class="toolbar">
#     <div class="toolbar-background"></div>
#
#     <ion-buttons start="">
#         <button class="bar-button bar-button-default"><span class="button-inner">
#           <span primary="">Cancel</span>
#         </span><ion-button-effect></ion-button-effect></button>
#       </ion-buttons>
#     <ion-buttons end="">
#           <button class="bar-button bar-button-default"><span class="button-inner">
#             <span primary="">Submit</span>
#           </span><ion-button-effect></ion-button-effect></button>
#         </ion-buttons>
#     <div class="toolbar-content">
#
#
#         <ion-title><div class="toolbar-title">
#           Residential Bulk Collection
#         </div></ion-title>
#
#
#     </div>
#   </ion-toolbar>
#     </ion-header>
#
#     <ion-content padding=""><scroll-content style="margin-top: 56px;">
#       <ion-list>
#         <!--template bindings={}--><div class="service-type-description">
#           <div>
#             <p>Servicing Agency</p>
#             <h4>DPW</h4>
#           </div>
#           <div>
#             <p>Service Resolution Estimate</p>
#             <h4>14 Business days</h4>
#           </div>
#           <div>
#             <p>Please use this service request type to schedule pick up of up to 7 bulk items, such as household furniture, appliances, water heaters, mattresses, bed frames and tree limbs. Prohibited Items include hazardous materials, construction debris and tires. These items should be disposed of at the Ft. Totten Transfer Station which is located at 4900 John F. McCormack Road, N.E.</p>
#           </div>
#         </div>
#       </ion-list>
#     </scroll-content></ion-content>
#   </ion-page>
# Out:
# <ion-page class="show-page service-type-component">
#     <ion-header>
#       <ion-toolbar class="toolbar">
#     <div class="toolbar-background"></div>
#
#     <ion-buttons start="">
#         <button class="bar-button bar-button-default"><span class="button-inner">
#           <span primary="">Cancel</span>
#         </span><ion-button-effect></ion-button-effect></button>
#       </ion-buttons>
#     <ion-buttons end="">
#           <button class="bar-button bar-button-default"><span class="button-inner">
#             <span primary="">Submit</span>
#           </span><ion-button-effect></ion-button-effect></button>
#         </ion-buttons>
#     <div class="toolbar-content">
#
#
#         <ion-title><div class="toolbar-title">
#           Residential Bulk Collection
#         </div></ion-title>
#
#
#     </div>
#   </ion-toolbar>
#     </ion-header>
#
#     <ion-content padding=""><scroll-content style="margin-top: 56px;">
#       <ion-list>
#         <!--template bindings={}--><div class="service-type-description">
#           <div>
#             <p>Servicing Agency</p>
#             <h4>DPW</h4>
#           </div>
#           <div>
#             <p>Service Resolution Estimate</p>
#             <h4>14 Business days</h4>
#           </div>
#           <div>
#             <p>Please use this service request type to schedule pick up of up to 7 bulk items, such as household furniture, appliances, water heaters, mattresses, bed frames and tree limbs. Prohibited Items include hazardous materials, construction debris and tires. These items should be disposed of at the Ft. Totten Transfer Station which is located at 4900 John F. McCormack Road, N.E.</p>
#           </div>
#         </div>
#       </ion-list>
#     </scroll-content></ion-content>
#   </ion-page>

# %% [markdown]
# You can use the markdown hyperlink convention to link a website. You can embed HTML with the HTML cell magic --CDL

# %% [markdown]
# ## Exercise 16
# Take a look at the data using some of the techniques including shape, head, and describe.
#
# Recall that we saw that date variables are stored as object data types in Pandas Data Frames.
# However, we CAN turn them in to datetime types using Pandas's nifty datetime commands.
# Let's begin by converting the service order date into a new datetime column in our DataFrame called "request_date".

# %%
df['request_date'] = pd.to_datetime(df['SERVICEORDERDATE'])

# %% [markdown]
# With any datetime object, we can use dt to pull the particulare date time that we're interested in.
# Here we use the value_counts function to look at the data by month.

# %%
df.request_date.dt.month.value_counts() #This is cool, I never use this when I should.
# Out:
# 1     34542
# 8     29892
# 9     26935
# 6     26253
# 7     25881
# 5     24289
# 10    24236
# 3     23892
# 4     23725
# 2     21541
# 11    20990
# 12    20809
# Name: request_date, dtype: int64

# %% [markdown]
# Notice that January is the month in which the city received the most service requests. However, the other top months for service requests are all summer months, and our winter months (December, November, February) are those with the least service requests. Does January seem to be an anomaly? Let's look closer.
# The value_counts function returns to pieces of information: the values, which are the actual counts of rows or observations, and the index, which the values are grouped by. In this case, the index is the set of months and the values are the number of service requests each month. The value_counts function returns an output that is sorted by the values, but we can also sort by the index using the sort_index function.

# %%
df.request_date.dt.month.value_counts().sort_index()
# Out:
# 1     34542
# 2     21541
# 3     23892
# 4     23725
# 5     24289
# 6     26253
# 7     25881
# 8     29892
# 9     26935
# 10    24236
# 11    20990
# 12    20809
# Name: request_date, dtype: int64

# %% [markdown]
# It may be helpful to plot this output to help us visualize the number of service requests made throughout the year.

# %%
requests_per_month = df.request_date.dt.month.value_counts()
requests_per_month.sort_index().plot()

# %% [markdown]
# We can see that January does, indeed, look anomalous. After spiking in January, service requests are low throughout the winter months, increasing as we move into the warmer months and peaking in August, after which they dip down again as we return to winter.
# Let's take a look at what's happening in January. We can focus in on January by selecting the subset of our service requests that came in January.

# %%
jan_requests = df[df.request_date.dt.month==1]
print(jan_requests.request_date.min())
print(jan_requests.request_date.max())
# Out:
# 2016-01-01 00:30:30
# 2016-01-31 23:43:20

# %% [markdown]
# Here, we've fed Python a logical statement telling it to return values from df where the date-part month in the column 'request_date' is equal to 1 (or January).
# # Exercise 4
# To better understand how this works, try taking the command out of the square brackets and running it. What does it return?

# %%
df.request_date.dt.month==1
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13         True
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23         True
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 302955    False
# 302956    False
# 302957    False
# 302958    False
# 302959    False
# 302960    False
# 302961    False
# 302962    False
# 302963    False
# 302964    False
# 302965    False
# 302966    False
# 302967    False
# 302968    False
# 302969    False
# 302970    False
# 302971    False
# 302972    False
# 302973    False
# 302974    False
# 302975    False
# 302976    False
# 302977    False
# 302978    False
# 302979    False
# 302980    False
# 302981    False
# 302982    False
# 302983    False
# 302984    False
# Name: request_date, dtype: bool

# %% [markdown]
# This returns a string of True and False statements. The 'True' values are the ones the DataFrame keeps, and the 'False' ones, it discards.
# Now that we have the January data, let's look at what kinds of requests were being made in January.
#
# ## Exercise 17
#
# Get value counts for the service code description from the subsample of January service requests. What where the most common requests?
#
# The city received a TON of snow removal requests in January 2016, but received very few other requests. It seems that these requests for snow removal are driving the high number of requests in January.
# If you were living in the District in January 2016, you'll remember this was the month that Snowzilla hit the city. This was a record-breaking snowstorm that dumped feet of snow on the city from January 22nd to January 23rd.
# Let's take a look at the top request in January, Snow/Ice Removal.

# %%
jan_requests['SERVICECODEDESCRIPTION'].value_counts()
# Out:
# Snow/Ice Removal                                        5347
# Residential Snow Removal (ServeDC)                      5278
# Sidewalk Shoveling Enforcement Exemption                5266
# Snow/Ice Removal (Roadways AND Bridge walkways ONLY)    2768
# Bulk Collection                                         2352
# Parking Enforcement                                     2079
# Parking Meter Repair                                    1997
# Snow Removal Complaints for Sidewalks                   1030
# Streetlight Repair Investigation                         817
# Emergency No-Parking Verification                        558
# Pothole                                                  543
# Trash Collection - Missed                                444
# Sanitation Enforcement                                   372
# Residential Parking Permit Violation                     357
# Abandoned Vehicle - On Public Property                   324
# Alley Cleaning                                           309
# DMV - Drivers License/ID Issues                          290
# Illegal Dumping                                          269
# Recycling Collection - Missed                            239
# DMV - Vehicle Registration Issues                        238
# Street Cleaning                                          226
# Alleylight Repair                                        210
# Sidewalk Repair                                          207
# TRU Report                                               169
# Out of State Parking Violation (ROSA)                    167
# Dead Animal Collection                                   146
# Christmas Tree Removal-Seasonal                          133
# Sign Replacement                                         131
# Traffic Signal Maintanence                               127
# Street Repair                                            124
#                                                         ...
# DOEE - Construction – Erosion Runoff                       6
# DOEE - Engine Idling Tips                                  5
# DC Government Information                                  5
# Safe Routes to School                                      5
# DMV - Driver and Vehicle Services Refund                   4
# Snow Other                                                 4
# Marking Modification                                       4
# DMV - Vehicle Inspection Issues                            4
# DOEE - Ban on Foam Food Containers                         4
# Illegal Poster                                             4
# Recycling- Information Request                             3
# DMV - eTIMS Ticket Alert Services Issues                   2
# Signed Street Sweeping Missed                              2
# Emergency - Power Outage/Wires Down                        2
# Curb and Gutter Repair Investigation                       2
# Insect Treatment                                           2
# OUC NYE Test                                               1
# Light-Overhead Guide Sign Lighting Repair                  1
# Traffic Safety Investigation                               1
# Marking Removal                                            1
# DMV - Offset Tracking                                      1
# Roadway Striping / Markings                                1
# DMV - Adjudication Supervisor                              1
# Grass and Weeds Mowing                                     1
# School Crossing Guard                                      1
# Roadway Marking Maintenance                                1
# How Is My Driving - Compliment                             1
# Alleylight Repair Investigation                            1
# Light-Light Pole                                           1
# DOEE - Foam Ban Tips                                       1
# Name: SERVICECODEDESCRIPTION, dtype: int64

# %% [markdown]
# ## Exercise 18
#
# Get the subsample of service requests for Snow/Ice Removal. Get the number of requests for each day in January 2016, then plot those requests so we can look at them over the course of the month.

# %%
snow_df = jan_requests[jan_requests['SERVICECODEDESCRIPTION']== "Snow/Ice Removal"]

# %%
requests_per_day = snow_df.request_date.dt.day.value_counts()
requests_per_day.sort_index().plot()

# %% [markdown]
# We can see that almost all of the requests for snow and ice removal came in the days following Snowzilla.
# Now let's take a look at WHERE those requests were coming from. DC is organized into 8 wards. These wards are the largest political geographies in the District. Each ward has a representative on the District Council who is elected directly by the residents of that ward.

# %% [markdown]
# ## Exercise 19
#
# Get the number of requests for snow and ice removal from each of the wards in January 2016.

# %%
all_snow = df[df['SERVICECODEDESCRIPTION']== "Snow/Ice Removal"]
request_per_ward = all_snow.WARD.value_counts()
request_per_ward
# Out:
# 7.0    1193
# 5.0     881
# 8.0     874
# 4.0     835
# 3.0     688
# 6.0     442
# 1.0     419
# 2.0     279
# Name: WARD, dtype: int64

# %% [markdown]
# By far, the most requests for snow and ice removal came from Ward 7, while the fewest (almost a thousand fewer) came from Ward 2.
# Now let's take a look at response times. Ward 7 had the most requests, but is that an indication that the city was slower to plot roads in Ward 7 than it was in other wards?

# %% [markdown]
# ## Exercise 20
# Create a new date column from the resolution date column in our DataFrame of requests for snow and ice removal in January.

# %%
df['RESOLUTIONDATE']= pd.to_datetime(df['RESOLUTIONDATE'])
df['ADDDATE']= pd.to_datetime(df['ADDDATE'])

# %% [markdown]
# Because the resolution date comes AFTER the service request, the resolution date will always be 'greater' than the request date. We can get the amount of time took the city to respond to each service request by taking the difference between the resolution date and the request date.
#
# ## Exercise 21
#
# Subtract the request date from the resolution date and assign that to an object called "time_diff". Print time_diff.

# %%
time_diff = df['RESOLUTIONDATE']-df['ADDDATE']
time_diff
# Out:
# 0          0 days 04:27:43
# 1          0 days 13:54:39
# 2                      NaT
# 3        262 days 00:18:45
# 4         10 days 02:37:30
# 5         10 days 02:36:34
# 6          0 days 02:51:04
# 7          2 days 03:07:29
# 8          2 days 03:10:14
# 9          9 days 00:03:28
# 10         2 days 00:12:12
# 11                     NaT
# 12       149 days 00:39:26
# 13         0 days 01:22:42
# 14         0 days 11:58:39
# 15         0 days 10:01:25
# 16        16 days 05:00:36
# 17         7 days 05:44:36
# 18         9 days 00:07:17
# 19         0 days 21:42:16
# 20         0 days 04:05:57
# 21         9 days 17:49:17
# 22         0 days 04:02:51
# 23        38 days 01:41:44
# 24         1 days 04:07:38
# 25         0 days 00:01:56
# 26         8 days 02:38:48
# 27        10 days 05:41:41
# 28         0 days 02:48:46
# 29         0 days 00:00:00
#                 ...
# 302955                 NaT
# 302956                 NaT
# 302957                 NaT
# 302958                 NaT
# 302959   215 days 23:17:52
# 302960   211 days 18:09:18
# 302961    46 days 19:02:21
# 302962                 NaT
# 302963   175 days 03:13:28
# 302964   152 days 21:24:42
# 302965   359 days 00:56:56
# 302966   222 days 00:27:17
# 302967                 NaT
# 302968                 NaT
# 302969                 NaT
# 302970   246 days 02:33:18
# 302971   252 days 00:34:41
# 302972   134 days 03:34:06
# 302973                 NaT
# 302974   105 days 17:38:11
# 302975                 NaT
# 302976   173 days 09:24:27
# 302977   332 days 06:19:59
# 302978                 NaT
# 302979                 NaT
# 302980   102 days 14:17:36
# 302981                 NaT
# 302982                 NaT
# 302983                 NaT
# 302984    61 days 19:19:21
# dtype: timedelta64[ns]

# %% [markdown]
# Great! Now let's convert time_diff to the number of hours it took to respond using the astype function. This function can be used to change the data type of a column. The timedelta64 function lets us convert to the datetime part we're interested in.

# %%
df['response_time']= time_diff.astype('timedelta64[h]')

# %% [markdown]
# ## Exercise 22
# Create a new column in our DataFrame calls "response_time" that is the time difference between resolution date and request date in hours.

# %%
df['response_time']
# Out:
# 0            4.0
# 1           13.0
# 2            NaN
# 3         6288.0
# 4          242.0
# 5          242.0
# 6            2.0
# 7           51.0
# 8           51.0
# 9          216.0
# 10          48.0
# 11           NaN
# 12        3576.0
# 13           1.0
# 14          11.0
# 15          10.0
# 16         389.0
# 17         173.0
# 18         216.0
# 19          21.0
# 20           4.0
# 21         233.0
# 22           4.0
# 23         913.0
# 24          28.0
# 25           0.0
# 26         194.0
# 27         245.0
# 28           2.0
# 29           0.0
#            ...
# 302955       NaN
# 302956       NaN
# 302957       NaN
# 302958       NaN
# 302959    5183.0
# 302960    5082.0
# 302961    1123.0
# 302962       NaN
# 302963    4203.0
# 302964    3669.0
# 302965    8616.0
# 302966    5328.0
# 302967       NaN
# 302968       NaN
# 302969       NaN
# 302970    5906.0
# 302971    6048.0
# 302972    3219.0
# 302973       NaN
# 302974    2537.0
# 302975       NaN
# 302976    4161.0
# 302977    7974.0
# 302978       NaN
# 302979       NaN
# 302980    2462.0
# 302981       NaN
# 302982       NaN
# 302983       NaN
# 302984    1483.0
# Name: response_time, dtype: float64

# %% [markdown]
# Now that we have our response times, let's use the groupby function to get the average response time by ward.

# %%
df.groupby('WARD').response_time.mean()
# Out:
# WARD
# 1.0    353.708141
# 2.0    453.247920
# 3.0    416.287066
# 4.0    509.956321
# 5.0    508.200059
# 6.0    376.486354
# 7.0    545.118179
# 8.0    490.214803
# Name: response_time, dtype: float64

# %% [markdown]
# This looks a lot like the output from the value_counts function. In fact, value_counts is a type of groupby function that simply returns counts for each of the unique values in a column.
# The groupby function allows us to aggregate the data by the unique values of a column (or multiple columns) and return various statistics, including mean, median, minimum (min), maximum (max), counts, etc.
# Again, we have two parts to the output: the index, in this case the ward, and the values, in this case the average hours it to the city to respond to a request for snow and ice removal. The groupby function returns the values sorted by the index. However, we can sort the values by the value using the sort_values function.

# %% [markdown]
# ## Exercise 23
# Get the average response times by ward again and sort the values by the average response time in ascending order (from highest to lowest). Which ward had the longest response times? Which had the lowest?
#
# Now we know which wards made the mo

# %%
group = df.groupby('WARD').response_time.mean()
group.sort_values(ascending=False)
# Out:
# WARD
# 7.0    545.118179
# 4.0    509.956321
# 5.0    508.200059
# 8.0    490.214803
# 2.0    453.247920
# 3.0    416.287066
# 6.0    376.486354
# 1.0    353.708141
# Name: response_time, dtype: float64

# %% [markdown]
# Now we know which wards made the most requests for snow and ice removal following the historic snowstorm in January 2016. Why do you think some wards received faster service than others? Do you think you could build a model predicting which requests would receive the fastest response?

# %%
#Worth a try
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib
import sklearn as sm
# Out:
# Using matplotlib backend: Qt5Agg

# %%
df_09 = pd.read_csv('https://opendata.arcgis.com/datasets/7c9ac81c00c14f4ba8c96df107f45e9d_0.csv')
df_10 = pd.read_csv('https://opendata.arcgis.com/datasets/ba150a4170bc484b8cc204be308fa70c_1.csv')
df_11 = pd.read_csv('https://opendata.arcgis.com/datasets/310e9e84ad7f4af7a31e7115395d7b57_2.csv')
df_12 = pd.read_csv('https://opendata.arcgis.com/datasets/65a81d0a91654b9692c08ca37809c3c3_3.csv')
df_13 = pd.read_csv('https://opendata.arcgis.com/datasets/20dc3ba98d494e51bee18a42f8430824_4.csv')
df_14 = pd.read_csv('https://opendata.arcgis.com/datasets/17cafb3ffab347409def7e85e14c56bd_5.csv')
df_15 = pd.read_csv('https://opendata.arcgis.com/datasets/b93ec7fc97734265a2da7da341f1bba2_6.csv')
df_16 = pd.read_csv('https://opendata.arcgis.com/datasets/0e4b7d3a83b94a178b3d1f015db901ee_7.csv')
df_17 = pd.read_csv('https://opendata.arcgis.com/datasets/19905e2b0e1140ec9ce8437776feb595_8.csv')
#Somebody made this phrase compliant with PEP-8! Wonder if intentional

data = [df_09, df_10, df_11, df_12, df_13, df_14, df_15, df_16, df_17]
enum_data = enumerate(data)
enum_data
# Out:
# C:\Users\CDL\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\CDL\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
big = pd.concat(data)

# %%
big
# Out:
#                 X          Y  OBJECTID SERVICECODE  \
# 0      -77.005626  38.836069    605933       S0016
# 1      -77.026395  38.934559    612172       S0361
# 2      -77.020725  38.920107    614299       S0361
# 3      -77.034179  38.947001    616895       S0361
# 4      -77.029991  38.969161    620733       S0361
# 5      -77.083420  38.910455    630107       S0361
# 6      -76.995534  38.953715    630370       S0361
# 7      -76.978046  38.903896    638422       S0459
# 8      -76.986580  38.896580    639735       S0016
# 9      -77.032005  38.926253    656297       S0036
# 10     -77.047342  38.923256    656309       S0036
# 11     -76.997500  38.923908    656657       S0036
# 12     -77.037173  38.878347    661779       S0301
# 13     -77.050162  38.892103    666840       S0301
# 14     -77.087731  38.935788    670459       S0406
# 15     -77.008191  38.898146    694503       S0361
# 16     -76.997346  38.886208    695530       S0361
# 17     -77.074151  38.913551    701703       GRAFF
# 18     -77.068629  38.905083    701704       GRAFF
# 19     -77.081614  38.949695    701705       GRAFF
# 20     -77.022742  38.934455    702053          11
# 21     -76.982457  38.894228    702501       S0166
# 22     -76.975848  38.850817    702502       S0166
# 23     -76.932957  38.903719    702503       S0166
# 24     -76.975848  38.850817    702504       S0166
# 25     -77.002036  38.882309    702505       S0166
# 26     -77.042229  38.946029    702506       S0166
# 27     -76.986379  38.869019    702507       S0166
# 28     -76.984369  38.891843    702508       S0166
# 29     -76.970269  38.857751    702509       S0166
# ...           ...        ...       ...         ...
# 216376 -76.993259  38.903045   1737774       S0031
# 216377 -77.016370  38.913195   1737775       S0336
# 216378 -77.016353  38.913742   1737776       GRAFF
# 216379 -77.055636  38.974065   1737777    CONTREMO
# 216380 -77.022433  38.914096   1737778       S0276
# 216381 -77.080572  38.946291   1737779       S0185
# 216382 -76.978277  38.903881   1737780         RPP
# 216383 -76.997134  38.954567   1737781       S05SL
# 216384 -77.063908  38.943164   1737782       S0301
# 216385 -77.071257  38.942925   1737783       S0301
# 216386 -77.083788  38.943172   1737784       S0301
# 216387 -77.072636  38.943005   1737785       S04TP
# 216388 -76.997542  38.954088   1737786    SIGNMISS
# 216389 -77.021921  38.912321   1737787       GRAFF
# 216390 -76.986065  38.907113   1737788       S0441
# 216391 -77.045344  38.921189   1737789       EMNPV
# 216392 -76.998212  38.926086   1737790         RPP
# 216393 -77.055343  38.942934   1737791       S0406
# 216394 -76.986725  38.929976   1737792         RPP
# 216395 -77.021892  38.936383   1737793       DMV19
# 216396 -77.081422  38.943168   1737794       GRAFF
# 216397 -76.989807  38.900881   1737795       S0181
# 216398 -77.015074  38.914197   1737796       S0031
# 216399 -76.992647  38.896256   1737797       S0441
# 216400 -76.965807  38.875066   1737798       S0003
# 216401 -76.990967  38.860336   1737799         RPP
# 216402 -76.991802  38.892937   1737800       S0457
# 216403 -77.048845  38.896912   1737801       S0276
# 216404 -77.007361  38.829955   1737802       S0261
# 216405 -77.026501  38.925031   1737803       S0261
#
#                          SERVICECODEDESCRIPTION  \
# 0                                  Alley Repair
# 1                               Sidewalk Repair
# 2                               Sidewalk Repair
# 3                               Sidewalk Repair
# 4                               Sidewalk Repair
# 5                               Sidewalk Repair
# 6                               Sidewalk Repair
# 7                                  Tree Removal
# 8                                  Alley Repair
# 9                                  Bus Shelters
# 10                                 Bus Shelters
# 11                                 Bus Shelters
# 12                                      Pothole
# 13                                      Pothole
# 14                                Street Repair
# 15                              Sidewalk Repair
# 16                              Sidewalk Repair
# 17                             Graffiti Removal
# 18                             Graffiti Removal
# 19                             Graffiti Removal
# 20                           Dead Animal Pickup
# 21                         Grass & Weeds Mowing
# 22                         Grass & Weeds Mowing
# 23                         Grass & Weeds Mowing
# 24                         Grass & Weeds Mowing
# 25                         Grass & Weeds Mowing
# 26                         Grass & Weeds Mowing
# 27                         Grass & Weeds Mowing
# 28                         Grass & Weeds Mowing
# 29                         Grass & Weeds Mowing
# ...                                         ...
# 216376                          Bulk Collection
# 216377    Out of State Parking Violation (ROSA)
# 216378                         Graffiti Removal
# 216379                        Container Removal
# 216380                     Parking Meter Repair
# 216381                           Illegal Poster
# 216382     Residential Parking Permit Violation
# 216383         Streetlight Repair Investigation
# 216384                                  Pothole
# 216385                                  Pothole
# 216386                                  Pothole
# 216387                            Tree Planting
# 216388                            Roadway Signs
# 216389                         Graffiti Removal
# 216390                Trash Collection - Missed
# 216391        Emergency No-Parking Verification
# 216392     Residential Parking Permit Violation
# 216393                           Roadway Repair
# 216394     Residential Parking Permit Violation
# 216395        DMV - Vehicle Registration Issues
# 216396                         Graffiti Removal
# 216397                          Illegal Dumping
# 216398                          Bulk Collection
# 216399                Trash Collection - Missed
# 216400  Abandoned Vehicle - On Private Property
# 216401     Residential Parking Permit Violation
# 216402                          Tree Inspection
# 216403                     Parking Meter Repair
# 216404                      Parking Enforcement
# 216405                      Parking Enforcement
#
#                                SERVICETYPECODEDESCRIPTION ORGANIZATIONACRONYM  \
# 0                                                   SIOD                 DDOT
# 1                                                   SIOD                 DDOT
# 2                                                   SIOD                 DDOT
# 3                                                   SIOD                 DDOT
# 4                                                   SIOD                 DDOT
# 5                                                   SIOD                 DDOT
# 6                                                   SIOD                 DDOT
# 7                                         Urban Forrestry                DDOT
# 8                                                   SIOD                 DDOT
# 9         Transportation Policy & Planning Administration                DDOT
# 10        Transportation Policy & Planning Administration                DDOT
# 11        Transportation Policy & Planning Administration                DDOT
# 12                            Street & Bridge Maintenance                DDOT
# 13                            Street & Bridge Maintenance                DDOT
# 14                                                  SIOD                 DDOT
# 15                                                  SIOD                 DDOT
# 16                                                  SIOD                 DDOT
# 17                                               Graffiti                 DPW
# 18                                               Graffiti                 DPW
# 19                                               Graffiti                 DPW
# 20                                            Dead Animal                 DPW
# 21                        Str & Alley Cleaning - Seasonal                 DPW
# 22                        Str & Alley Cleaning - Seasonal                 DPW
# 23                        Str & Alley Cleaning - Seasonal                 DPW
# 24                        Str & Alley Cleaning - Seasonal                 DPW
# 25                        Str & Alley Cleaning - Seasonal                 DPW
# 26                        Str & Alley Cleaning - Seasonal                 DPW
# 27                        Str & Alley Cleaning - Seasonal                 DPW
# 28                        Str & Alley Cleaning - Seasonal                 DPW
# 29                        Str & Alley Cleaning - Seasonal                 DPW
# ...                                                   ...                 ...
# 216376          SWMA- Solid Waste Management Admistration                 DPW
# 216377  PEMA- Parking Enforcement Management Administr...                 DPW
# 216378          SWMA- Solid Waste Management Admistration                 DPW
# 216379          SWMA- Solid Waste Management Admistration                 DPW
# 216380           Transportation Operations Administration                DDOT
# 216381          SWMA- Solid Waste Management Admistration                 DPW
# 216382  PEMA- Parking Enforcement Management Administr...                 DPW
# 216383           Transportation Operations Administration                DDOT
# 216384                    Toa-Street & Bridge Maintenance                DDOT
# 216385                    Toa-Street & Bridge Maintenance                DDOT
# 216386                    Toa-Street & Bridge Maintenance                DDOT
# 216387                                    Urban Forrestry                DDOT
# 216388                            Toa-Trans Sys Mnt-Signs                DDOT
# 216389          SWMA- Solid Waste Management Admistration                 DPW
# 216390          SWMA- Solid Waste Management Admistration                 DPW
# 216391  PEMA- Parking Enforcement Management Administr...                 DPW
# 216392  PEMA- Parking Enforcement Management Administr...                 DPW
# 216393                                               SIOD                DDOT
# 216394  PEMA- Parking Enforcement Management Administr...                 DPW
# 216395                            Driver Vehicle Services                 DMV
# 216396          SWMA- Solid Waste Management Admistration                 DPW
# 216397          SWMA- Solid Waste Management Admistration                 DPW
# 216398          SWMA- Solid Waste Management Admistration                 DPW
# 216399          SWMA- Solid Waste Management Admistration                 DPW
# 216400  PEMA- Parking Enforcement Management Administr...                 DPW
# 216401  PEMA- Parking Enforcement Management Administr...                 DPW
# 216402                                    Urban Forrestry                DDOT
# 216403           Transportation Operations Administration                DDOT
# 216404  PEMA- Parking Enforcement Management Administr...                 DPW
# 216405  PEMA- Parking Enforcement Management Administr...                 DPW
#
#         SERVICECALLCOUNT                   ADDDATE            RESOLUTIONDATE  \
# 0                      1  2009-10-30T12:54:23.000Z  2015-05-01T14:28:07.000Z
# 1                      1  2009-12-21T12:03:10.000Z  2015-05-01T14:33:19.000Z
# 2                      1  2009-10-20T11:46:48.000Z  2015-05-01T14:27:07.000Z
# 3                      1  2009-12-04T09:37:47.000Z  2015-05-01T14:32:24.000Z
# 4                      1  2009-12-09T14:50:04.000Z  2015-05-01T14:32:50.000Z
# 5                      1  2009-10-17T20:31:44.000Z  2015-05-01T14:27:05.000Z
# 6                      1  2009-11-09T16:16:25.000Z  2015-05-01T14:30:21.000Z
# 7                      1  2009-09-16T10:56:42.000Z  2012-02-08T16:43:59.000Z
# 8                      1  2009-10-16T16:35:57.000Z  2015-05-01T14:27:04.000Z
# 9                      1  2009-10-19T11:45:41.000Z  2015-05-01T14:27:06.000Z
# 10                     1  2009-10-26T08:09:29.000Z  2015-05-01T14:27:22.000Z
# 11                     1  2009-10-21T13:54:34.000Z  2015-05-01T14:27:13.000Z
# 12                     1  2009-12-27T20:08:56.000Z  2010-01-08T10:26:51.000Z
# 13                     1  2009-11-17T18:05:19.000Z  2009-12-04T15:47:05.000Z
# 14                     1  2009-11-17T23:44:22.000Z  2010-10-04T18:13:07.000Z
# 15                     1  2009-12-28T14:37:40.000Z  2015-05-01T14:33:32.000Z
# 16                     1  2009-09-28T11:03:13.000Z  2012-02-08T16:47:12.000Z
# 17                     1  2009-01-16T17:35:18.000Z  2014-09-25T12:59:45.000Z
# 18                     1  2009-01-09T08:47:35.000Z  2014-09-25T12:56:49.000Z
# 19                     1  2009-01-20T15:36:02.000Z  2014-09-25T13:00:53.000Z
# 20                     1  2009-07-23T13:22:00.000Z  2014-09-26T08:00:43.000Z
# 21                     1  2009-06-01T12:15:00.000Z  2014-09-29T13:36:53.000Z
# 22                     1  2009-06-02T14:28:00.000Z  2014-09-29T13:45:55.000Z
# 23                     1  2009-06-01T14:30:00.000Z  2014-09-29T13:39:53.000Z
# 24                     1  2009-05-28T13:37:00.000Z  2014-09-29T13:11:29.000Z
# 25                     1  2009-06-01T23:40:16.000Z  2014-09-29T13:42:39.000Z
# 26                     1  2009-06-02T17:42:11.000Z  2014-09-29T13:50:59.000Z
# 27                     1  2009-06-01T13:30:00.000Z  2014-09-29T13:38:30.000Z
# 28                     1  2009-06-01T08:49:00.000Z  2014-09-29T13:32:13.000Z
# 29                     1  2009-06-01T09:05:00.000Z  2014-09-29T13:34:50.000Z
# ...                  ...                       ...                       ...
# 216376                 1  2017-09-11T08:58:29.000Z                       NaN
# 216377                 1  2017-09-11T08:58:57.000Z                       NaN
# 216378                 1  2017-09-11T08:59:01.000Z                       NaN
# 216379                 1  2017-09-11T08:59:40.000Z                       NaN
# 216380                 1  2017-09-11T08:59:19.000Z                       NaN
# 216381                 1  2017-09-11T08:59:47.000Z                       NaN
# 216382                 1  2017-09-11T08:59:56.000Z                       NaN
# 216383                 1  2017-09-11T08:55:23.000Z                       NaN
# 216384                 1  2017-09-11T08:56:53.000Z                       NaN
# 216385                 1  2017-09-11T08:57:51.000Z                       NaN
# 216386                 1  2017-09-11T08:58:39.000Z                       NaN
# 216387                 1  2017-09-11T09:00:45.000Z                       NaN
# 216388                 1  2017-09-11T09:02:34.000Z                       NaN
# 216389                 1  2017-09-11T09:01:26.000Z                       NaN
# 216390                 1  2017-09-11T09:03:46.000Z                       NaN
# 216391                 1  2017-09-11T09:04:09.000Z                       NaN
# 216392                 1  2017-09-11T09:04:37.000Z                       NaN
# 216393                 1  2017-09-11T09:16:52.000Z                       NaN
# 216394                 1  2017-09-11T09:18:32.000Z                       NaN
# 216395                 1  2017-09-11T09:19:12.000Z                       NaN
# 216396                 1  2017-09-11T09:19:15.000Z                       NaN
# 216397                 1  2017-09-11T09:20:30.000Z                       NaN
# 216398                 1  2017-09-11T09:21:46.000Z                       NaN
# 216399                 1  2017-09-11T09:23:08.000Z                       NaN
# 216400                 1  2017-09-11T09:23:32.000Z                       NaN
# 216401                 1  2017-09-11T09:23:18.000Z                       NaN
# 216402                 1  2017-09-11T09:22:38.000Z                       NaN
# 216403                 1  2017-09-11T09:22:46.000Z                       NaN
# 216404                 1  2017-09-11T09:24:00.000Z                       NaN
# 216405                 1  2017-09-11T09:24:05.000Z                       NaN
#
#                               ...                                 XCOORD  \
# 0                             ...                          399511.740000
# 1                             ...                          397711.740000
# 2                             ...                          398202.899996
# 3                             ...                          397037.350000
# 4                             ...                          397401.180000
# 5                             ...                          392765.100000
# 6                             ...                          400387.320000
# 7                             ...                          401904.500000
# 8                             ...                          401164.330000
# 9                             ...                          397224.970000
# 10                            ...                          395894.910010
# 11                            ...                          400216.990000
# 12                            ...                          396774.670011
# 13                            ...                          395648.497402
# 14                            ...                          392393.930007
# 15                            ...                          399289.640000
# 16                            ...                          400230.420000
# 17                            ...                          393569.240056
# 18                            ...                          394047.492952
# 19                            ...                          392925.599991
# 20                            ...                          398028.420000
# 21                            ...                          401522.110000
# 22                            ...                          402096.690000
# 23                            ...                          405815.460000
# 24                            ...                          402096.690000
# 25                            ...                          399823.519998
# 26                            ...                          396339.430000
# 27                            ...                          401182.270000
# 28                            ...                          401356.240000
# 29                            ...                          402580.710000
# ...                           ...                                    ...
# 216376                        ...                          400584.920000
# 216377                        ...                          398580.490000
# 216378                        ...                          398581.910000
# 216379                        ...                          395179.100000
# 216380                        ...                          398054.690000
# 216381                        ...                          393015.600000
# 216382                        ...                          401884.400000
# 216383                        ...                          400248.630000
# 216384                        ...                          394459.910000
# 216385                        ...                          393822.810000
# 216386                        ...                          392736.470007
# 216387                        ...                          393703.260000
# 216388                        ...                          400213.230000
# 216389                        ...                          398099.022844
# 216390                        ...                          401208.890000
# 216391                        ...                          396068.030000
# 216392                        ...                          400155.230000
# 216393                        ...                          395202.460000
# 216394                        ...                          401151.240000
# 216395                        ...                          398102.150000
# 216396                        ...                          392941.590007
# 216397                        ...                          400884.340000
# 216398                        ...                          398692.880000
# 216399                        ...                          400638.090000
# 216400                        ...                          402967.300000
# 216401                        ...                          400784.210000
# 216402                        ...                          400711.430000
# 216403                        ...                          395762.990000
# 216404                        ...                          399361.010000
# 216405                        ...                          397702.170000
#
#                YCOORD   LATITUDE  LONGITUDE        CITY STATE  ZIPCODE  \
# 0       129807.610000  38.836061 -77.005624  WASHINGTON    DC  20032.0
# 1       140741.130000  38.934551 -77.026392  WASHINGTON    DC  20010.0
# 2       139136.719999  38.920100 -77.020723  WASHINGTON    DC  20059.0
# 3       142122.450000  38.946993 -77.034177  WASHINGTON    DC  20011.0
# 4       144582.310000  38.969153 -77.029989  WASHINGTON    DC  20012.0
# 5       138068.380000  38.910448 -77.083418  WASHINGTON    DC  20007.0
# 6       142867.310000  38.953708 -76.995532  WASHINGTON    DC  20011.0
# 7       137337.200000  38.903889 -76.978043  WASHINGTON    DC  20002.0
# 8       136524.860000  38.896572 -76.986578  WASHINGTON    DC  20002.0
# 9       139819.250000  38.926245 -77.032003  WASHINGTON    DC  20009.0
# 10      139487.130015  38.923248 -77.047340  WASHINGTON    DC  20009.0
# 11      139558.380000  38.923900 -76.997498  WASHINGTON    DC  20017.0
# 12      134501.437690  38.878339 -77.037171  WASHINGTON    DC  20024.0
# 13      136029.001756  38.892095 -77.050159  WASHINGTON    DC  20037.0
# 14      140880.900000  38.935781 -77.087728  WASHINGTON    DC  20016.0
# 15      136698.700000  38.898139 -77.008189  WASHINGTON    DC  20002.0
# 16      135373.430000  38.886200 -76.997344  WASHINGTON    DC  20003.0
# 17      138411.320030  38.913543 -77.074149  WASHINGTON    DC  20007.0
# 18      137470.966333  38.905076 -77.068627  WASHINGTON    DC  20007.0
# 19      142424.200002  38.949688 -77.081612  WASHINGTON    DC  20016.0
# 20      140729.470000  38.934447 -77.022740  WASHINGTON    DC  20010.0
# 21      136263.880000  38.894221 -76.982454  WASHINGTON    DC  20002.0
# 22      131445.020000  38.850809 -76.975846  WASHINGTON    DC  20020.0
# 23      137319.390000  38.903711 -76.932955  WASHINGTON    DC  20019.0
# 24      131445.020000  38.850809 -76.975846  WASHINGTON    DC  20020.0
# 25      134940.650011  38.882302 -77.002034  WASHINGTON    DC  20003.0
# 26      142014.880000  38.946021 -77.042227  WASHINGTON    DC  20011.0
# 27      133465.370000  38.869011 -76.986376  WASHINGTON    DC  20020.0
# 28      135999.060000  38.891835 -76.984367  WASHINGTON    DC  20002.0
# 29      132214.860000  38.857743 -76.970267  WASHINGTON    DC  20020.0
# ...               ...        ...        ...         ...   ...      ...
# 216376  137242.530000  38.903038 -76.993257  WASHINGTON    DC  20002.0
# 216377  138369.300000  38.913187 -77.016367  WASHINGTON    DC  20001.0
# 216378  138430.080000  38.913735 -77.016351  WASHINGTON    DC  20001.0
# 216379  145127.750000  38.974057 -77.055634  WASHINGTON    DC  20015.0
# 216380  138469.470003  38.914088 -77.022430  WASHINGTON    DC  20001.0
# 216381  142046.210003  38.946283 -77.080570  WASHINGTON    DC  20016.0
# 216382  137335.510000  38.903874 -76.978275  WASHINGTON    DC  20002.0
# 216383  142961.790000  38.954559 -76.997132  WASHINGTON    DC  20011.0
# 216384  141697.890003  38.943156 -77.063906  WASHINGTON    DC  20008.0
# 216385  141671.850000  38.942917 -77.071255  WASHINGTON    DC  20008.0
# 216386  141700.277004  38.943165 -77.083786  WASHINGTON    DC  20016.0
# 216387  141680.900000  38.942998 -77.072634  WASHINGTON    DC  20016.0
# 216388  142908.720000  38.954081 -76.997540  WASHINGTON    DC  20011.0
# 216389  138272.346750  38.912313 -77.021919         NaN   NaN  20001.0
# 216390  137694.120000  38.907105 -76.986062  WASHINGTON    DC  20002.0
# 216391  139257.540000  38.921181 -77.045342  WASHINGTON    DC  20009.0
# 216392  139800.250000  38.926079 -76.998210  WASHINGTON    DC  20017.0
# 216393  141671.900000  38.942926 -77.055340  WASHINGTON    DC  20008.0
# 216394  140232.060000  38.929968 -76.986723  WASHINGTON    DC  20017.0
# 216395  140943.470000  38.936375 -77.021890  WASHINGTON    DC  20010.0
# 216396  141699.567020  38.943160 -77.081420  WASHINGTON    DC  20016.0
# 216397  137002.240000  38.900873 -76.989805  WASHINGTON    DC  20002.0
# 216398  138480.500000  38.914189 -77.015072  WASHINGTON    DC  20001.0
# 216399  136488.800000  38.896248 -76.992644  WASHINGTON    DC  20002.0
# 216400  134137.180000  38.875059 -76.965804  WASHINGTON    DC  20019.0
# 216401  132501.460000  38.860328 -76.990965  WASHINGTON    DC  20020.0
# 216402  136120.460000  38.892930 -76.991799  WASHINGTON    DC  20002.0
# 216403  136562.830003  38.896905 -77.048843  WASHINGTON    DC  20052.0
# 216404  129128.970000  38.829948 -77.007359  WASHINGTON    DC  20032.0
# 216405  139683.440000  38.925024 -77.026499  WASHINGTON    DC  20001.0
#
#        MARADDRESSREPOSITORYID WARD  \
# 0                     30914.0    8
# 1                    230546.0    1
# 2                         NaN    1
# 3                    255554.0    4
# 4                    257398.0    4
# 5                    271047.0    3
# 6                     12393.0    5
# 7                     56150.0    5
# 8                     66041.0    6
# 9                    231582.0    1
# 10                        NaN    1
# 11                   289571.0    5
# 12                        NaN    2
# 13                        NaN    2
# 14                        NaN    3
# 15                   293217.0    6
# 16                     2733.0    6
# 17                        NaN    2
# 18                        NaN    2
# 19                        NaN    3
# 20                   228602.0    1
# 21                    37089.0    6
# 22                    53110.0    8
# 23                    75071.0    7
# 24                    53110.0    8
# 25                        NaN    6
# 26                   258884.0    4
# 27                    68315.0    8
# 28                    63474.0    6
# 29                    46714.0    8
# ...                       ...  ...
# 216376                81941.0    6
# 216377               279322.0    5
# 216378               237210.0    5
# 216379               260492.0    4
# 216380               811339.0  NaN
# 216381               802564.0    3
# 216382                56507.0    5
# 216383                 8442.0    5
# 216384               802614.0    3
# 216385               222853.0    3
# 216386               900606.0    3
# 216387               222903.0    3
# 216388                12272.0    5
# 216389               903729.0    6
# 216390                71046.0    5
# 216391               235385.0    1
# 216392                44400.0    5
# 216393               219369.0    3
# 216394                66321.0    5
# 216395               228407.0    1
# 216396               902545.0    3
# 216397                72068.0    6
# 216398               230035.0    5
# 216399               812458.0    6
# 216400                67984.0    7
# 216401                65997.0    8
# 216402                49135.0    6
# 216403               803972.0    2
# 216404                27051.0    8
# 216405               231776.0    1
#
#                                                   DETAILS
# 0                                                     NaN
# 1                           Sidewalk needs to be repaired
# 2       on the corner there is hole just above the sto...
# 3       caller reports that the sidewalk has been upro...
# 4                                        CONCERN CITIZEN.
# 5       My driveway is on Foxhall Road, NOT Q St. This...
# 6       caller req to have sidewalk repaired sidewalk ...
# 7                                       IFO 1823 L Street
# 8       There is a broken cover for pipes in the alley...
# 9       Caller requiting for bus shelters and bunch at...
# 10                                                    NaN
# 11                                                    NaN
# 12                                                    NaN
# 13                                                    NaN
# 14      seam across entire intersection when turning f...
# 15                         concrete side walk need repair
# 16      The "tree root" heave is so severe that there ...
# 17      GRAFF ~COMMENTS - PARKING SIGN DEFACED WITH GR...
# 18      GRAFF ~COMMENTS - TWO TRAFFIC CONTROL BOXES DE...
# 19      GRAFF ~COMMENTS -  ~LOC - GRAFFITI ON EAST-FAC...
# 20      ** GEO-MERGE ** 11 ~COMMENTS - dead cat ~LOC -...
# 21      ** GEO-MERGE ** S0166 ~COMMENTS - There is som...
# 22      ** GEO-MERGE ** S0166 ~COMMENTS - caller reque...
# 23      ** GEO-MERGE ** S0166 ~COMMENTS - req to have ...
# 24      ** GEO-MERGE ** S0166 ~COMMENTS - grass and we...
# 25      S0166 ~COMMENTS - **SRCB**    WHAT TYPE OF ARE...
# 26      ** GEO-MERGE ** S0166 ~COMMENTS - **SRCB**    ...
# 27      ** GEO-MERGE ** S0166 ~COMMENTS - HIGH GRASS I...
# 28      ** GEO-MERGE ** S0166 ~COMMENTS - GRASS AND WE...
# 29      ** GEO-MERGE ** S0166 ~COMMENTS - req to have ...
# ...                                                   ...
# 216376                                                NaN
# 216377                                                NaN
# 216378                                                NaN
# 216379                                                NaN
# 216380                                                NaN
# 216381                                                NaN
# 216382                                                NaN
# 216383                                                NaN
# 216384                                                NaN
# 216385                                                NaN
# 216386                                                NaN
# 216387                                                NaN
# 216388                                                NaN
# 216389                                                NaN
# 216390                                                NaN
# 216391                                                NaN
# 216392                                                NaN
# 216393                                                NaN
# 216394                                                NaN
# 216395                                                NaN
# 216396                                                NaN
# 216397                                                NaN
# 216398                                                NaN
# 216399                                                NaN
# 216400                                                NaN
# 216401                                                NaN
# 216402                                                NaN
# 216403                                                NaN
# 216404                                                NaN
# 216405                                                NaN
#
# [1695234 rows x 30 columns]

# %%
#Ok the easy part is done I guess. Time to get my timedeltas
big['ADDDATE'] = pd.to_datetime(big['ADDDATE'], errors='coerce')
big['ADDDATE'].value_counts(dropna=False)
# Out:
# 2015-04-17 10:59:00    46
# 2015-04-17 11:05:00    45
# 2015-04-17 10:49:00    42
# 2015-04-17 11:02:00    41
# 2015-04-25 07:25:00    40
# 2015-04-25 21:26:00    39
# 2015-04-25 21:38:00    39
# 2015-04-25 21:29:00    39
# 2015-04-25 21:35:00    38
# 2015-04-17 10:52:00    38
# 2015-04-25 07:31:00    38
# 2015-04-17 10:46:00    36
# 2015-04-17 10:56:00    34
# 2015-04-25 20:46:00    34
# 2015-04-25 20:40:00    33
# 2015-04-25 20:41:00    33
# 2015-04-25 07:28:00    32
# 2015-04-25 21:32:00    32
# 2015-04-25 20:37:00    31
# 2015-04-25 07:22:00    31
# 2015-04-25 20:43:00    28
# 2015-04-29 06:30:00    28
# 2015-04-25 20:44:00    27
# 2015-04-25 20:34:00    27
# 2015-04-29 06:26:00    27
# 2015-04-17 10:55:00    26
# 2015-04-25 07:19:00    25
# 2015-04-25 07:29:00    22
# 2015-04-25 07:34:00    22
# 2015-04-25 07:23:00    22
#                        ..
# 2017-05-09 16:41:59     1
# 2017-05-01 14:27:40     1
# 2012-04-05 20:12:18     1
# 2017-08-23 21:28:17     1
# 2014-12-08 16:07:44     1
# 2014-09-10 11:21:10     1
# 2017-08-26 20:58:04     1
# 2012-08-28 08:26:05     1
# 2017-01-13 16:15:32     1
# 2016-07-18 13:10:41     1
# 2017-01-20 12:47:34     1
# 2017-04-14 10:08:27     1
# 2016-04-21 19:00:45     1
# 2014-11-22 13:56:43     1
# 2015-05-18 13:44:37     1
# 2012-05-14 11:15:09     1
# 2013-09-09 15:26:49     1
# 2012-09-27 16:29:13     1
# 2012-11-30 13:41:56     1
# 2016-08-18 07:58:21     1
# 2017-01-11 12:25:05     1
# 2016-05-19 14:37:20     1
# 2017-09-04 10:17:56     1
# 2016-12-05 12:52:47     1
# 2013-05-18 14:55:53     1
# 2012-07-17 10:58:10     1
# 2014-04-20 19:20:57     1
# 2014-01-28 08:14:21     1
# 2016-11-23 15:02:05     1
# 2012-07-11 17:45:34     1
# Name: ADDDATE, dtype: int64

# %%
big['RESOLUTIONDATE'] = pd.to_datetime(big['RESOLUTIONDATE'], errors='coerce')
big['RESOLUTIONDATE'].value_counts(dropna=False)
# Out:
# NaT                    143713
# 2014-10-01 09:55:14       770
# 2014-10-01 09:55:13       614
# 2014-10-01 09:55:15       591
# 2015-02-13 15:13:17       326
# 2015-01-30 12:05:25       322
# 2015-01-30 12:05:24       318
# 2015-01-30 12:05:26       311
# 2015-02-13 15:13:18       308
# 2015-01-30 12:05:28       306
# 2015-01-29 08:18:16       297
# 2015-01-30 12:05:27       289
# 2015-01-30 12:05:31       286
# 2015-01-30 12:05:29       283
# 2015-01-30 12:05:30       277
# 2015-01-30 12:05:32       277
# 2015-01-30 12:05:34       257
# 2015-01-30 12:05:33       255
# 2015-01-30 12:05:23       247
# 2015-01-30 12:05:35       247
# 2015-01-30 12:05:36       239
# 2015-01-30 12:05:37       237
# 2015-01-30 12:05:40       229
# 2015-01-30 12:05:41       226
# 2015-01-30 12:05:38       226
# 2015-01-30 12:05:42       220
# 2015-01-30 12:05:39       219
# 2015-01-30 12:05:43       210
# 2015-01-30 12:05:44       207
# 2016-09-29 14:23:09       200
#                         ...
# 2016-03-01 11:52:48         1
# 2017-04-11 09:13:40         1
# 2016-01-28 13:07:25         1
# 2016-03-28 15:54:09         1
# 2014-09-27 09:12:11         1
# 2013-12-06 13:34:33         1
# 2016-04-27 19:07:48         1
# 2017-06-20 14:13:48         1
# 2015-11-04 09:12:50         1
# 2012-08-28 11:56:11         1
# 2014-02-21 03:49:18         1
# 2014-03-25 12:48:34         1
# 2014-09-29 10:01:23         1
# 2015-10-13 14:18:38         1
# 2016-06-14 16:41:31         1
# 2015-09-10 13:18:49         1
# 2014-02-21 12:20:35         1
# 2014-04-21 15:00:25         1
# 2016-04-20 16:02:08         1
# 2013-09-05 14:48:01         1
# 2014-03-05 10:12:17         1
# 2012-05-22 09:42:30         1
# 2014-07-09 14:51:18         1
# 2014-09-09 13:31:29         1
# 2015-11-02 09:30:05         1
# 2012-05-20 12:29:43         1
# 2015-08-11 13:49:32         1
# 2014-10-02 06:23:07         1
# 2012-09-17 15:38:55         1
# 2016-12-29 14:42:58         1
# Name: RESOLUTIONDATE, dtype: int64

# %%
#That's too many NaTs, what happend? Gotta reset my dataframe
big = pd.concat(data)

# %%
big['ADDDATE'] = pd.to_datetime(big['ADDDATE'], errors='coerce', 
                                format='%Y%m%d%h%m')
big['ADDDATE'].value_counts(dropna=False)
# Out:
# 2015-04-17T10:59:00.000Z    46
# 2015-04-17T11:05:00.000Z    45
# 2015-04-17T10:49:00.000Z    42
# 2015-04-17T11:02:00.000Z    41
# 2015-04-25T07:25:00.000Z    40
# 2015-04-25T21:29:00.000Z    39
# 2015-04-25T21:26:00.000Z    39
# 2015-04-25T21:38:00.000Z    39
# 2015-04-25T21:35:00.000Z    38
# 2015-04-25T07:31:00.000Z    38
# 2015-04-17T10:52:00.000Z    38
# 2015-04-17T10:46:00.000Z    36
# 2015-04-17T10:56:00.000Z    34
# 2015-04-25T20:46:00.000Z    34
# 2015-04-25T20:41:00.000Z    33
# 2015-04-25T20:40:00.000Z    33
# 2015-04-25T07:28:00.000Z    32
# 2015-04-25T21:32:00.000Z    32
# 2015-04-25T07:22:00.000Z    31
# 2015-04-25T20:37:00.000Z    31
# 2015-04-25T20:43:00.000Z    28
# 2015-04-29T06:30:00.000Z    28
# 2015-04-25T20:44:00.000Z    27
# 2015-04-29T06:26:00.000Z    27
# 2015-04-25T20:34:00.000Z    27
# 2015-04-17T10:55:00.000Z    26
# 2015-04-25T07:19:00.000Z    25
# 2015-04-25T07:29:00.000Z    22
# 2015-04-25T07:23:00.000Z    22
# 2015-04-25T07:34:00.000Z    22
#                             ..
# 2015-08-01T09:10:21.000Z     1
# 2013-08-02T11:07:39.000Z     1
# 2016-07-19T15:07:07.000Z     1
# 2014-04-10T11:59:39.000Z     1
# 2015-05-31T17:20:39.000Z     1
# 2017-09-02T09:29:09.000Z     1
# 2017-03-14T16:21:43.000Z     1
# 2017-06-24T01:05:37.000Z     1
# 2015-09-27T11:50:20.000Z     1
# 2014-10-24T12:05:35.000Z     1
# 2012-06-21T08:49:38.000Z     1
# 2014-07-21T15:32:39.000Z     1
# 2014-01-24T09:28:35.000Z     1
# 2014-01-11T08:14:09.000Z     1
# 2014-03-12T17:54:04.000Z     1
# 2012-08-30T08:58:55.000Z     1
# 2014-07-19T18:32:42.000Z     1
# 2015-12-23T09:45:43.000Z     1
# 2016-07-20T15:26:29.000Z     1
# 2015-01-14T17:26:03.000Z     1
# 2013-07-30T19:46:01.000Z     1
# 2012-08-18T14:28:15.000Z     1
# 2016-06-13T10:15:12.000Z     1
# 2014-08-06T16:17:20.000Z     1
# 2016-04-18T18:52:45.000Z     1
# 2015-08-19T11:00:59.000Z     1
# 2015-08-12T11:11:01.000Z     1
# 2016-02-18T11:50:45.000Z     1
# 2012-05-01T20:46:02.000Z     1
# 2013-06-25T08:26:37.000Z     1
# Name: ADDDATE, dtype: int64

# %%
big['RES_ERR'] = pd.to_datetime(big['RESOLUTIONDATE'], errors='coerce', 
                                format='%Y%m%d%h%m')

# %%
#big[big['RES_ERR'] == pd.NaT]
big['RESOLUTIONDATE'].value_counts(dropna=False)
# Out:
# NaN                         143713
# 2014-10-01T09:55:14.000Z       770
# 2014-10-01T09:55:13.000Z       614
# 2014-10-01T09:55:15.000Z       591
# 2015-02-13T15:13:17.000Z       326
# 2015-01-30T12:05:25.000Z       322
# 2015-01-30T12:05:24.000Z       318
# 2015-01-30T12:05:26.000Z       311
# 2015-02-13T15:13:18.000Z       308
# 2015-01-30T12:05:28.000Z       306
# 2015-01-29T08:18:16.000Z       297
# 2015-01-30T12:05:27.000Z       289
# 2015-01-30T12:05:31.000Z       286
# 2015-01-30T12:05:29.000Z       283
# 2015-01-30T12:05:30.000Z       277
# 2015-01-30T12:05:32.000Z       277
# 2015-01-30T12:05:34.000Z       257
# 2015-01-30T12:05:33.000Z       255
# 2015-01-30T12:05:23.000Z       247
# 2015-01-30T12:05:35.000Z       247
# 2015-01-30T12:05:36.000Z       239
# 2015-01-30T12:05:37.000Z       237
# 2015-01-30T12:05:40.000Z       229
# 2015-01-30T12:05:38.000Z       226
# 2015-01-30T12:05:41.000Z       226
# 2015-01-30T12:05:42.000Z       220
# 2015-01-30T12:05:39.000Z       219
# 2015-01-30T12:05:43.000Z       210
# 2015-01-30T12:05:44.000Z       207
# 2016-09-29T14:23:09.000Z       200
#                              ...
# 2014-06-26T12:19:51.000Z         1
# 2016-01-28T01:43:07.000Z         1
# 2017-08-18T08:59:34.000Z         1
# 2017-05-15T14:39:25.000Z         1
# 2014-08-19T13:45:28.000Z         1
# 2014-03-12T11:58:22.000Z         1
# 2012-05-08T07:15:47.000Z         1
# 2017-06-12T11:58:46.000Z         1
# 2014-09-09T11:13:11.000Z         1
# 2016-05-16T13:43:15.000Z         1
# 2016-01-19T19:48:00.000Z         1
# 2014-07-16T14:04:32.000Z         1
# 2017-03-17T12:23:25.000Z         1
# 2016-12-01T11:26:40.000Z         1
# 2016-02-12T12:13:38.000Z         1
# 2014-08-22T13:29:45.000Z         1
# 2014-10-03T08:46:27.000Z         1
# 2014-08-14T19:51:25.000Z         1
# 2015-03-10T11:55:30.000Z         1
# 2016-12-21T00:44:25.000Z         1
# 2015-07-08T08:20:45.000Z         1
# 2012-10-17T12:32:33.000Z         1
# 2016-12-05T13:43:16.000Z         1
# 2016-11-16T11:14:56.000Z         1
# 2012-10-25T13:38:55.000Z         1
# 2017-07-12T15:33:45.000Z         1
# 2012-05-30T06:34:07.000Z         1
# 2014-11-05T13:57:01.000Z         1
# 2017-04-20T10:52:58.000Z         1
# 2016-04-25T20:27:33.000Z         1
# Name: RESOLUTIONDATE, dtype: int64

# %%
big[['RES_ERR', 'RESOLUTIONDATE']]
# Out:
#                          RES_ERR            RESOLUTIONDATE
# 0       2015-05-01T14:28:07.000Z  2015-05-01T14:28:07.000Z
# 1       2015-05-01T14:33:19.000Z  2015-05-01T14:33:19.000Z
# 2       2015-05-01T14:27:07.000Z  2015-05-01T14:27:07.000Z
# 3       2015-05-01T14:32:24.000Z  2015-05-01T14:32:24.000Z
# 4       2015-05-01T14:32:50.000Z  2015-05-01T14:32:50.000Z
# 5       2015-05-01T14:27:05.000Z  2015-05-01T14:27:05.000Z
# 6       2015-05-01T14:30:21.000Z  2015-05-01T14:30:21.000Z
# 7       2012-02-08T16:43:59.000Z  2012-02-08T16:43:59.000Z
# 8       2015-05-01T14:27:04.000Z  2015-05-01T14:27:04.000Z
# 9       2015-05-01T14:27:06.000Z  2015-05-01T14:27:06.000Z
# 10      2015-05-01T14:27:22.000Z  2015-05-01T14:27:22.000Z
# 11      2015-05-01T14:27:13.000Z  2015-05-01T14:27:13.000Z
# 12      2010-01-08T10:26:51.000Z  2010-01-08T10:26:51.000Z
# 13      2009-12-04T15:47:05.000Z  2009-12-04T15:47:05.000Z
# 14      2010-10-04T18:13:07.000Z  2010-10-04T18:13:07.000Z
# 15      2015-05-01T14:33:32.000Z  2015-05-01T14:33:32.000Z
# 16      2012-02-08T16:47:12.000Z  2012-02-08T16:47:12.000Z
# 17      2014-09-25T12:59:45.000Z  2014-09-25T12:59:45.000Z
# 18      2014-09-25T12:56:49.000Z  2014-09-25T12:56:49.000Z
# 19      2014-09-25T13:00:53.000Z  2014-09-25T13:00:53.000Z
# 20      2014-09-26T08:00:43.000Z  2014-09-26T08:00:43.000Z
# 21      2014-09-29T13:36:53.000Z  2014-09-29T13:36:53.000Z
# 22      2014-09-29T13:45:55.000Z  2014-09-29T13:45:55.000Z
# 23      2014-09-29T13:39:53.000Z  2014-09-29T13:39:53.000Z
# 24      2014-09-29T13:11:29.000Z  2014-09-29T13:11:29.000Z
# 25      2014-09-29T13:42:39.000Z  2014-09-29T13:42:39.000Z
# 26      2014-09-29T13:50:59.000Z  2014-09-29T13:50:59.000Z
# 27      2014-09-29T13:38:30.000Z  2014-09-29T13:38:30.000Z
# 28      2014-09-29T13:32:13.000Z  2014-09-29T13:32:13.000Z
# 29      2014-09-29T13:34:50.000Z  2014-09-29T13:34:50.000Z
# ...                          ...                       ...
# 216376                       NaN                       NaN
# 216377                       NaN                       NaN
# 216378                       NaN                       NaN
# 216379                       NaN                       NaN
# 216380                       NaN                       NaN
# 216381                       NaN                       NaN
# 216382                       NaN                       NaN
# 216383                       NaN                       NaN
# 216384                       NaN                       NaN
# 216385                       NaN                       NaN
# 216386                       NaN                       NaN
# 216387                       NaN                       NaN
# 216388                       NaN                       NaN
# 216389                       NaN                       NaN
# 216390                       NaN                       NaN
# 216391                       NaN                       NaN
# 216392                       NaN                       NaN
# 216393                       NaN                       NaN
# 216394                       NaN                       NaN
# 216395                       NaN                       NaN
# 216396                       NaN                       NaN
# 216397                       NaN                       NaN
# 216398                       NaN                       NaN
# 216399                       NaN                       NaN
# 216400                       NaN                       NaN
# 216401                       NaN                       NaN
# 216402                       NaN                       NaN
# 216403                       NaN                       NaN
# 216404                       NaN                       NaN
# 216405                       NaN                       NaN
#
# [1695234 rows x 2 columns]

# %%
#Maybe the 'RESOLUTIONDATE' headername is not consistent across data?

# %%
cols = [list(i.columns) for i in data]
head = []
for i in cols:
    for j in i:
        head += i
head= list(set(head))
head
# Out:
# ['STATE',
#  'Y',
#  'XCOORD',
#  'SERVICECODE',
#  'X',
#  'OBJECTID',
#  'ADDDATE',
#  'SERVICECODEDESCRIPTION',
#  'WARD',
#  'LATITUDE',
#  'LONGITUDE',
#  'INSPECTORNAME',
#  'STATUS_CODE',
#  'YCOORD',
#  'ORGANIZATIONACRONYM',
#  'INSPECTIONFLAG',
#  'ZIPCODE',
#  'SERVICEDUEDATE',
#  'INSPECTIONDATE',
#  'SERVICETYPECODEDESCRIPTION',
#  'SERVICEREQUESTID',
#  'SERVICECALLCOUNT',
#  'MARADDRESSREPOSITORYID',
#  'CITY',
#  'RESOLUTIONDATE',
#  'SERVICEORDERSTATUS',
#  'STREETADDRESS',
#  'SERVICEORDERDATE',
#  'DETAILS',
#  'PRIORITY']
